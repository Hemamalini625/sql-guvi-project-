# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemamalini625/sql-guvi-project-/blob/main/worksheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import googleapiclient.discovery
import pandas as pd
import seaborn as sns
from pprint import pprint
import json
import pymongo
api_key= "AIzaSyBhq9db_KumO5vbwfW2gd_uz7ONHDB2G_Y"
ch_ids= ["UCiT9RITQ9PW6BhXK0y2jaeg",# ken jee
         "UCiEmtpFVJjpvdhsQ2QAhxVA",# zen class from guvi
         "UCduIoIMfD8tT3KoU0-zBRgQ",#guvi
         "UCSJbGtTlrDami-tDGPUV9-w",#Academind
         "UCWv7vMbMWH4-V0ZXdmDpPBA"#programming with mosh
]

youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=api_key)
def get_channel(youtube,ch_ids):

    whole_data=[]

    request = youtube.channels().list(part="snippet,contentDetails,statistics",
                                      id=','.join(ch_ids))
    response = request.execute()

    for i in range (len(response['items'])):

      channel=dict( ch_name=response['items'][i]['snippet']['title'] ,# channel title,
                    ch_desc=response['items'][i]['snippet']['description'], #channel description
                    ch_join=response['items'][i]['snippet']['publishedAt'],#channel started
                    subscriber=response['items'][i]['statistics']['subscriberCount'],#subscriber count
                    viewer=response['items'][i]['statistics']['viewCount'],#view count
                    vi_count=response['items'][i]['statistics']['videoCount'],
                    playlist_id=response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])# video count)
      whole_data.append(channel)
    return whole_data

channel_details=get_channel(youtube,ch_ids)
channel_details
about_channel=pd.DataFrame(channel_details)
about_channel
about_channel.dtypes
about_channel['subscriber']=pd.to_numeric(about_channel['subscriber'])
about_channel['viewer']=pd.to_numeric(about_channel['viewer'])
about_channel['vi_count']=pd.to_numeric(about_channel['vi_count'])
about_channel['ch_join']=pd.to_datetime(about_channel['ch_join'])
about_channel.dtypes
playlist_ids=about_channel.loc[about_channel['ch_name'] == 'Ken Jee' ,'playlist_id'].iloc[0]
def get_video(youtube,playlist_ids):

      request = youtube.playlistItems().list(part='contentDetails',playlistId=playlist_ids,maxResults = 50)
      response = request.execute()

      video_ids=[]
      for i in range(len(response ['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])

      next_page_token = response.get('nextPageToken')
      more_pages = True

      while more_pages:
            if next_page_token is None:
                more_pages = False
            else:
                request = youtube.playlistItems().list(part='contentDetails',playlistId=playlist_ids,maxResults = 50,pageToken =next_page_token )
                response = request.execute()
                for i in range(len(response ['items'])):
                    video_ids.append(response['items'][i]['contentDetails']['videoId'])
                next_page_token = response.get('nextPageToken')
      return video_ids
video_ids=get_video(youtube,playlist_ids)
video_ids
def get_video(youtube,video_ids):
  all_video=[]
  for i in range(0,len(video_ids),50):
      request = youtube.videos().list(part='snippet,statistics',
                                    id =','.join(video_ids[i:i+50]))
      response=request.execute()
      for video in response['items']:
          video_status=dict(video_title=video['snippet']['title'],
                            published = video['snippet']['publishedAt'],
                            viewcount = video['statistics']['viewCount'],
                            comment_ct = video['statistics']['commentCount'],
                            likecount = video['statistics']['likeCount'])


          all_video.append(video_status)
  return all_video

video_det=get_video(youtube,video_ids)
video_data=pd.DataFrame(video_det)
video_data
video_data['published'] = pd.to_datetime(video_data['published']).dt.date
video_data['viewcount'] = pd.to_numeric(video_data['viewcount'])
video_data['likecount'] = pd.to_numeric(video_data['likecount'])
video_data['comment_ct'] = pd.to_numeric(video_data['comment_ct'])
video_det
# Out:
# [{'video_title': 'The Death of the Full-Time Job (Rise of the Contractor)',
#   'published': '2023-09-22T11:46:35Z',
#   'viewcount': '4871',
#   'comment_ct': '70',
#   'likecount': '334'},
#  {'video_title': 'How to Survive a Down Data Job Market',
#   'published': '2023-09-05T10:50:39Z',
#   'viewcount': '15562',
#   'comment_ct': '64',
#   'likecount': '508'},
#  {'video_title': 'The Harsh Reality of the Data Job Market',
#   'published': '2023-08-24T11:30:19Z',
#   'viewcount': '103828',
#   'comment_ct': '293',
#   'likecount': '2522'},
#  {'video_title': '7 Industries AI will Aggressively Disrupt',
#   'published': '2023-08-14T11:30:19Z',
#   'viewcount': '5568',
#   'comment_ct': '41',
#   'likecount': '229'},
#  {'video_title': "What's in My Data Science Travel Bag? (50+ Flights Last Year)",
#   'published': '2023-08-07T17:57:05Z',
#   'viewcount': '3849',
#   'comment_ct': '47',
#   'likecount': '122'},
#  {'video_title': '7 Enticing Jobs AI Will Create',
#   'published': '2023-07-24T12:00:01Z',
#   'viewcount': '4408',
#   'comment_ct': '37',
#   'likecount': '191'},
#  {'video_title': 'The ChatGPT Code Interpreter is OVERRATED',
#   'published': '2023-07-22T09:42:29Z',
#   'viewcount': '3944',
#   'comment_ct': '31',
#   'likecount': '142'},
#  {'video_title': 'Exciting Announcement!',
#   'published': '2023-06-23T17:28:36Z',
#   'viewcount': '6507',
#   'comment_ct': '50',
#   'likecount': '294'},
#  {'video_title': 'AI: A Customer Service Revolution?',
#   'published': '2023-05-26T12:00:21Z',
#   'viewcount': '3740',
#   'comment_ct': '35',
#   'likecount': '117'},
#  {'video_title': 'Beginner Kaggle Data Science Project Walk-Through (Housing Prices) | With ChatGPT',
#   'published': '2023-05-16T12:00:25Z',
#   'viewcount': '26804',
#   'comment_ct': '57',
#   'likecount': '919'},
#  {'video_title': 'How I Would Learn Data Science with AI (If I Could Start Over)',
#   'published': '2023-05-04T12:04:56Z',
#   'viewcount': '31697',
#   'comment_ct': '77',
#   'likecount': '1342'},
#  {'video_title': 'This AI question will determine our future',
#   'published': '2023-04-06T13:00:32Z',
#   'viewcount': '4225',
#   'comment_ct': '37',
#   'likecount': '262'},
#  {'video_title': "I'll Never Code the Same Again... (GPT-4 is OP)",
#   'published': '2023-04-03T13:00:27Z',
#   'viewcount': '70734',
#   'comment_ct': '79',
#   'likecount': '828'},
#  {'video_title': 'Your current portfolio is actually hurting you #shorts',
#   'published': '2023-03-30T13:00:37Z',
#   'viewcount': '6607',
#   'comment_ct': '7',
#   'likecount': '395'},
#  {'video_title': 'Traditional "networking" is stupid. Do THIS instead #shorts',
#   'published': '2023-03-27T13:00:41Z',
#   'viewcount': '6683',
#   'comment_ct': '3',
#   'likecount': '364'},
#  {'video_title': "you're job searching wrong. #shorts",
#   'published': '2023-03-23T13:00:35Z',
#   'viewcount': '4056',
#   'comment_ct': '3',
#   'likecount': '245'},
#  {'video_title': 'The Economics of Data Roles #shorts',
#   'published': '2023-03-21T13:00:15Z',
#   'viewcount': '7947',
#   'comment_ct': '10',
#   'likecount': '506'},
#  {'video_title': 'Why your phone knows everything you say #shorts',
#   'published': '2023-03-18T13:00:42Z',
#   'viewcount': '2684',
#   'comment_ct': '7',
#   'likecount': '120'},
#  {'video_title': 'Read these for a successful career. #shorts',
#   'published': '2023-03-16T01:19:35Z',
#   'viewcount': '2955',
#   'comment_ct': '2',
#   'likecount': '234'},
#  {'video_title': 'Is Your Phone Actually Listening to You? #shorts',
#   'published': '2023-03-09T13:00:01Z',
#   'viewcount': '2398',
#   'comment_ct': '5',
#   'likecount': '44'},
#  {'video_title': 'How I Realized I Was a Bad Manager #shorts',
#   'published': '2023-03-07T13:00:11Z',
#   'viewcount': '2603',
#   'comment_ct': '1',
#   'likecount': '120'},
#  {'video_title': 'How I Use ChatGPT as a Data Scientist (4-5 hrs Saved Per Week)',
#   'published': '2023-03-03T13:00:07Z',
#   'viewcount': '19986',
#   'comment_ct': '52',
#   'likecount': '751'},
#  {'video_title': 'Why I Quit Data Science... and then crawled back #shorts',
#   'published': '2023-03-01T13:00:17Z',
#   'viewcount': '7839',
#   'comment_ct': '13',
#   'likecount': '266'},
#  {'video_title': 'The Best Place to Look for Data Science Opportunities #shorts',
#   'published': '2023-02-27T13:00:32Z',
#   'viewcount': '2547',
#   'comment_ct': '2',
#   'likecount': '160'},
#  {'video_title': 'Learning On the companies dime #shorts',
#   'published': '2023-02-24T17:00:13Z',
#   'viewcount': '3045',
#   'comment_ct': '1',
#   'likecount': '173'},
#  {'video_title': 'The Best Way to Transition to Data Science? #shorts',
#   'published': '2023-02-21T17:13:47Z',
#   'viewcount': '3937',
#   'comment_ct': '6',
#   'likecount': '251'},
#  {'video_title': 'Avoid this Massive Data Science Learning Mistake #shorts',
#   'published': '2023-02-17T13:00:03Z',
#   'viewcount': '6707',
#   'comment_ct': '6',
#   'likecount': '388'},
#  {'video_title': "Don't Go into Data for the Money #shorts",
#   'published': '2023-02-15T10:00:37Z',
#   'viewcount': '3706',
#   'comment_ct': '12',
#   'likecount': '218'},
#  {'video_title': 'First Data Science Project? Watch This.',
#   'published': '2023-02-13T13:00:36Z',
#   'viewcount': '6515',
#   'comment_ct': '22',
#   'likecount': '340'},
#  {'video_title': 'How to Approach Applying for a Data Role #shorts',
#   'published': '2023-02-08T13:00:39Z',
#   'viewcount': '3652',
#   'comment_ct': '7',
#   'likecount': '243'},
#  {'video_title': 'The Hard Reality of Data Science Work #shorts',
#   'published': '2023-02-06T19:35:25Z',
#   'viewcount': '14051',
#   'comment_ct': '14',
#   'likecount': '789'},
#  {'video_title': 'How Much Money Does a Data Scientist Make? #shorts',
#   'published': '2023-02-03T12:00:03Z',
#   'viewcount': '4468',
#   'comment_ct': '6',
#   'likecount': '187'},
#  {'video_title': 'These 3 Things Make Data Science Special #shorts',
#   'published': '2023-02-01T12:00:12Z',
#   'viewcount': '4161',
#   'comment_ct': '7',
#   'likecount': '328'},
#  {'video_title': 'Will Data Science Be Automated? #shorts',
#   'published': '2023-01-27T11:00:44Z',
#   'viewcount': '8739',
#   'comment_ct': '8',
#   'likecount': '387'},
#  {'video_title': 'Is Data Science A Good Fit For You? #shorts',
#   'published': '2023-01-25T11:00:05Z',
#   'viewcount': '4997',
#   'comment_ct': '11',
#   'likecount': '287'},
#  {'video_title': '5 Books I Wish I Read Earlier In My Career',
#   'published': '2023-01-23T15:31:48Z',
#   'viewcount': '9167',
#   'comment_ct': '50',
#   'likecount': '512'},
#  {'video_title': 'How To Start Working on Data Science Projects (As a Beginner) #shorts',
#   'published': '2023-01-19T07:00:06Z',
#   'viewcount': '6163',
#   'comment_ct': '12',
#   'likecount': '554'},
#  {'video_title': 'What Data Science Tool Would I Learn First? #shorts',
#   'published': '2023-01-17T07:00:12Z',
#   'viewcount': '6242',
#   'comment_ct': '10',
#   'likecount': '472'},
#  {'video_title': 'How long does it take to become a Data Scientist? #shorts',
#   'published': '2023-01-12T11:45:02Z',
#   'viewcount': '6249',
#   'comment_ct': '6',
#   'likecount': '471'},
#  {'video_title': 'Where & how to start your Data Science Journey #shorts',
#   'published': '2023-01-09T00:35:13Z',
#   'viewcount': '6651',
#   'comment_ct': '2',
#   'likecount': '410'},
#  {'video_title': 'How I Would NOT Learn Data Science in 2023.',
#   'published': '2023-01-03T13:00:34Z',
#   'viewcount': '124367',
#   'comment_ct': '254',
#   'likecount': '4113'},
#  {'video_title': 'The Greatest Data Science Event You Never Heard Of  [Behind The Scenes]',
#   'published': '2022-12-14T13:00:23Z',
#   'viewcount': '4839',
#   'comment_ct': '28',
#   'likecount': '202'},
#  {'video_title': 'The Essential Programming Concepts For Learning Data Science',
#   'published': '2022-11-14T13:00:02Z',
#   'viewcount': '20380',
#   'comment_ct': '46',
#   'likecount': '847'},
#  {'video_title': 'The Data Content House: What You Missed',
#   'published': '2022-10-07T13:00:04Z',
#   'viewcount': '10436',
#   'comment_ct': '49',
#   'likecount': '348'},
#  {'video_title': 'Is Data Science A Good Career?',
#   'published': '2022-09-29T20:40:31Z',
#   'viewcount': '61074',
#   'comment_ct': '139',
#   'likecount': '1933'},
#  {'video_title': 'IRON ANALYST (Teaser) #shorts',
#   'published': '2022-09-27T17:21:13Z',
#   'viewcount': '5641',
#   'comment_ct': '24',
#   'likecount': '366'},
#  {'video_title': 'When a New Data Scientist Joins The Team',
#   'published': '2022-08-29T13:00:01Z',
#   'viewcount': '16415',
#   'comment_ct': '133',
#   'likecount': '745'},
#  {'video_title': 'State of Data Science - Web Data',
#   'published': '2022-08-05T20:20:04Z',
#   'viewcount': '10433',
#   'comment_ct': '34',
#   'likecount': '359'},
#  {'video_title': 'Data Science Town Hall - State of Data Science',
#   'published': '2022-08-04T18:34:49Z',
#   'viewcount': '9961',
#   'comment_ct': '38',
#   'likecount': '376'},
#  {'video_title': 'The Programming Roadmap For Data Science',
#   'published': '2022-07-29T14:31:33Z',
#   'viewcount': '27335',
#   'comment_ct': '64',
#   'likecount': '1301'},
#  {'video_title': '5 Impactful Data Science Projects For Your Portfolio',
#   'published': '2022-06-27T13:00:10Z',
#   'viewcount': '77787',
#   'comment_ct': '90',
#   'likecount': '2928'},
#  {'video_title': 'Can AI Fix my Baseball Swing?',
#   'published': '2022-06-10T13:00:00Z',
#   'viewcount': '7616',
#   'comment_ct': '68',
#   'likecount': '341'},
#  {'video_title': 'Every Data Scientist... (funny!)',
#   'published': '2022-05-24T13:00:07Z',
#   'viewcount': '16738',
#   'comment_ct': '146',
#   'likecount': '853'},
#  {'video_title': 'State of Data Science (Town Hall) ft - Data Squad',
#   'published': '2022-05-07T22:43:20Z',
#   'viewcount': '15980',
#   'comment_ct': '65',
#   'likecount': '429'},
#  {'video_title': 'Data Science Portfolio Project From Scratch | Building a YouTube Data Dashboard with Streamlit',
#   'published': '2022-04-04T13:00:16Z',
#   'viewcount': '59580',
#   'comment_ct': '87',
#   'likecount': '1524'},
#  {'video_title': 'Why You Are NOT Landing Data Jobs ... Yet',
#   'published': '2022-03-25T13:00:38Z',
#   'viewcount': '21323',
#   'comment_ct': '113',
#   'likecount': '890'},
#  {'video_title': 'Data Scientists VS NFT Scam',
#   'published': '2022-03-03T13:00:36Z',
#   'viewcount': '4646',
#   'comment_ct': '49',
#   'likecount': '189'},
#  {'video_title': 'When a PM Joins the Data Team... (funny!) - Ft @LukeBarousse',
#   'published': '2022-02-21T13:00:03Z',
#   'viewcount': '11173',
#   'comment_ct': '144',
#   'likecount': '510'},
#  {'video_title': 'What Professional Data Scientists ACTUALLY Do',
#   'published': '2022-02-14T13:00:31Z',
#   'viewcount': '95961',
#   'comment_ct': '187',
#   'likecount': '3321'},
#  {'video_title': 'Can You Analyze My Data Better Than I Can?',
#   'published': '2022-01-31T13:00:11Z',
#   'viewcount': '7335',
#   'comment_ct': '62',
#   'likecount': '323'},
#  {'video_title': 'Giving Back to My Most Engaged Subscribers!',
#   'published': '2022-01-28T13:00:01Z',
#   'viewcount': '2331',
#   'comment_ct': '89',
#   'likecount': '119'},
#  {'video_title': 'How to Make $1 Billion Betting on Horse Racing with Machine Learning',
#   'published': '2022-01-24T13:00:09Z',
#   'viewcount': '33206',
#   'comment_ct': '131',
#   'likecount': '949'},
#  {'video_title': 'Should You Be Excited About Web 3? (As a Data Scientist)',
#   'published': '2022-01-17T13:00:00Z',
#   'viewcount': '8854',
#   'comment_ct': '83',
#   'likecount': '424'},
#  {'video_title': 'Should  @LukeBarousse Take This Data Analyst Job? (Funny) #Shorts',
#   'published': '2022-01-14T10:00:02Z',
#   'viewcount': '8526',
#   'comment_ct': '33',
#   'likecount': '253'},
#  {'video_title': 'The Only Data Science Explanation You Need',
#   'published': '2022-01-10T13:00:33Z',
#   'viewcount': '59853',
#   'comment_ct': '172',
#   'likecount': '2234'},
#  {'video_title': 'We Need to Talk About The LinkedIn Machine Learning Assessment.',
#   'published': '2022-01-03T13:00:35Z',
#   'viewcount': '14484',
#   'comment_ct': '144',
#   'likecount': '647'},
#  {'video_title': 'How I Would Learn Data Science in 2022 (If I Had to Start Over)',
#   'published': '2021-12-27T13:00:34Z',
#   'viewcount': '341824',
#   'comment_ct': '536',
#   'likecount': '15007'},
#  {'video_title': 'What the Heck is WSL 2? (My New Favorite Tool)',
#   'published': '2021-12-17T14:00:01Z',
#   'viewcount': '12611',
#   'comment_ct': '67',
#   'likecount': '430'},
#  {'video_title': 'How Statistics Saved the US SERIOUS $$$$ During WW2 #Shorts',
#   'published': '2021-12-10T13:00:22Z',
#   'viewcount': '8023',
#   'comment_ct': '25',
#   'likecount': '571'},
#  {'video_title': 'How Zillow Lost $500 MILLION With Machine Learning',
#   'published': '2021-12-03T13:00:14Z',
#   'viewcount': '24682',
#   'comment_ct': '146',
#   'likecount': '1185'},
#  {'video_title': 'Why Is Data Engineering So HOT Right Now?',
#   'published': '2021-11-26T13:00:22Z',
#   'viewcount': '29516',
#   'comment_ct': '141',
#   'likecount': '1102'},
#  {'video_title': 'Is Data Science Dying?',
#   'published': '2021-11-19T13:00:01Z',
#   'viewcount': '123686',
#   'comment_ct': '363',
#   'likecount': '3882'},
#  {'video_title': '7 Incredible Books That Transformed My Health and My Life',
#   'published': '2021-11-12T13:00:04Z',
#   'viewcount': '8141',
#   'comment_ct': '112',
#   'likecount': '386'},
#  {'video_title': 'Why EVERYONE Should Start a Podcast (Including YOU)',
#   'published': '2021-11-05T13:00:23Z',
#   'viewcount': '3629',
#   'comment_ct': '46',
#   'likecount': '202'},
#  {'video_title': 'Building a Burrito Dashboard - Data Science Project from Scratch with atoti',
#   'published': '2021-10-29T12:00:01Z',
#   'viewcount': '13487',
#   'comment_ct': '39',
#   'likecount': '301'},
#  {'video_title': 'ML Ops: What is it REALLY?',
#   'published': '2021-10-22T13:00:00Z',
#   'viewcount': '6987',
#   'comment_ct': '66',
#   'likecount': '285'},
#  {'video_title': 'Business Skills for Data Science: What are they REALLY?',
#   'published': '2021-10-18T13:00:27Z',
#   'viewcount': '6837',
#   'comment_ct': '50',
#   'likecount': '301'},
#  {'video_title': '#66DaysOfData Round 3 Live Event! (feat. @statquest)',
#   'published': '2021-10-12T16:05:54Z',
#   'viewcount': '2205',
#   'comment_ct': '5',
#   'likecount': '123'},
#  {'video_title': 'Roasting My First Data Science Project (Common Project Mistakes)',
#   'published': '2021-10-08T13:00:15Z',
#   'viewcount': '5941',
#   'comment_ct': '64',
#   'likecount': '283'},
#  {'video_title': "Is Data Visualization Important for Data Science? (A Data Scientist's Perspective)",
#   'published': '2021-08-20T13:00:20Z',
#   'viewcount': '12861',
#   'comment_ct': '112',
#   'likecount': '530'},
#  {'video_title': 'Project Presentation - Expectations vs. Reality (funny) #shorts',
#   'published': '2021-08-07T14:00:11Z',
#   'viewcount': '10225',
#   'comment_ct': '32',
#   'likecount': '434'},
#  {'video_title': 'Data Science Project - Expectations vs Reality (funny) #shorts',
#   'published': '2021-08-06T23:04:24Z',
#   'viewcount': '41367',
#   'comment_ct': '32',
#   'likecount': '1604'},
#  {'video_title': 'How I Learned to Learn.',
#   'published': '2021-07-31T13:00:26Z',
#   'viewcount': '50850',
#   'comment_ct': '209',
#   'likecount': '2367'},
#  {'video_title': 'Is Spotify Shuffle Really Random? #Shorts',
#   'published': '2021-07-21T13:00:21Z',
#   'viewcount': '10735',
#   'comment_ct': '50',
#   'likecount': '588'},
#  {'video_title': 'I Eat a Papaya Live on Stream (Plus Q&A for 150K Subs!)',
#   'published': '2021-07-16T21:30:26Z',
#   'viewcount': '2410',
#   'comment_ct': '30',
#   'likecount': '93'},
#  {'video_title': 'Why are APIs Important for Data Science?',
#   'published': '2021-07-09T13:00:32Z',
#   'viewcount': '9983',
#   'comment_ct': '95',
#   'likecount': '455'},
#  {'video_title': 'Is Your Phone REALLY Listening to You?',
#   'published': '2021-07-03T13:00:31Z',
#   'viewcount': '5188',
#   'comment_ct': '116',
#   'likecount': '279'},
#  {'video_title': 'Kaggle vs Github - Which is Best for Your Data Science Portfolio?',
#   'published': '2021-06-25T13:00:12Z',
#   'viewcount': '15516',
#   'comment_ct': '123',
#   'likecount': '611'},
#  {'video_title': '#66DaysOfData - 3 Reasons to Start!',
#   'published': '2021-06-18T13:00:32Z',
#   'viewcount': '4098',
#   'comment_ct': '41',
#   'likecount': '224'},
#  {'video_title': '#66DaysOfData - What is it? #shorts',
#   'published': '2021-06-11T12:48:29Z',
#   'viewcount': '9221',
#   'comment_ct': '54',
#   'likecount': '395'},
#  {'video_title': 'A Quick Data Science Project Tip! #SHORTS',
#   'published': '2021-06-03T13:00:06Z',
#   'viewcount': '16684',
#   'comment_ct': '89',
#   'likecount': '1020'},
#  {'video_title': 'Discouraged with Data Science? - Watch THIS video.',
#   'published': '2021-05-28T13:00:02Z',
#   'viewcount': '7467',
#   'comment_ct': '195',
#   'likecount': '393'},
#  {'video_title': 'How Data Science Projects Pay Off',
#   'published': '2021-05-22T13:30:03Z',
#   'viewcount': '10736',
#   'comment_ct': '146',
#   'likecount': '601'},
#  {'video_title': 'How I Use Data to Optimize My Life | What I Collect & How I Analyze It',
#   'published': '2021-05-14T13:00:03Z',
#   'viewcount': '10622',
#   'comment_ct': '134',
#   'likecount': '491'},
#  {'video_title': 'What is a lambda function (python)? #shorts',
#   'published': '2021-05-13T00:38:55Z',
#   'viewcount': '15453',
#   'comment_ct': '49',
#   'likecount': '949'},
#  {'video_title': 'Why Kaggle Should Be Your Favorite Data Science Resource #shorts',
#   'published': '2021-05-07T13:00:30Z',
#   'viewcount': '30556',
#   'comment_ct': '64',
#   'likecount': '1619'},
#  {'video_title': 'What is Pandas? (Data & Data Science) #shorts',
#   'published': '2021-04-30T13:00:07Z',
#   'viewcount': '23843',
#   'comment_ct': '87',
#   'likecount': '1226'},
#  {'video_title': 'The 7 Biggest Data Science  Beginner Mistakes',
#   'published': '2021-04-23T13:00:14Z',
#   'viewcount': '77228',
#   'comment_ct': '284',
#   'likecount': '3433'},
#  {'video_title': 'Data Scientist Reacts: REAL Data Science Job Application Data',
#   'published': '2021-04-16T13:00:00Z',
#   'viewcount': '23503',
#   'comment_ct': '85',
#   'likecount': '694'},
#  {'video_title': "Why You Probably Won't Become a Data Scientist",
#   'published': '2021-04-09T13:00:31Z',
#   'viewcount': '138374',
#   'comment_ct': '481',
#   'likecount': '4042'},
#  {'video_title': 'How to Go From Data Analyst to Data Scientist',
#   'published': '2021-04-02T13:00:14Z',
#   'viewcount': '53857',
#   'comment_ct': '177',
#   'likecount': '1543'},
#  {'video_title': 'Why I Have 2 Offices for Data Science & Content Creation',
#   'published': '2021-03-26T13:00:03Z',
#   'viewcount': '3982',
#   'comment_ct': '92',
#   'likecount': '138'},
#  {'video_title': 'MARCH MADNESS - Will My Machine Learning Model Beat Your Bracket?',
#   'published': '2021-03-19T13:00:32Z',
#   'viewcount': '18197',
#   'comment_ct': '108',
#   'likecount': '350'},
#  {'video_title': 'My Regrets as a Data Science Student',
#   'published': '2021-03-12T13:00:27Z',
#   'viewcount': '23943',
#   'comment_ct': '112',
#   'likecount': '882'},
#  {'video_title': 'My Daily Battle With Time - Will I Win? [Vlog]',
#   'published': '2021-03-08T13:00:06Z',
#   'viewcount': '3833',
#   'comment_ct': '83',
#   'likecount': '196'},
#  {'video_title': 'What is the Future of my Comment Leaderboard Project?',
#   'published': '2021-02-26T14:00:15Z',
#   'viewcount': '5573',
#   'comment_ct': '81',
#   'likecount': '201'},
#  {'video_title': 'How to Build a Website  - Building my ULTIMATE Portfolio Website',
#   'published': '2021-02-19T13:00:14Z',
#   'viewcount': '6766',
#   'comment_ct': '51',
#   'likecount': '174'},
#  {'video_title': 'Why I Quit Data Science',
#   'published': '2021-02-12T13:00:19Z',
#   'viewcount': '104806',
#   'comment_ct': '347',
#   'likecount': '2350'},
#  {'video_title': '🌶 Hot Topics in Tech: Data Science Explained #SHORTS',
#   'published': '2021-01-29T13:00:06Z',
#   'viewcount': '10711',
#   'comment_ct': '116',
#   'likecount': '556'},
#  {'video_title': 'How I Balance Data Science and Content Creation (7 Secrets)',
#   'published': '2021-01-23T14:00:30Z',
#   'viewcount': '6998',
#   'comment_ct': '126',
#   'likecount': '294'},
#  {'video_title': 'Kaggle Project From Scratch - Part 3 (Advanced Graphs & Gender Imbalance Analysis)',
#   'published': '2021-01-16T14:00:10Z',
#   'viewcount': '9764',
#   'comment_ct': '52',
#   'likecount': '301'},
#  {'video_title': 'Kaggle Project From Scratch - Part 2 (Exploratory Data Analysis)',
#   'published': '2021-01-08T13:00:16Z',
#   'viewcount': '22769',
#   'comment_ct': '134',
#   'likecount': '697'},
#  {'video_title': 'Kaggle Project From Scratch - Part 1 (Data Science Profession Survey)',
#   'published': '2021-01-02T14:00:26Z',
#   'viewcount': '37934',
#   'comment_ct': '147',
#   'likecount': '1139'},
#  {'video_title': 'What is the #66DaysOfData?',
#   'published': '2020-12-26T14:00:31Z',
#   'viewcount': '70020',
#   'comment_ct': '202',
#   'likecount': '2325'},
#  {'video_title': 'How I Would Learn Data Science in 2021 (What Has Changed?)',
#   'published': '2020-12-19T14:00:01Z',
#   'viewcount': '131497',
#   'comment_ct': '488',
#   'likecount': '5970'},
#  {'video_title': 'Unboxing the Ultimate Z by HP Data Science Package (FIRST EVER HP Workstation w/ Data Science Stack)',
#   'published': '2020-12-10T13:00:09Z',
#   'viewcount': '10935',
#   'comment_ct': '133',
#   'likecount': '398'},
#  {'video_title': 'I Built the FIRST EVER YouTube Subscriber LEADERBOARD',
#   'published': '2020-12-07T14:00:11Z',
#   'viewcount': '23526',
#   'comment_ct': '326',
#   'likecount': '727'},
#  {'video_title': '7 Things to Look For in a Masters For Data Science (feat. @TinaHuang1)',
#   'published': '2020-11-20T13:00:26Z',
#   'viewcount': '28078',
#   'comment_ct': '160',
#   'likecount': '857'},
#  {'video_title': '6 Lessons from #66DaysOfData',
#   'published': '2020-11-13T13:00:02Z',
#   'viewcount': '6733',
#   'comment_ct': '93',
#   'likecount': '340'},
#  {'video_title': '100K Channel Update + AMA Stream!',
#   'published': '2020-11-12T17:34:26Z',
#   'viewcount': '2319',
#   'comment_ct': '22',
#   'likecount': '127'},
#  {'video_title': 'Find a Data Science Project With These 3 Techniques',
#   'published': '2020-11-06T13:00:13Z',
#   'viewcount': '16816',
#   'comment_ct': '106',
#   'likecount': '727'},
#  {'video_title': 'How I Chose My Masters Degree for Breaking into Data Science',
#   'published': '2020-10-30T14:00:07Z',
#   'viewcount': '27306',
#   'comment_ct': '155',
#   'likecount': '678'},
#  {'video_title': 'git for Data Science Made Simple... (Hopefully)',
#   'published': '2020-10-23T15:00:10Z',
#   'viewcount': '19923',
#   'comment_ct': '92',
#   'likecount': '871'},
#  {'video_title': 'The PODCAST you might have asked for?',
#   'published': '2020-10-19T15:00:11Z',
#   'viewcount': '2118',
#   'comment_ct': '44',
#   'likecount': '94'},
#  {'video_title': 'Dealing with Doubt in Data Science (My Impostor Syndrome Story)',
#   'published': '2020-10-16T15:00:18Z',
#   'viewcount': '6747',
#   'comment_ct': '113',
#   'likecount': '448'},
#  {'video_title': 'Advice from a Data Analytics CEO (@How to Get an Analytics Job) - KNN EP. 17',
#   'published': '2020-10-14T15:00:11Z',
#   'viewcount': '14292',
#   'comment_ct': '47',
#   'likecount': '417'},
#  {'video_title': 'Data Science Resume Round-Up With @Tina Huang  | Episode 3',
#   'published': '2020-10-12T15:00:00Z',
#   'viewcount': '6835',
#   'comment_ct': '62',
#   'likecount': '143'},
#  {'video_title': '5 Unusual Data Science Projects that Will Land You a Job',
#   'published': '2020-10-09T15:00:09Z',
#   'viewcount': '11750',
#   'comment_ct': '83',
#   'likecount': '567'},
#  {'video_title': 'Sh*t Data Scientists Say (Parody)',
#   'published': '2020-10-05T15:00:08Z',
#   'viewcount': '9531',
#   'comment_ct': '144',
#   'likecount': '579'},
#  {'video_title': '5 Proven Strategies to Break into a Data Science Job',
#   'published': '2020-10-02T15:00:08Z',
#   'viewcount': '8620',
#   'comment_ct': '93',
#   'likecount': '366'},
#  {'video_title': 'Why Data-Viz is so Darn Important (@Story by Data | Kate Strachnyi) - KNN EP. 16',
#   'published': '2020-09-30T15:00:09Z',
#   'viewcount': '7072',
#   'comment_ct': '61',
#   'likecount': '287'},
#  {'video_title': 'Data Science Resume Round-Up With @TinaHuang1  - Episode 1',
#   'published': '2020-09-28T15:00:04Z',
#   'viewcount': '11719',
#   'comment_ct': '69',
#   'likecount': '292'},
#  {'video_title': '5 Essential Data Science Projects for Your Portfolio',
#   'published': '2020-09-26T15:00:06Z',
#   'viewcount': '73061',
#   'comment_ct': '206',
#   'likecount': '3106'},
#  {'video_title': 'His Startup Will Land You a Data Science Job (Jeremie Harris) - KNN EP. 15',
#   'published': '2020-09-23T15:00:02Z',
#   'viewcount': '5185',
#   'comment_ct': '64',
#   'likecount': '198'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 21(The Cleanest Portfolio)',
#   'published': '2020-09-21T15:00:03Z',
#   'viewcount': '12231',
#   'comment_ct': '58',
#   'likecount': '470'},
#  {'video_title': 'Hedge Funds, Startups, and Data Science Oh my! (@DataLeap) - KNN EP. 14',
#   'published': '2020-09-18T16:00:10Z',
#   'viewcount': '7452',
#   'comment_ct': '34',
#   'likecount': '253'},
#  {'video_title': 'Land a Data Science Job in a Different Country (Vijay Pravin Maharajan) - KNN EP. 13',
#   'published': '2020-09-16T15:00:24Z',
#   'viewcount': '5109',
#   'comment_ct': '56',
#   'likecount': '194'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 20 (Bootcamp Capstone)',
#   'published': '2020-09-14T15:00:00Z',
#   'viewcount': '4283',
#   'comment_ct': '35',
#   'likecount': '157'},
#  {'video_title': 'The 5 Pillars of Success I Live By',
#   'published': '2020-09-11T15:00:11Z',
#   'viewcount': '10139',
#   'comment_ct': '152',
#   'likecount': '873'},
#  {'video_title': 'Fast Cars to Faster Data (Alex Castrounis) - KNN EP. 12',
#   'published': '2020-09-09T15:00:12Z',
#   'viewcount': '1891',
#   'comment_ct': '25',
#   'likecount': '78'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 19 (One Big Improvement)',
#   'published': '2020-09-07T15:00:30Z',
#   'viewcount': '4039',
#   'comment_ct': '43',
#   'likecount': '163'},
#  {'video_title': "How I Learn Data Science Through Studying Other People's Code | #66DaysOfData",
#   'published': '2020-09-04T15:00:00Z',
#   'viewcount': '11822',
#   'comment_ct': '144',
#   'likecount': '737'},
#  {'video_title': 'How She Dominated the FAANG Data Science Interview  (@TinaHuang1 ) - KNN EP. 11',
#   'published': '2020-09-02T15:00:13Z',
#   'viewcount': '17968',
#   'comment_ct': '89',
#   'likecount': '572'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 18 (Job-Worthy GitHub)',
#   'published': '2020-08-31T15:00:15Z',
#   'viewcount': '17996',
#   'comment_ct': '93',
#   'likecount': '794'},
#  {'video_title': "Why I'm Starting Data Science Over Again.",
#   'published': '2020-08-29T15:30:10Z',
#   'viewcount': '50754',
#   'comment_ct': '450',
#   'likecount': '2603'},
#  {'video_title': 'Inside the Mind of the Ultimate Kaggle Grandmaster (@Abhishek Thakur ) - KNN EP. 10',
#   'published': '2020-08-26T15:00:03Z',
#   'viewcount': '15174',
#   'comment_ct': '77',
#   'likecount': '632'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 17 (Best Portfolio Website Yet?)',
#   'published': '2020-08-24T15:00:31Z',
#   'viewcount': '12941',
#   'comment_ct': '55',
#   'likecount': '462'},
#  {'video_title': "Don't Buy My Course..",
#   'published': '2020-08-21T16:00:32Z',
#   'viewcount': '7340',
#   'comment_ct': '146',
#   'likecount': '359'},
#  {'video_title': 'How a Subscriber Landed a Data Analyst Job in Less Than a Year (Ray Ojel) - KNN EP. 09',
#   'published': '2020-08-19T15:00:11Z',
#   'viewcount': '29112',
#   'comment_ct': '166',
#   'likecount': '1115'},
#  {'video_title': 'Reviewing Your Projects - Episode 16 (Project Review for Beginners)',
#   'published': '2020-08-17T15:00:07Z',
#   'viewcount': '3241',
#   'comment_ct': '40',
#   'likecount': '128'},
#  {'video_title': 'Data Scientist Dismantles the YouTube Algorithm.',
#   'published': '2020-08-14T15:00:31Z',
#   'viewcount': '6322',
#   'comment_ct': '108',
#   'likecount': '539'},
#  {'video_title': 'Sports Analytics & Streaming Data Science on Twitch (Nick Wan) - KNN EP. 08',
#   'published': '2020-08-12T15:30:26Z',
#   'viewcount': '5002',
#   'comment_ct': '39',
#   'likecount': '183'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 15 (Quant Finance)',
#   'published': '2020-08-10T15:00:08Z',
#   'viewcount': '12410',
#   'comment_ct': '53',
#   'likecount': '391'},
#  {'video_title': 'The Plagiarism Problem in Data Science',
#   'published': '2020-08-07T15:00:16Z',
#   'viewcount': '13075',
#   'comment_ct': '145',
#   'likecount': '629'},
#  {'video_title': 'Interview with the Director of AI Research @ NVIDIA (Anima Anandkumar) - KNN EP. 07',
#   'published': '2020-08-05T15:00:09Z',
#   'viewcount': '14427',
#   'comment_ct': '89',
#   'likecount': '602'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 14 [Deep Learning Focus]',
#   'published': '2020-08-03T15:00:08Z',
#   'viewcount': '4916',
#   'comment_ct': '56',
#   'likecount': '187'},
#  {'video_title': 'My First Data Science Contracting Side-Gig (How I Did It)',
#   'published': '2020-07-31T14:30:01Z',
#   'viewcount': '11428',
#   'comment_ct': '90',
#   'likecount': '582'},
#  {'video_title': 'Do You Have a Data Science Mentor? (@Danny Ma) - KNN EP. 06',
#   'published': '2020-07-30T01:00:10Z',
#   'viewcount': '2321',
#   'comment_ct': '34',
#   'likecount': '116'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 13 (BONUS LinkedIn Review)',
#   'published': '2020-07-27T15:00:30Z',
#   'viewcount': '5620',
#   'comment_ct': '112',
#   'likecount': '251'},
#  {'video_title': 'Building a Deep Learning BEAST (NVIDIA TITAN RTX + RYZEN 3900X)',
#   'published': '2020-07-24T15:00:11Z',
#   'viewcount': '8218',
#   'comment_ct': '199',
#   'likecount': '246'},
#  {'video_title': 'Is it Important to Share Your Data Science Work? (Ft. Eric Weber)',
#   'published': '2020-07-22T15:00:05Z',
#   'viewcount': '1858',
#   'comment_ct': '27',
#   'likecount': '98'},
#  {'video_title': 'Reviewing Your Data Science Resumes - Episode 12 (3 Different Resumes!)',
#   'published': '2020-07-20T15:00:08Z',
#   'viewcount': '29152',
#   'comment_ct': '90',
#   'likecount': '565'},
#  {'video_title': 'Beginner Kaggle Data Science Project Walk-Through (Titanic)',
#   'published': '2020-07-17T16:00:05Z',
#   'viewcount': '332379',
#   'comment_ct': '425',
#   'likecount': '7355'},
#  {'video_title': 'Uber Driver to Machine Learning Engineer in 9 Months! (@Daniel Bourke) - KNN EP. 05',
#   'published': '2020-07-16T02:00:09Z',
#   'viewcount': '30310',
#   'comment_ct': '121',
#   'likecount': '1125'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 11(GITHUB CLEANING)',
#   'published': '2020-07-13T16:00:01Z',
#   'viewcount': '3637',
#   'comment_ct': '50',
#   'likecount': '135'},
#  {'video_title': 'The Best Computer for Data Science Beginners',
#   'published': '2020-07-10T16:00:09Z',
#   'viewcount': '38290',
#   'comment_ct': '158',
#   'likecount': '854'},
#  {'video_title': 'Should You Major in Data Science? (Jaemin Lee) - KNN EP. 04',
#   'published': '2020-07-08T21:00:09Z',
#   'viewcount': '6167',
#   'comment_ct': '82',
#   'likecount': '231'},
#  {'video_title': 'Critiquing MY OWN Data Science Resume',
#   'published': '2020-07-06T16:00:30Z',
#   'viewcount': '12665',
#   'comment_ct': '88',
#   'likecount': '397'},
#  {'video_title': 'Where to Start Learning Data Science',
#   'published': '2020-07-03T16:00:04Z',
#   'viewcount': '18803',
#   'comment_ct': '127',
#   'likecount': '784'},
#  {'video_title': 'Data Science Productivity, Motivation, and Organization (ft. Data Professor & Codebasics)',
#   'published': '2020-07-01T15:00:12Z',
#   'viewcount': '4155',
#   'comment_ct': '37',
#   'likecount': '197'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 10 (Leveraging Your Data)',
#   'published': '2020-06-29T15:00:08Z',
#   'viewcount': '4596',
#   'comment_ct': '52',
#   'likecount': '176'},
#  {'video_title': 'How to Get a Data Science Job at FAANG (@Data Science Jay) - KNN EP. 03',
#   'published': '2020-06-26T15:00:10Z',
#   'viewcount': '16437',
#   'comment_ct': '79',
#   'likecount': '550'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 9 (Professional Violinist)',
#   'published': '2020-06-22T13:00:03Z',
#   'viewcount': '2415',
#   'comment_ct': '40',
#   'likecount': '82'},
#  {'video_title': 'Ken Jee Q & A Live Stream (50,000 Sub Special!)',
#   'published': '2020-06-20T02:09:18Z',
#   'viewcount': '2386',
#   'comment_ct': '49',
#   'likecount': '139'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 8 (College Student Help)',
#   'published': '2020-06-15T13:00:12Z',
#   'viewcount': '4371',
#   'comment_ct': '46',
#   'likecount': '169'},
#  {'video_title': "Why You're Struggling to Learn Data Science",
#   'published': '2020-06-12T13:00:17Z',
#   'viewcount': '15255',
#   'comment_ct': '159',
#   'likecount': '1010'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 7 (Incredible Portfolio Website)',
#   'published': '2020-06-08T13:00:21Z',
#   'viewcount': '11787',
#   'comment_ct': '70',
#   'likecount': '359'},
#  {'video_title': 'The State of Data Science with Krish Naik & The Data Professor [Panel Discussion]',
#   'published': '2020-06-05T13:00:26Z',
#   'viewcount': '23913',
#   'comment_ct': '146',
#   'likecount': '687'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 6 (Only 3 months of coding experience)',
#   'published': '2020-06-01T13:00:32Z',
#   'viewcount': '5706',
#   'comment_ct': '53',
#   'likecount': '154'},
#  {'video_title': 'How to Build a Data Science Portfolio Website with Hugo & Github Pages [feat. Data Professor]',
#   'published': '2020-05-29T13:00:21Z',
#   'viewcount': '72817',
#   'comment_ct': '269',
#   'likecount': '2199'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 5 (Very Detailed Project)',
#   'published': '2020-05-25T13:00:13Z',
#   'viewcount': '20981',
#   'comment_ct': '81',
#   'likecount': '489'},
#  {'video_title': 'Different Data Science Roles Explained (by a Data Scientist)',
#   'published': '2020-05-22T13:01:09Z',
#   'viewcount': '55468',
#   'comment_ct': '178',
#   'likecount': '1973'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 4 (Resume & Github)',
#   'published': '2020-05-18T13:00:22Z',
#   'viewcount': '11251',
#   'comment_ct': '53',
#   'likecount': '178'},
#  {'video_title': 'How to Make A Data Science Portfolio Website with Github Pages',
#   'published': '2020-05-15T13:30:00Z',
#   'viewcount': '130441',
#   'comment_ct': '193',
#   'likecount': '4440'},
#  {'video_title': '10000 Subscriber and 100th Video Special (Data Science)',
#   'published': '2020-05-13T13:00:17Z',
#   'viewcount': '3100',
#   'comment_ct': '115',
#   'likecount': '147'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 3 (Student Portfolio)',
#   'published': '2020-05-11T13:00:33Z',
#   'viewcount': '4522',
#   'comment_ct': '74',
#   'likecount': '153'},
#  {'video_title': 'How I Would Learn Data Science (If I Had to Start Over)',
#   'published': '2020-05-08T13:00:03Z',
#   'viewcount': '1395184',
#   'comment_ct': '1994',
#   'likecount': '49025'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 2 (Resume and Portfolio)',
#   'published': '2020-05-04T13:00:12Z',
#   'viewcount': '5546',
#   'comment_ct': '42',
#   'likecount': '196'},
#  {'video_title': 'What You Need to Know for a Data Science Internship',
#   'published': '2020-05-01T13:00:10Z',
#   'viewcount': '22163',
#   'comment_ct': '60',
#   'likecount': '1208'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 1 (Exploratory Analysis)',
#   'published': '2020-04-27T13:00:10Z',
#   'viewcount': '8362',
#   'comment_ct': '54',
#   'likecount': '350'},
#  {'video_title': "What It's Like to be a Socially Distanced Data Scientist (A Day in the Life)",
#   'published': '2020-04-24T13:00:32Z',
#   'viewcount': '14983',
#   'comment_ct': '103',
#   'likecount': '458'},
#  {'video_title': 'Data Science in Sports - Talk for Northwestern (Kellogg) MBA Students',
#   'published': '2020-04-22T13:00:30Z',
#   'viewcount': '3132',
#   'comment_ct': '24',
#   'likecount': '85'},
#  {'video_title': '5 Tips for Crushing the Work From Home Life',
#   'published': '2020-04-20T13:00:04Z',
#   'viewcount': '5424',
#   'comment_ct': '38',
#   'likecount': '203'},
#  {'video_title': 'Data Science Project from Scratch - Part 7 (Documenting Your Work)',
#   'published': '2020-04-17T13:00:04Z',
#   'viewcount': '21571',
#   'comment_ct': '129',
#   'likecount': '740'},
#  {'video_title': 'Data Science Project from Scratch -  Part 6 (Putting the Model into Production)',
#   'published': '2020-04-15T13:00:32Z',
#   'viewcount': '29535',
#   'comment_ct': '98',
#   'likecount': '734'},
#  {'video_title': 'Data Science Project from Scratch  - Part 5 (Model Building)',
#   'published': '2020-04-13T13:00:03Z',
#   'viewcount': '44224',
#   'comment_ct': '154',
#   'likecount': '907'},
#  {'video_title': 'Data Science Project from Scratch - Part 4 (Exploratory Data Analysis)',
#   'published': '2020-04-10T13:00:15Z',
#   'viewcount': '72593',
#   'comment_ct': '213',
#   'likecount': '1890'},
#  {'video_title': 'Data Science Project from Scratch - Part 3 (Data Cleaning)',
#   'published': '2020-04-08T13:00:19Z',
#   'viewcount': '80928',
#   'comment_ct': '277',
#   'likecount': '1759'},
#  {'video_title': 'Data Science Project from Scratch - Part 2 (Data Collection)',
#   'published': '2020-04-06T13:00:07Z',
#   'viewcount': '128746',
#   'comment_ct': '620',
#   'likecount': '3499'},
#  {'video_title': 'Data Science Project from Scratch - Part 1 (Project Planning)',
#   'published': '2020-04-03T13:00:12Z',
#   'viewcount': '197822',
#   'comment_ct': '175',
#   'likecount': '5047'},
#  {'video_title': 'When Data Science Goes Wrong',
#   'published': '2020-03-30T13:00:06Z',
#   'viewcount': '1807',
#   'comment_ct': '32',
#   'likecount': '106'},
#  {'video_title': 'How to ULTRALEARN Data Science',
#   'published': '2020-03-27T13:00:02Z',
#   'viewcount': '61899',
#   'comment_ct': '169',
#   'likecount': '3822'},
#  {'video_title': 'Why Right NOW is a Great Time to Learn Data Science',
#   'published': '2020-03-23T13:00:30Z',
#   'viewcount': '4430',
#   'comment_ct': '50',
#   'likecount': '268'},
#  {'video_title': 'Data Science Project Example Start to Finish (Deep Learning Image Classifier)',
#   'published': '2020-03-20T13:00:22Z',
#   'viewcount': '13022',
#   'comment_ct': '45',
#   'likecount': '468'},
#  {'video_title': "The Secret Data Scientists Don't Want You to Know",
#   'published': '2020-03-16T13:00:23Z',
#   'viewcount': '10760',
#   'comment_ct': '103',
#   'likecount': '1139'},
#  {'video_title': 'The 5 Stages of Learning Data Science',
#   'published': '2020-03-13T13:00:26Z',
#   'viewcount': '17509',
#   'comment_ct': '78',
#   'likecount': '1296'},
#  {'video_title': 'Can You Learn Data Science Without a Computer?',
#   'published': '2020-03-11T13:00:03Z',
#   'viewcount': '1707',
#   'comment_ct': '14',
#   'likecount': '117'},
#  {'video_title': 'The Best Free Data Science Courses Nobody is Talking About',
#   'published': '2020-03-09T13:00:04Z',
#   'viewcount': '346858',
#   'comment_ct': '620',
#   'likecount': '21220'},
#  {'video_title': 'The Data Science Projects that Got Me a Job',
#   'published': '2020-03-06T14:00:11Z',
#   'viewcount': '40981',
#   'comment_ct': '41',
#   'likecount': '1399'},
#  {'video_title': 'How to Integrate Data Science into Your Business',
#   'published': '2020-03-02T14:00:01Z',
#   'viewcount': '3378',
#   'comment_ct': '18',
#   'likecount': '129'},
#  {'video_title': 'The Problem with Data Science',
#   'published': '2020-02-28T14:00:07Z',
#   'viewcount': '3792',
#   'comment_ct': '19',
#   'likecount': '154'},
#  {'video_title': 'How Much Did Cheating Help the Astros Win? (What the Numbers Say)',
#   'published': '2020-02-24T14:00:00Z',
#   'viewcount': '1170',
#   'comment_ct': '16',
#   'likecount': '46'},
#  {'video_title': 'How to Set Up Your Data Science Environment (Anaconda Beginner)',
#   'published': '2020-02-21T14:00:02Z',
#   'viewcount': '128747',
#   'comment_ct': '97',
#   'likecount': '2464'},
#  {'video_title': '3 Proven Data Science Projects for Beginners (Kaggle)',
#   'published': '2020-02-17T14:00:04Z',
#   'viewcount': '327208',
#   'comment_ct': '525',
#   'likecount': '17782'},
#  {'video_title': 'Data Science Advice for College Students',
#   'published': '2020-02-14T17:22:37Z',
#   'viewcount': '68941',
#   'comment_ct': '197',
#   'likecount': '1964'},
#  {'video_title': 'Avoid These Data Science Resume Mistakes!',
#   'published': '2020-02-10T15:52:59Z',
#   'viewcount': '28428',
#   'comment_ct': '62',
#   'likecount': '1243'},
#  {'video_title': 'Data Science Explained with ... Cooking?',
#   'published': '2020-02-07T15:56:55Z',
#   'viewcount': '5304',
#   'comment_ct': '48',
#   'likecount': '315'},
#  {'video_title': 'The 4 Types of Sports Analytics Projects',
#   'published': '2020-02-03T16:35:19Z',
#   'viewcount': '31383',
#   'comment_ct': '62',
#   'likecount': '1023'},
#  {'video_title': 'Data Science in Golf: PGA Merchandise Show 2020',
#   'published': '2020-01-31T18:50:23Z',
#   'viewcount': '587',
#   'comment_ct': '13',
#   'likecount': '18'},
#  {'video_title': 'How I Learned Data Science',
#   'published': '2020-01-27T14:41:18Z',
#   'viewcount': '94122',
#   'comment_ct': '210',
#   'likecount': '2695'},
#  {'video_title': 'What is Sports Analytics Really?',
#   'published': '2020-01-20T14:00:00Z',
#   'viewcount': '21344',
#   'comment_ct': '73',
#   'likecount': '614'},
#  {'video_title': 'Data Science Certificate vs Bootcamp vs Masters Degree',
#   'published': '2020-01-18T01:03:08Z',
#   'viewcount': '111248',
#   'comment_ct': '582',
#   'likecount': '3137'},
#  {'video_title': 'How To Learn Programming for Data Science [3 Steps]',
#   'published': '2020-01-13T16:48:44Z',
#   'viewcount': '30092',
#   'comment_ct': '96',
#   'likecount': '1979'},
#  {'video_title': 'Data Science Fundamentals: SQL Queries',
#   'published': '2020-01-10T19:15:01Z',
#   'viewcount': '6505',
#   'comment_ct': '35',
#   'likecount': '214'},
#  {'video_title': 'Questions You Should Ask Your Data Science Interviewers',
#   'published': '2020-01-06T14:00:04Z',
#   'viewcount': '3147',
#   'comment_ct': '14',
#   'likecount': '152'},
#  {'video_title': 'The 9 Books That Changed My Perspective in 2019',
#   'published': '2020-01-03T14:45:28Z',
#   'viewcount': '3392',
#   'comment_ct': '25',
#   'likecount': '180'},
#  {'video_title': 'The Data Science Interview: What to Expect',
#   'published': '2019-12-30T14:00:01Z',
#   'viewcount': '8567',
#   'comment_ct': '32',
#   'likecount': '380'},
#  {'video_title': '5 Data Science Resolutions for 2020',
#   'published': '2019-12-27T14:00:07Z',
#   'viewcount': '475',
#   'comment_ct': '12',
#   'likecount': '25'},
#  {'video_title': 'How to Scrape NBA Data Using the nba_api Python Module',
#   'published': '2019-12-23T12:59:47Z',
#   'viewcount': '16837',
#   'comment_ct': '93',
#   'likecount': '595'},
#  {'video_title': 'Collision Course: Sports Betting + Data Science',
#   'published': '2019-12-20T14:00:02Z',
#   'viewcount': '18114',
#   'comment_ct': '27',
#   'likecount': '505'},
#  {'video_title': '3 Reasons You Should NOT Become a Data Scientist',
#   'published': '2019-12-16T18:46:58Z',
#   'viewcount': '100961',
#   'comment_ct': '204',
#   'likecount': '2932'},
#  {'video_title': '5 Sports Analytics Books to Get You Started',
#   'published': '2019-12-13T14:00:01Z',
#   'viewcount': '10950',
#   'comment_ct': '59',
#   'likecount': '415'},
#  {'video_title': 'Math Needed for Mastering Data Science',
#   'published': '2019-12-09T14:00:15Z',
#   'viewcount': '57048',
#   'comment_ct': '222',
#   'likecount': '2884'},
#  {'video_title': 'The 5 Stages of Data Science Adoption',
#   'published': '2019-12-06T14:00:04Z',
#   'viewcount': '1330',
#   'comment_ct': '17',
#   'likecount': '69'},
#  {'video_title': 'How YOU Can Land a Sports Analytics Job',
#   'published': '2019-12-02T14:00:05Z',
#   'viewcount': '69824',
#   'comment_ct': '231',
#   'likecount': '3086'},
#  {'video_title': 'Data Science Fundamentals: Linear Regression',
#   'published': '2019-11-29T14:00:02Z',
#   'viewcount': '6391',
#   'comment_ct': '42',
#   'likecount': '172'},
#  {'video_title': 'Golf: Would You Rather Be the LONGEST or STRAIGHTEST Driver on the PGA Tour?',
#   'published': '2019-11-25T14:00:11Z',
#   'viewcount': '1106',
#   'comment_ct': '12',
#   'likecount': '53'},
#  {'video_title': 'Sports Analytics 101: The Pythagorean Theorem of Sports',
#   'published': '2019-11-22T14:00:06Z',
#   'viewcount': '6155',
#   'comment_ct': '26',
#   'likecount': '272'},
#  {'video_title': '9 Ways You Can Make Extra Income as a Data Scientist',
#   'published': '2019-11-18T15:34:12Z',
#   'viewcount': '46256',
#   'comment_ct': '80',
#   'likecount': '1760'},
#  {'video_title': 'Applying Data Science To My YouTube Data: My Surprising Findings',
#   'published': '2019-11-11T21:12:11Z',
#   'viewcount': '5940',
#   'comment_ct': '31',
#   'likecount': '137'},
#  {'video_title': 'Why Selling Is An Important Data Science Skill',
#   'published': '2019-11-04T14:57:00Z',
#   'viewcount': '1631',
#   'comment_ct': '13',
#   'likecount': '81'},
#  {'video_title': 'By The Numbers: Where Should The NBA Put a 4 Point Line?',
#   'published': '2019-10-21T16:38:58Z',
#   'viewcount': '2856',
#   'comment_ct': '18',
#   'likecount': '73'},
#  {'video_title': 'Why is Balance Important in Data Science?',
#   'published': '2019-10-16T17:40:34Z',
#   'viewcount': '704',
#   'comment_ct': '13',
#   'likecount': '32'},
#  {'video_title': 'How to Stay Productive & Motivated When Learning Data Science',
#   'published': '2019-09-29T00:29:59Z',
#   'viewcount': '11925',
#   'comment_ct': '54',
#   'likecount': '585'},
#  {'video_title': 'How Far Should the NBA 3-Point Line Actually Be?',
#   'published': '2019-09-21T23:04:57Z',
#   'viewcount': '3886',
#   'comment_ct': '34',
#   'likecount': '116'},
#  {'video_title': '6 Habits of Successful Data Scientists',
#   'published': '2019-09-13T04:40:51Z',
#   'viewcount': '2233',
#   'comment_ct': '17',
#   'likecount': '95'},
#  {'video_title': 'How To Build A Word Cloud From Scraped Data (Python)',
#   'published': '2019-09-04T01:32:06Z',
#   'viewcount': '4672',
#   'comment_ct': '9',
#   'likecount': '102'},
#  {'video_title': "Thank You For The Support | What's Next | Ken Jee | Data Science",
#   'published': '2019-08-26T12:42:32Z',
#   'viewcount': '521',
#   'comment_ct': '29',
#   'likecount': '24'},
#  {'video_title': 'Is Data Science Right For You?',
#   'published': '2019-08-18T16:54:05Z',
#   'viewcount': '51018',
#   'comment_ct': '109',
#   'likecount': '1182'},
#  {'video_title': 'Data Science Fundamentals: Data Cleaning in Python',
#   'published': '2019-08-11T20:50:23Z',
#   'viewcount': '14922',
#   'comment_ct': '55',
#   'likecount': '393'},
#  {'video_title': 'How To Get Data Science Experience (Without a Job)',
#   'published': '2019-08-08T01:58:40Z',
#   'viewcount': '29564',
#   'comment_ct': '77',
#   'likecount': '1388'},
#  {'video_title': 'Take Your Data Science Projects From Good to Great',
#   'published': '2019-08-05T02:34:28Z',
#   'viewcount': '1618',
#   'comment_ct': '11',
#   'likecount': '107'},
#  {'video_title': 'The Projects You Should Do To Get A Data Science Job',
#   'published': '2019-07-30T03:35:48Z',
#   'viewcount': '151152',
#   'comment_ct': '255',
#   'likecount': '5712'},
#  {'video_title': 'What Does a Data Scientist Actually Do?',
#   'published': '2019-07-19T03:18:04Z',
#   'viewcount': '46546',
#   'comment_ct': '81',
#   'likecount': '1272'},
#  {'video_title': 'Data Science Fundamentals: Data Manipulation in Python (Pandas)',
#   'published': '2019-07-13T21:09:41Z',
#   'viewcount': '13020',
#   'comment_ct': '43',
#   'likecount': '352'},
#  {'video_title': 'Data Science Fundamentals: Data Exploration in Python (Pandas)',
#   'published': '2019-07-05T14:29:49Z',
#   'viewcount': '17986',
#   'comment_ct': '61',
#   'likecount': '529'},
#  {'video_title': 'Data Science: Pros and Cons',
#   'published': '2019-06-30T15:26:49Z',
#   'viewcount': '5282',
#   'comment_ct': '18',
#   'likecount': '218'},
#  {'video_title': 'How I Got My First Data Science Internship (And How You Can Land One)',
#   'published': '2019-06-21T04:33:34Z',
#   'viewcount': '24939',
#   'comment_ct': '89',
#   'likecount': '1201'},
#  {'video_title': 'My Top 5 Data Science Internship Tips',
#   'published': '2019-06-15T15:28:26Z',
#   'viewcount': '11957',
#   'comment_ct': '23',
#   'likecount': '496'},
#  {'video_title': 'Golf STATS: Strokes Gained Explained',
#   'published': '2019-06-07T03:10:34Z',
#   'viewcount': '7569',
#   'comment_ct': '28',
#   'likecount': '158'},
#  {'video_title': 'Most Data Science Hopefuls Overlook This Important Skill',
#   'published': '2019-05-25T18:34:33Z',
#   'viewcount': '619',
#   'comment_ct': '5',
#   'likecount': '45'},
#  {'video_title': 'What I Learned From My Three Degrees',
#   'published': '2019-05-17T03:10:29Z',
#   'viewcount': '1272',
#   'comment_ct': '12',
#   'likecount': '61'},
#  {'video_title': 'I Wish I Had Known THIS Before Starting in Data Science',
#   'published': '2019-05-14T00:21:28Z',
#   'viewcount': '25675',
#   'comment_ct': '66',
#   'likecount': '1071'},
#  {'video_title': 'NASA Physicist Turned Data Scientist (Tim Bowling) - KNN EP. 02',
#   'published': '2019-05-05T20:26:36Z',
#   'viewcount': '1254',
#   'comment_ct': '2',
#   'likecount': '40'},
#  {'video_title': 'Should You Learn R for Data Science?',
#   'published': '2019-04-25T15:00:01Z',
#   'viewcount': '21252',
#   'comment_ct': '71',
#   'likecount': '566'},
#  {'video_title': 'Scrape Twitter Data in Python with Twitterscraper Module',
#   'published': '2019-04-18T15:00:14Z',
#   'viewcount': '46450',
#   'comment_ct': '331',
#   'likecount': '855'},
#  {'video_title': 'Work From Home Data Scientist: Day in the Life',
#   'published': '2019-04-12T15:00:00Z',
#   'viewcount': '28115',
#   'comment_ct': '101',
#   'likecount': '758'},
#  {'video_title': 'Where to Look for Data Science Jobs',
#   'published': '2019-03-29T16:00:01Z',
#   'viewcount': '3015',
#   'comment_ct': '9',
#   'likecount': '121'},
#  {'video_title': 'Data Science: Startup vs. Large Corporation',
#   'published': '2019-03-21T17:00:01Z',
#   'viewcount': '2174',
#   'comment_ct': '4',
#   'likecount': '75'},
#  {'video_title': "Data Science, Machine Learning, and AI: What's the Difference?",
#   'published': '2019-03-16T14:00:04Z',
#   'viewcount': '6191',
#   'comment_ct': '26',
#   'likecount': '176'},
#  {'video_title': 'Was Captain Marvel Bad? A Sentiment Analysis of Twitter Data',
#   'published': '2019-03-09T21:58:10Z',
#   'viewcount': '4212',
#   'comment_ct': '15',
#   'likecount': '180'},
#  {'video_title': "Why You DON'T Want to be a WFH Data Scientist",
#   'published': '2019-03-03T22:14:01Z',
#   'viewcount': '809',
#   'comment_ct': '12',
#   'likecount': '33'},
#  {'video_title': 'Welcome To My Channel | Ken Jee | Data Science',
#   'published': '2019-03-03T01:00:17Z',
#   'viewcount': '1441',
#   'comment_ct': '8',
#   'likecount': '36'},
#  {'video_title': 'Where YOU Should Start With Data Science Projects',
#   'published': '2019-02-19T03:23:50Z',
#   'viewcount': '17101',
#   'comment_ct': '17',
#   'likecount': '352'},
#  {'video_title': 'Watch This Before Applying to Data Science Jobs',
#   'published': '2019-02-04T23:40:34Z',
#   'viewcount': '1502',
#   'comment_ct': '13',
#   'likecount': '66'},
#  {'video_title': 'My Top 5 Data Science Resources for 2019',
#   'published': '2019-01-05T22:07:08Z',
#   'viewcount': '3714',
#   'comment_ct': '17',
#   'likecount': '122'},
#  {'video_title': "IT'S NOT TOO LATE TO LEARN CODE!",
#   'published': '2018-12-18T02:01:15Z',
#   'viewcount': '836',
#   'comment_ct': '6',
#   'likecount': '36'},
#  {'video_title': 'The Best Way to Predict NBA Minutes Played',
#   'published': '2018-12-11T02:39:35Z',
#   'viewcount': '4359',
#   'comment_ct': '14',
#   'likecount': '109'},
#  {'video_title': 'Demystifying Data Science Roles',
#   'published': '2018-11-30T01:22:49Z',
#   'viewcount': '1140',
#   'comment_ct': '5',
#   'likecount': '54'},
#  {'video_title': 'How to Simulate NBA Games in Python',
#   'published': '2018-11-19T23:31:49Z',
#   'viewcount': '17784',
#   'comment_ct': '54',
#   'likecount': '394'},
#  {'video_title': 'Should You Get A Masters in Data Science?',
#   'published': '2018-11-14T01:39:33Z',
#   'viewcount': '20607',
#   'comment_ct': '135',
#   'likecount': '305'},
#  {'video_title': 'How I Became A Data Scientist From a Business Background',
#   'published': '2018-11-12T00:26:08Z',
#   'viewcount': '6480',
#   'comment_ct': '23',
#   'likecount': '197'},
#  {'video_title': 'Predicting Season Long NBA Wins Using Multiple Linear Regression',
#   'published': '2018-07-10T16:39:52Z',
#   'viewcount': '8751',
#   'comment_ct': '17',
#   'likecount': '192'},
#  {'video_title': 'Predicting Crypto-Currency Price Using RNN lSTM & GRU',
#   'published': '2017-11-18T20:04:51Z',
#   'viewcount': '18996',
#   'comment_ct': '41',
#   'likecount': '293'}]

# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (671 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.3/671.3 kB 10.9 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 39.2 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.5.0

# %%
get_video(youtube,playlist_ids)
# Out:
# []

# %%
get_video(youtube,video_ids)
# Out:
# [{'video_title': 'The Death of the Full-Time Job (Rise of the Contractor)',
#   'published': '2023-09-22T11:46:35Z',
#   'viewcount': '4858',
#   'comment_ct': '70',
#   'likecount': '334'},
#  {'video_title': 'How to Survive a Down Data Job Market',
#   'published': '2023-09-05T10:50:39Z',
#   'viewcount': '15550',
#   'comment_ct': '64',
#   'likecount': '507'},
#  {'video_title': 'The Harsh Reality of the Data Job Market',
#   'published': '2023-08-24T11:30:19Z',
#   'viewcount': '103807',
#   'comment_ct': '293',
#   'likecount': '2522'},
#  {'video_title': '7 Industries AI will Aggressively Disrupt',
#   'published': '2023-08-14T11:30:19Z',
#   'viewcount': '5562',
#   'comment_ct': '41',
#   'likecount': '229'},
#  {'video_title': "What's in My Data Science Travel Bag? (50+ Flights Last Year)",
#   'published': '2023-08-07T17:57:05Z',
#   'viewcount': '3846',
#   'comment_ct': '47',
#   'likecount': '122'},
#  {'video_title': '7 Enticing Jobs AI Will Create',
#   'published': '2023-07-24T12:00:01Z',
#   'viewcount': '4407',
#   'comment_ct': '36',
#   'likecount': '191'},
#  {'video_title': 'The ChatGPT Code Interpreter is OVERRATED',
#   'published': '2023-07-22T09:42:29Z',
#   'viewcount': '3943',
#   'comment_ct': '31',
#   'likecount': '142'},
#  {'video_title': 'Exciting Announcement!',
#   'published': '2023-06-23T17:28:36Z',
#   'viewcount': '6505',
#   'comment_ct': '50',
#   'likecount': '294'},
#  {'video_title': 'AI: A Customer Service Revolution?',
#   'published': '2023-05-26T12:00:21Z',
#   'viewcount': '3739',
#   'comment_ct': '35',
#   'likecount': '117'},
#  {'video_title': 'Beginner Kaggle Data Science Project Walk-Through (Housing Prices) | With ChatGPT',
#   'published': '2023-05-16T12:00:25Z',
#   'viewcount': '26716',
#   'comment_ct': '57',
#   'likecount': '917'},
#  {'video_title': 'How I Would Learn Data Science with AI (If I Could Start Over)',
#   'published': '2023-05-04T12:04:56Z',
#   'viewcount': '31670',
#   'comment_ct': '77',
#   'likecount': '1341'},
#  {'video_title': 'This AI question will determine our future',
#   'published': '2023-04-06T13:00:32Z',
#   'viewcount': '4225',
#   'comment_ct': '37',
#   'likecount': '262'},
#  {'video_title': "I'll Never Code the Same Again... (GPT-4 is OP)",
#   'published': '2023-04-03T13:00:27Z',
#   'viewcount': '70729',
#   'comment_ct': '79',
#   'likecount': '828'},
#  {'video_title': 'Your current portfolio is actually hurting you #shorts',
#   'published': '2023-03-30T13:00:37Z',
#   'viewcount': '6595',
#   'comment_ct': '7',
#   'likecount': '395'},
#  {'video_title': 'Traditional "networking" is stupid. Do THIS instead #shorts',
#   'published': '2023-03-27T13:00:41Z',
#   'viewcount': '6675',
#   'comment_ct': '3',
#   'likecount': '363'},
#  {'video_title': "you're job searching wrong. #shorts",
#   'published': '2023-03-23T13:00:35Z',
#   'viewcount': '4051',
#   'comment_ct': '3',
#   'likecount': '245'},
#  {'video_title': 'The Economics of Data Roles #shorts',
#   'published': '2023-03-21T13:00:15Z',
#   'viewcount': '7929',
#   'comment_ct': '10',
#   'likecount': '506'},
#  {'video_title': 'Why your phone knows everything you say #shorts',
#   'published': '2023-03-18T13:00:42Z',
#   'viewcount': '2683',
#   'comment_ct': '7',
#   'likecount': '120'},
#  {'video_title': 'Read these for a successful career. #shorts',
#   'published': '2023-03-16T01:19:35Z',
#   'viewcount': '2953',
#   'comment_ct': '2',
#   'likecount': '234'},
#  {'video_title': 'Is Your Phone Actually Listening to You? #shorts',
#   'published': '2023-03-09T13:00:01Z',
#   'viewcount': '2398',
#   'comment_ct': '5',
#   'likecount': '44'},
#  {'video_title': 'How I Realized I Was a Bad Manager #shorts',
#   'published': '2023-03-07T13:00:11Z',
#   'viewcount': '2603',
#   'comment_ct': '1',
#   'likecount': '120'},
#  {'video_title': 'How I Use ChatGPT as a Data Scientist (4-5 hrs Saved Per Week)',
#   'published': '2023-03-03T13:00:07Z',
#   'viewcount': '19986',
#   'comment_ct': '52',
#   'likecount': '751'},
#  {'video_title': 'Why I Quit Data Science... and then crawled back #shorts',
#   'published': '2023-03-01T13:00:17Z',
#   'viewcount': '7837',
#   'comment_ct': '13',
#   'likecount': '266'},
#  {'video_title': 'The Best Place to Look for Data Science Opportunities #shorts',
#   'published': '2023-02-27T13:00:32Z',
#   'viewcount': '2546',
#   'comment_ct': '2',
#   'likecount': '160'},
#  {'video_title': 'Learning On the companies dime #shorts',
#   'published': '2023-02-24T17:00:13Z',
#   'viewcount': '3045',
#   'comment_ct': '1',
#   'likecount': '173'},
#  {'video_title': 'The Best Way to Transition to Data Science? #shorts',
#   'published': '2023-02-21T17:13:47Z',
#   'viewcount': '3936',
#   'comment_ct': '6',
#   'likecount': '251'},
#  {'video_title': 'Avoid this Massive Data Science Learning Mistake #shorts',
#   'published': '2023-02-17T13:00:03Z',
#   'viewcount': '6703',
#   'comment_ct': '6',
#   'likecount': '387'},
#  {'video_title': "Don't Go into Data for the Money #shorts",
#   'published': '2023-02-15T10:00:37Z',
#   'viewcount': '3705',
#   'comment_ct': '12',
#   'likecount': '218'},
#  {'video_title': 'First Data Science Project? Watch This.',
#   'published': '2023-02-13T13:00:36Z',
#   'viewcount': '6508',
#   'comment_ct': '22',
#   'likecount': '340'},
#  {'video_title': 'How to Approach Applying for a Data Role #shorts',
#   'published': '2023-02-08T13:00:39Z',
#   'viewcount': '3652',
#   'comment_ct': '7',
#   'likecount': '243'},
#  {'video_title': 'The Hard Reality of Data Science Work #shorts',
#   'published': '2023-02-06T19:35:25Z',
#   'viewcount': '14008',
#   'comment_ct': '14',
#   'likecount': '786'},
#  {'video_title': 'How Much Money Does a Data Scientist Make? #shorts',
#   'published': '2023-02-03T12:00:03Z',
#   'viewcount': '4467',
#   'comment_ct': '6',
#   'likecount': '187'},
#  {'video_title': 'These 3 Things Make Data Science Special #shorts',
#   'published': '2023-02-01T12:00:12Z',
#   'viewcount': '4159',
#   'comment_ct': '7',
#   'likecount': '328'},
#  {'video_title': 'Will Data Science Be Automated? #shorts',
#   'published': '2023-01-27T11:00:44Z',
#   'viewcount': '8724',
#   'comment_ct': '8',
#   'likecount': '386'},
#  {'video_title': 'Is Data Science A Good Fit For You? #shorts',
#   'published': '2023-01-25T11:00:05Z',
#   'viewcount': '4997',
#   'comment_ct': '11',
#   'likecount': '287'},
#  {'video_title': '5 Books I Wish I Read Earlier In My Career',
#   'published': '2023-01-23T15:31:48Z',
#   'viewcount': '9166',
#   'comment_ct': '50',
#   'likecount': '512'},
#  {'video_title': 'How To Start Working on Data Science Projects (As a Beginner) #shorts',
#   'published': '2023-01-19T07:00:06Z',
#   'viewcount': '6140',
#   'comment_ct': '12',
#   'likecount': '554'},
#  {'video_title': 'What Data Science Tool Would I Learn First? #shorts',
#   'published': '2023-01-17T07:00:12Z',
#   'viewcount': '6242',
#   'comment_ct': '10',
#   'likecount': '472'},
#  {'video_title': 'How long does it take to become a Data Scientist? #shorts',
#   'published': '2023-01-12T11:45:02Z',
#   'viewcount': '6244',
#   'comment_ct': '6',
#   'likecount': '471'},
#  {'video_title': 'Where & how to start your Data Science Journey #shorts',
#   'published': '2023-01-09T00:35:13Z',
#   'viewcount': '6651',
#   'comment_ct': '2',
#   'likecount': '410'},
#  {'video_title': 'How I Would NOT Learn Data Science in 2023.',
#   'published': '2023-01-03T13:00:34Z',
#   'viewcount': '124332',
#   'comment_ct': '254',
#   'likecount': '4111'},
#  {'video_title': 'The Greatest Data Science Event You Never Heard Of  [Behind The Scenes]',
#   'published': '2022-12-14T13:00:23Z',
#   'viewcount': '4838',
#   'comment_ct': '28',
#   'likecount': '202'},
#  {'video_title': 'The Essential Programming Concepts For Learning Data Science',
#   'published': '2022-11-14T13:00:02Z',
#   'viewcount': '20375',
#   'comment_ct': '46',
#   'likecount': '847'},
#  {'video_title': 'The Data Content House: What You Missed',
#   'published': '2022-10-07T13:00:04Z',
#   'viewcount': '10436',
#   'comment_ct': '49',
#   'likecount': '348'},
#  {'video_title': 'Is Data Science A Good Career?',
#   'published': '2022-09-29T20:40:31Z',
#   'viewcount': '61060',
#   'comment_ct': '139',
#   'likecount': '1933'},
#  {'video_title': 'IRON ANALYST (Teaser) #shorts',
#   'published': '2022-09-27T17:21:13Z',
#   'viewcount': '5641',
#   'comment_ct': '24',
#   'likecount': '365'},
#  {'video_title': 'When a New Data Scientist Joins The Team',
#   'published': '2022-08-29T13:00:01Z',
#   'viewcount': '16412',
#   'comment_ct': '133',
#   'likecount': '745'},
#  {'video_title': 'State of Data Science - Web Data',
#   'published': '2022-08-05T20:20:04Z',
#   'viewcount': '10433',
#   'comment_ct': '34',
#   'likecount': '359'},
#  {'video_title': 'Data Science Town Hall - State of Data Science',
#   'published': '2022-08-04T18:34:49Z',
#   'viewcount': '9961',
#   'comment_ct': '38',
#   'likecount': '376'},
#  {'video_title': 'The Programming Roadmap For Data Science',
#   'published': '2022-07-29T14:31:33Z',
#   'viewcount': '27329',
#   'comment_ct': '64',
#   'likecount': '1301'},
#  {'video_title': '5 Impactful Data Science Projects For Your Portfolio',
#   'published': '2022-06-27T13:00:10Z',
#   'viewcount': '77723',
#   'comment_ct': '90',
#   'likecount': '2928'},
#  {'video_title': 'Can AI Fix my Baseball Swing?',
#   'published': '2022-06-10T13:00:00Z',
#   'viewcount': '7615',
#   'comment_ct': '68',
#   'likecount': '341'},
#  {'video_title': 'Every Data Scientist... (funny!)',
#   'published': '2022-05-24T13:00:07Z',
#   'viewcount': '16732',
#   'comment_ct': '146',
#   'likecount': '853'},
#  {'video_title': 'State of Data Science (Town Hall) ft - Data Squad',
#   'published': '2022-05-07T22:43:20Z',
#   'viewcount': '15980',
#   'comment_ct': '65',
#   'likecount': '429'},
#  {'video_title': 'Data Science Portfolio Project From Scratch | Building a YouTube Data Dashboard with Streamlit',
#   'published': '2022-04-04T13:00:16Z',
#   'viewcount': '59546',
#   'comment_ct': '87',
#   'likecount': '1524'},
#  {'video_title': 'Why You Are NOT Landing Data Jobs ... Yet',
#   'published': '2022-03-25T13:00:38Z',
#   'viewcount': '21320',
#   'comment_ct': '113',
#   'likecount': '890'},
#  {'video_title': 'Data Scientists VS NFT Scam',
#   'published': '2022-03-03T13:00:36Z',
#   'viewcount': '4645',
#   'comment_ct': '49',
#   'likecount': '189'},
#  {'video_title': 'When a PM Joins the Data Team... (funny!) - Ft @LukeBarousse',
#   'published': '2022-02-21T13:00:03Z',
#   'viewcount': '11173',
#   'comment_ct': '144',
#   'likecount': '510'},
#  {'video_title': 'What Professional Data Scientists ACTUALLY Do',
#   'published': '2022-02-14T13:00:31Z',
#   'viewcount': '95954',
#   'comment_ct': '187',
#   'likecount': '3321'},
#  {'video_title': 'Can You Analyze My Data Better Than I Can?',
#   'published': '2022-01-31T13:00:11Z',
#   'viewcount': '7335',
#   'comment_ct': '62',
#   'likecount': '323'},
#  {'video_title': 'Giving Back to My Most Engaged Subscribers!',
#   'published': '2022-01-28T13:00:01Z',
#   'viewcount': '2331',
#   'comment_ct': '89',
#   'likecount': '119'},
#  {'video_title': 'How to Make $1 Billion Betting on Horse Racing with Machine Learning',
#   'published': '2022-01-24T13:00:09Z',
#   'viewcount': '33163',
#   'comment_ct': '131',
#   'likecount': '949'},
#  {'video_title': 'Should You Be Excited About Web 3? (As a Data Scientist)',
#   'published': '2022-01-17T13:00:00Z',
#   'viewcount': '8854',
#   'comment_ct': '83',
#   'likecount': '424'},
#  {'video_title': 'Should  @LukeBarousse Take This Data Analyst Job? (Funny) #Shorts',
#   'published': '2022-01-14T10:00:02Z',
#   'viewcount': '8526',
#   'comment_ct': '33',
#   'likecount': '253'},
#  {'video_title': 'The Only Data Science Explanation You Need',
#   'published': '2022-01-10T13:00:33Z',
#   'viewcount': '59845',
#   'comment_ct': '172',
#   'likecount': '2234'},
#  {'video_title': 'We Need to Talk About The LinkedIn Machine Learning Assessment.',
#   'published': '2022-01-03T13:00:35Z',
#   'viewcount': '14484',
#   'comment_ct': '144',
#   'likecount': '647'},
#  {'video_title': 'How I Would Learn Data Science in 2022 (If I Had to Start Over)',
#   'published': '2021-12-27T13:00:34Z',
#   'viewcount': '341805',
#   'comment_ct': '536',
#   'likecount': '15006'},
#  {'video_title': 'What the Heck is WSL 2? (My New Favorite Tool)',
#   'published': '2021-12-17T14:00:01Z',
#   'viewcount': '12601',
#   'comment_ct': '67',
#   'likecount': '430'},
#  {'video_title': 'How Statistics Saved the US SERIOUS $$$$ During WW2 #Shorts',
#   'published': '2021-12-10T13:00:22Z',
#   'viewcount': '8023',
#   'comment_ct': '25',
#   'likecount': '571'},
#  {'video_title': 'How Zillow Lost $500 MILLION With Machine Learning',
#   'published': '2021-12-03T13:00:14Z',
#   'viewcount': '24682',
#   'comment_ct': '146',
#   'likecount': '1185'},
#  {'video_title': 'Why Is Data Engineering So HOT Right Now?',
#   'published': '2021-11-26T13:00:22Z',
#   'viewcount': '29515',
#   'comment_ct': '141',
#   'likecount': '1102'},
#  {'video_title': 'Is Data Science Dying?',
#   'published': '2021-11-19T13:00:01Z',
#   'viewcount': '123676',
#   'comment_ct': '363',
#   'likecount': '3882'},
#  {'video_title': '7 Incredible Books That Transformed My Health and My Life',
#   'published': '2021-11-12T13:00:04Z',
#   'viewcount': '8139',
#   'comment_ct': '112',
#   'likecount': '386'},
#  {'video_title': 'Why EVERYONE Should Start a Podcast (Including YOU)',
#   'published': '2021-11-05T13:00:23Z',
#   'viewcount': '3629',
#   'comment_ct': '46',
#   'likecount': '202'},
#  {'video_title': 'Building a Burrito Dashboard - Data Science Project from Scratch with atoti',
#   'published': '2021-10-29T12:00:01Z',
#   'viewcount': '13484',
#   'comment_ct': '39',
#   'likecount': '300'},
#  {'video_title': 'ML Ops: What is it REALLY?',
#   'published': '2021-10-22T13:00:00Z',
#   'viewcount': '6986',
#   'comment_ct': '66',
#   'likecount': '285'},
#  {'video_title': 'Business Skills for Data Science: What are they REALLY?',
#   'published': '2021-10-18T13:00:27Z',
#   'viewcount': '6836',
#   'comment_ct': '50',
#   'likecount': '301'},
#  {'video_title': '#66DaysOfData Round 3 Live Event! (feat. @statquest)',
#   'published': '2021-10-12T16:05:54Z',
#   'viewcount': '2205',
#   'comment_ct': '5',
#   'likecount': '123'},
#  {'video_title': 'Roasting My First Data Science Project (Common Project Mistakes)',
#   'published': '2021-10-08T13:00:15Z',
#   'viewcount': '5941',
#   'comment_ct': '64',
#   'likecount': '283'},
#  {'video_title': "Is Data Visualization Important for Data Science? (A Data Scientist's Perspective)",
#   'published': '2021-08-20T13:00:20Z',
#   'viewcount': '12861',
#   'comment_ct': '112',
#   'likecount': '530'},
#  {'video_title': 'Project Presentation - Expectations vs. Reality (funny) #shorts',
#   'published': '2021-08-07T14:00:11Z',
#   'viewcount': '10225',
#   'comment_ct': '32',
#   'likecount': '434'},
#  {'video_title': 'Data Science Project - Expectations vs Reality (funny) #shorts',
#   'published': '2021-08-06T23:04:24Z',
#   'viewcount': '41365',
#   'comment_ct': '32',
#   'likecount': '1605'},
#  {'video_title': 'How I Learned to Learn.',
#   'published': '2021-07-31T13:00:26Z',
#   'viewcount': '50849',
#   'comment_ct': '209',
#   'likecount': '2367'},
#  {'video_title': 'Is Spotify Shuffle Really Random? #Shorts',
#   'published': '2021-07-21T13:00:21Z',
#   'viewcount': '10732',
#   'comment_ct': '50',
#   'likecount': '588'},
#  {'video_title': 'I Eat a Papaya Live on Stream (Plus Q&A for 150K Subs!)',
#   'published': '2021-07-16T21:30:26Z',
#   'viewcount': '2409',
#   'comment_ct': '30',
#   'likecount': '93'},
#  {'video_title': 'Why are APIs Important for Data Science?',
#   'published': '2021-07-09T13:00:32Z',
#   'viewcount': '9982',
#   'comment_ct': '95',
#   'likecount': '455'},
#  {'video_title': 'Is Your Phone REALLY Listening to You?',
#   'published': '2021-07-03T13:00:31Z',
#   'viewcount': '5187',
#   'comment_ct': '116',
#   'likecount': '279'},
#  {'video_title': 'Kaggle vs Github - Which is Best for Your Data Science Portfolio?',
#   'published': '2021-06-25T13:00:12Z',
#   'viewcount': '15509',
#   'comment_ct': '123',
#   'likecount': '611'},
#  {'video_title': '#66DaysOfData - 3 Reasons to Start!',
#   'published': '2021-06-18T13:00:32Z',
#   'viewcount': '4098',
#   'comment_ct': '41',
#   'likecount': '224'},
#  {'video_title': '#66DaysOfData - What is it? #shorts',
#   'published': '2021-06-11T12:48:29Z',
#   'viewcount': '9221',
#   'comment_ct': '54',
#   'likecount': '395'},
#  {'video_title': 'A Quick Data Science Project Tip! #SHORTS',
#   'published': '2021-06-03T13:00:06Z',
#   'viewcount': '16683',
#   'comment_ct': '89',
#   'likecount': '1020'},
#  {'video_title': 'Discouraged with Data Science? - Watch THIS video.',
#   'published': '2021-05-28T13:00:02Z',
#   'viewcount': '7467',
#   'comment_ct': '195',
#   'likecount': '393'},
#  {'video_title': 'How Data Science Projects Pay Off',
#   'published': '2021-05-22T13:30:03Z',
#   'viewcount': '10736',
#   'comment_ct': '146',
#   'likecount': '601'},
#  {'video_title': 'How I Use Data to Optimize My Life | What I Collect & How I Analyze It',
#   'published': '2021-05-14T13:00:03Z',
#   'viewcount': '10622',
#   'comment_ct': '134',
#   'likecount': '491'},
#  {'video_title': 'What is a lambda function (python)? #shorts',
#   'published': '2021-05-13T00:38:55Z',
#   'viewcount': '15449',
#   'comment_ct': '49',
#   'likecount': '949'},
#  {'video_title': 'Why Kaggle Should Be Your Favorite Data Science Resource #shorts',
#   'published': '2021-05-07T13:00:30Z',
#   'viewcount': '30531',
#   'comment_ct': '64',
#   'likecount': '1619'},
#  {'video_title': 'What is Pandas? (Data & Data Science) #shorts',
#   'published': '2021-04-30T13:00:07Z',
#   'viewcount': '23840',
#   'comment_ct': '87',
#   'likecount': '1226'},
#  {'video_title': 'The 7 Biggest Data Science  Beginner Mistakes',
#   'published': '2021-04-23T13:00:14Z',
#   'viewcount': '77224',
#   'comment_ct': '284',
#   'likecount': '3433'},
#  {'video_title': 'Data Scientist Reacts: REAL Data Science Job Application Data',
#   'published': '2021-04-16T13:00:00Z',
#   'viewcount': '23502',
#   'comment_ct': '85',
#   'likecount': '694'},
#  {'video_title': "Why You Probably Won't Become a Data Scientist",
#   'published': '2021-04-09T13:00:31Z',
#   'viewcount': '138369',
#   'comment_ct': '481',
#   'likecount': '4042'},
#  {'video_title': 'How to Go From Data Analyst to Data Scientist',
#   'published': '2021-04-02T13:00:14Z',
#   'viewcount': '53850',
#   'comment_ct': '177',
#   'likecount': '1543'},
#  {'video_title': 'Why I Have 2 Offices for Data Science & Content Creation',
#   'published': '2021-03-26T13:00:03Z',
#   'viewcount': '3983',
#   'comment_ct': '92',
#   'likecount': '138'},
#  {'video_title': 'MARCH MADNESS - Will My Machine Learning Model Beat Your Bracket?',
#   'published': '2021-03-19T13:00:32Z',
#   'viewcount': '18197',
#   'comment_ct': '108',
#   'likecount': '350'},
#  {'video_title': 'My Regrets as a Data Science Student',
#   'published': '2021-03-12T13:00:27Z',
#   'viewcount': '23944',
#   'comment_ct': '112',
#   'likecount': '882'},
#  {'video_title': 'My Daily Battle With Time - Will I Win? [Vlog]',
#   'published': '2021-03-08T13:00:06Z',
#   'viewcount': '3833',
#   'comment_ct': '83',
#   'likecount': '196'},
#  {'video_title': 'What is the Future of my Comment Leaderboard Project?',
#   'published': '2021-02-26T14:00:15Z',
#   'viewcount': '5573',
#   'comment_ct': '81',
#   'likecount': '201'},
#  {'video_title': 'How to Build a Website  - Building my ULTIMATE Portfolio Website',
#   'published': '2021-02-19T13:00:14Z',
#   'viewcount': '6765',
#   'comment_ct': '51',
#   'likecount': '174'},
#  {'video_title': 'Why I Quit Data Science',
#   'published': '2021-02-12T13:00:19Z',
#   'viewcount': '104805',
#   'comment_ct': '347',
#   'likecount': '2350'},
#  {'video_title': '🌶 Hot Topics in Tech: Data Science Explained #SHORTS',
#   'published': '2021-01-29T13:00:06Z',
#   'viewcount': '10711',
#   'comment_ct': '116',
#   'likecount': '556'},
#  {'video_title': 'How I Balance Data Science and Content Creation (7 Secrets)',
#   'published': '2021-01-23T14:00:30Z',
#   'viewcount': '6998',
#   'comment_ct': '126',
#   'likecount': '294'},
#  {'video_title': 'Kaggle Project From Scratch - Part 3 (Advanced Graphs & Gender Imbalance Analysis)',
#   'published': '2021-01-16T14:00:10Z',
#   'viewcount': '9762',
#   'comment_ct': '52',
#   'likecount': '301'},
#  {'video_title': 'Kaggle Project From Scratch - Part 2 (Exploratory Data Analysis)',
#   'published': '2021-01-08T13:00:16Z',
#   'viewcount': '22764',
#   'comment_ct': '134',
#   'likecount': '697'},
#  {'video_title': 'Kaggle Project From Scratch - Part 1 (Data Science Profession Survey)',
#   'published': '2021-01-02T14:00:26Z',
#   'viewcount': '37925',
#   'comment_ct': '147',
#   'likecount': '1139'},
#  {'video_title': 'What is the #66DaysOfData?',
#   'published': '2020-12-26T14:00:31Z',
#   'viewcount': '70016',
#   'comment_ct': '202',
#   'likecount': '2325'},
#  {'video_title': 'How I Would Learn Data Science in 2021 (What Has Changed?)',
#   'published': '2020-12-19T14:00:01Z',
#   'viewcount': '131497',
#   'comment_ct': '488',
#   'likecount': '5970'},
#  {'video_title': 'Unboxing the Ultimate Z by HP Data Science Package (FIRST EVER HP Workstation w/ Data Science Stack)',
#   'published': '2020-12-10T13:00:09Z',
#   'viewcount': '10933',
#   'comment_ct': '133',
#   'likecount': '398'},
#  {'video_title': 'I Built the FIRST EVER YouTube Subscriber LEADERBOARD',
#   'published': '2020-12-07T14:00:11Z',
#   'viewcount': '23525',
#   'comment_ct': '326',
#   'likecount': '727'},
#  {'video_title': '7 Things to Look For in a Masters For Data Science (feat. @TinaHuang1)',
#   'published': '2020-11-20T13:00:26Z',
#   'viewcount': '28078',
#   'comment_ct': '160',
#   'likecount': '857'},
#  {'video_title': '6 Lessons from #66DaysOfData',
#   'published': '2020-11-13T13:00:02Z',
#   'viewcount': '6733',
#   'comment_ct': '93',
#   'likecount': '340'},
#  {'video_title': '100K Channel Update + AMA Stream!',
#   'published': '2020-11-12T17:34:26Z',
#   'viewcount': '2319',
#   'comment_ct': '22',
#   'likecount': '127'},
#  {'video_title': 'Find a Data Science Project With These 3 Techniques',
#   'published': '2020-11-06T13:00:13Z',
#   'viewcount': '16816',
#   'comment_ct': '106',
#   'likecount': '727'},
#  {'video_title': 'How I Chose My Masters Degree for Breaking into Data Science',
#   'published': '2020-10-30T14:00:07Z',
#   'viewcount': '27303',
#   'comment_ct': '155',
#   'likecount': '678'},
#  {'video_title': 'git for Data Science Made Simple... (Hopefully)',
#   'published': '2020-10-23T15:00:10Z',
#   'viewcount': '19916',
#   'comment_ct': '92',
#   'likecount': '871'},
#  {'video_title': 'The PODCAST you might have asked for?',
#   'published': '2020-10-19T15:00:11Z',
#   'viewcount': '2118',
#   'comment_ct': '44',
#   'likecount': '94'},
#  {'video_title': 'Dealing with Doubt in Data Science (My Impostor Syndrome Story)',
#   'published': '2020-10-16T15:00:18Z',
#   'viewcount': '6747',
#   'comment_ct': '113',
#   'likecount': '448'},
#  {'video_title': 'Advice from a Data Analytics CEO (@How to Get an Analytics Job) - KNN EP. 17',
#   'published': '2020-10-14T15:00:11Z',
#   'viewcount': '14291',
#   'comment_ct': '47',
#   'likecount': '417'},
#  {'video_title': 'Data Science Resume Round-Up With @Tina Huang  | Episode 3',
#   'published': '2020-10-12T15:00:00Z',
#   'viewcount': '6834',
#   'comment_ct': '62',
#   'likecount': '143'},
#  {'video_title': '5 Unusual Data Science Projects that Will Land You a Job',
#   'published': '2020-10-09T15:00:09Z',
#   'viewcount': '11750',
#   'comment_ct': '83',
#   'likecount': '567'},
#  {'video_title': 'Sh*t Data Scientists Say (Parody)',
#   'published': '2020-10-05T15:00:08Z',
#   'viewcount': '9531',
#   'comment_ct': '144',
#   'likecount': '579'},
#  {'video_title': '5 Proven Strategies to Break into a Data Science Job',
#   'published': '2020-10-02T15:00:08Z',
#   'viewcount': '8620',
#   'comment_ct': '93',
#   'likecount': '366'},
#  {'video_title': 'Why Data-Viz is so Darn Important (@Story by Data | Kate Strachnyi) - KNN EP. 16',
#   'published': '2020-09-30T15:00:09Z',
#   'viewcount': '7072',
#   'comment_ct': '61',
#   'likecount': '287'},
#  {'video_title': 'Data Science Resume Round-Up With @TinaHuang1  - Episode 1',
#   'published': '2020-09-28T15:00:04Z',
#   'viewcount': '11716',
#   'comment_ct': '69',
#   'likecount': '292'},
#  {'video_title': '5 Essential Data Science Projects for Your Portfolio',
#   'published': '2020-09-26T15:00:06Z',
#   'viewcount': '73054',
#   'comment_ct': '206',
#   'likecount': '3106'},
#  {'video_title': 'His Startup Will Land You a Data Science Job (Jeremie Harris) - KNN EP. 15',
#   'published': '2020-09-23T15:00:02Z',
#   'viewcount': '5185',
#   'comment_ct': '64',
#   'likecount': '198'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 21(The Cleanest Portfolio)',
#   'published': '2020-09-21T15:00:03Z',
#   'viewcount': '12223',
#   'comment_ct': '58',
#   'likecount': '469'},
#  {'video_title': 'Hedge Funds, Startups, and Data Science Oh my! (@DataLeap) - KNN EP. 14',
#   'published': '2020-09-18T16:00:10Z',
#   'viewcount': '7451',
#   'comment_ct': '34',
#   'likecount': '253'},
#  {'video_title': 'Land a Data Science Job in a Different Country (Vijay Pravin Maharajan) - KNN EP. 13',
#   'published': '2020-09-16T15:00:24Z',
#   'viewcount': '5109',
#   'comment_ct': '56',
#   'likecount': '194'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 20 (Bootcamp Capstone)',
#   'published': '2020-09-14T15:00:00Z',
#   'viewcount': '4281',
#   'comment_ct': '35',
#   'likecount': '157'},
#  {'video_title': 'The 5 Pillars of Success I Live By',
#   'published': '2020-09-11T15:00:11Z',
#   'viewcount': '10139',
#   'comment_ct': '152',
#   'likecount': '873'},
#  {'video_title': 'Fast Cars to Faster Data (Alex Castrounis) - KNN EP. 12',
#   'published': '2020-09-09T15:00:12Z',
#   'viewcount': '1891',
#   'comment_ct': '25',
#   'likecount': '78'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 19 (One Big Improvement)',
#   'published': '2020-09-07T15:00:30Z',
#   'viewcount': '4039',
#   'comment_ct': '43',
#   'likecount': '163'},
#  {'video_title': "How I Learn Data Science Through Studying Other People's Code | #66DaysOfData",
#   'published': '2020-09-04T15:00:00Z',
#   'viewcount': '11822',
#   'comment_ct': '144',
#   'likecount': '737'},
#  {'video_title': 'How She Dominated the FAANG Data Science Interview  (@TinaHuang1 ) - KNN EP. 11',
#   'published': '2020-09-02T15:00:13Z',
#   'viewcount': '17965',
#   'comment_ct': '89',
#   'likecount': '572'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 18 (Job-Worthy GitHub)',
#   'published': '2020-08-31T15:00:15Z',
#   'viewcount': '17993',
#   'comment_ct': '93',
#   'likecount': '794'},
#  {'video_title': "Why I'm Starting Data Science Over Again.",
#   'published': '2020-08-29T15:30:10Z',
#   'viewcount': '50754',
#   'comment_ct': '450',
#   'likecount': '2603'},
#  {'video_title': 'Inside the Mind of the Ultimate Kaggle Grandmaster (@Abhishek Thakur ) - KNN EP. 10',
#   'published': '2020-08-26T15:00:03Z',
#   'viewcount': '15174',
#   'comment_ct': '77',
#   'likecount': '632'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 17 (Best Portfolio Website Yet?)',
#   'published': '2020-08-24T15:00:31Z',
#   'viewcount': '12941',
#   'comment_ct': '55',
#   'likecount': '462'},
#  {'video_title': "Don't Buy My Course..",
#   'published': '2020-08-21T16:00:32Z',
#   'viewcount': '7339',
#   'comment_ct': '146',
#   'likecount': '359'},
#  {'video_title': 'How a Subscriber Landed a Data Analyst Job in Less Than a Year (Ray Ojel) - KNN EP. 09',
#   'published': '2020-08-19T15:00:11Z',
#   'viewcount': '29112',
#   'comment_ct': '166',
#   'likecount': '1115'},
#  {'video_title': 'Reviewing Your Projects - Episode 16 (Project Review for Beginners)',
#   'published': '2020-08-17T15:00:07Z',
#   'viewcount': '3241',
#   'comment_ct': '40',
#   'likecount': '128'},
#  {'video_title': 'Data Scientist Dismantles the YouTube Algorithm.',
#   'published': '2020-08-14T15:00:31Z',
#   'viewcount': '6322',
#   'comment_ct': '108',
#   'likecount': '539'},
#  {'video_title': 'Sports Analytics & Streaming Data Science on Twitch (Nick Wan) - KNN EP. 08',
#   'published': '2020-08-12T15:30:26Z',
#   'viewcount': '5000',
#   'comment_ct': '39',
#   'likecount': '183'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 15 (Quant Finance)',
#   'published': '2020-08-10T15:00:08Z',
#   'viewcount': '12409',
#   'comment_ct': '53',
#   'likecount': '391'},
#  {'video_title': 'The Plagiarism Problem in Data Science',
#   'published': '2020-08-07T15:00:16Z',
#   'viewcount': '13075',
#   'comment_ct': '145',
#   'likecount': '629'},
#  {'video_title': 'Interview with the Director of AI Research @ NVIDIA (Anima Anandkumar) - KNN EP. 07',
#   'published': '2020-08-05T15:00:09Z',
#   'viewcount': '14426',
#   'comment_ct': '89',
#   'likecount': '602'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 14 [Deep Learning Focus]',
#   'published': '2020-08-03T15:00:08Z',
#   'viewcount': '4916',
#   'comment_ct': '56',
#   'likecount': '187'},
#  {'video_title': 'My First Data Science Contracting Side-Gig (How I Did It)',
#   'published': '2020-07-31T14:30:01Z',
#   'viewcount': '11428',
#   'comment_ct': '90',
#   'likecount': '582'},
#  {'video_title': 'Do You Have a Data Science Mentor? (@Danny Ma) - KNN EP. 06',
#   'published': '2020-07-30T01:00:10Z',
#   'viewcount': '2321',
#   'comment_ct': '34',
#   'likecount': '116'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 13 (BONUS LinkedIn Review)',
#   'published': '2020-07-27T15:00:30Z',
#   'viewcount': '5620',
#   'comment_ct': '112',
#   'likecount': '251'},
#  {'video_title': 'Building a Deep Learning BEAST (NVIDIA TITAN RTX + RYZEN 3900X)',
#   'published': '2020-07-24T15:00:11Z',
#   'viewcount': '8218',
#   'comment_ct': '199',
#   'likecount': '246'},
#  {'video_title': 'Is it Important to Share Your Data Science Work? (Ft. Eric Weber)',
#   'published': '2020-07-22T15:00:05Z',
#   'viewcount': '1858',
#   'comment_ct': '27',
#   'likecount': '98'},
#  {'video_title': 'Reviewing Your Data Science Resumes - Episode 12 (3 Different Resumes!)',
#   'published': '2020-07-20T15:00:08Z',
#   'viewcount': '29145',
#   'comment_ct': '90',
#   'likecount': '565'},
#  {'video_title': 'Beginner Kaggle Data Science Project Walk-Through (Titanic)',
#   'published': '2020-07-17T16:00:05Z',
#   'viewcount': '332261',
#   'comment_ct': '425',
#   'likecount': '7352'},
#  {'video_title': 'Uber Driver to Machine Learning Engineer in 9 Months! (@Daniel Bourke) - KNN EP. 05',
#   'published': '2020-07-16T02:00:09Z',
#   'viewcount': '30310',
#   'comment_ct': '121',
#   'likecount': '1125'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 11(GITHUB CLEANING)',
#   'published': '2020-07-13T16:00:01Z',
#   'viewcount': '3637',
#   'comment_ct': '50',
#   'likecount': '135'},
#  {'video_title': 'The Best Computer for Data Science Beginners',
#   'published': '2020-07-10T16:00:09Z',
#   'viewcount': '38288',
#   'comment_ct': '158',
#   'likecount': '854'},
#  {'video_title': 'Should You Major in Data Science? (Jaemin Lee) - KNN EP. 04',
#   'published': '2020-07-08T21:00:09Z',
#   'viewcount': '6167',
#   'comment_ct': '82',
#   'likecount': '231'},
#  {'video_title': 'Critiquing MY OWN Data Science Resume',
#   'published': '2020-07-06T16:00:30Z',
#   'viewcount': '12663',
#   'comment_ct': '88',
#   'likecount': '397'},
#  {'video_title': 'Where to Start Learning Data Science',
#   'published': '2020-07-03T16:00:04Z',
#   'viewcount': '18802',
#   'comment_ct': '127',
#   'likecount': '784'},
#  {'video_title': 'Data Science Productivity, Motivation, and Organization (ft. Data Professor & Codebasics)',
#   'published': '2020-07-01T15:00:12Z',
#   'viewcount': '4155',
#   'comment_ct': '37',
#   'likecount': '197'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 10 (Leveraging Your Data)',
#   'published': '2020-06-29T15:00:08Z',
#   'viewcount': '4596',
#   'comment_ct': '52',
#   'likecount': '176'},
#  {'video_title': 'How to Get a Data Science Job at FAANG (@Data Science Jay) - KNN EP. 03',
#   'published': '2020-06-26T15:00:10Z',
#   'viewcount': '16436',
#   'comment_ct': '79',
#   'likecount': '550'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 9 (Professional Violinist)',
#   'published': '2020-06-22T13:00:03Z',
#   'viewcount': '2415',
#   'comment_ct': '40',
#   'likecount': '82'},
#  {'video_title': 'Ken Jee Q & A Live Stream (50,000 Sub Special!)',
#   'published': '2020-06-20T02:09:18Z',
#   'viewcount': '2386',
#   'comment_ct': '49',
#   'likecount': '139'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 8 (College Student Help)',
#   'published': '2020-06-15T13:00:12Z',
#   'viewcount': '4369',
#   'comment_ct': '46',
#   'likecount': '169'},
#  {'video_title': "Why You're Struggling to Learn Data Science",
#   'published': '2020-06-12T13:00:17Z',
#   'viewcount': '15255',
#   'comment_ct': '159',
#   'likecount': '1010'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 7 (Incredible Portfolio Website)',
#   'published': '2020-06-08T13:00:21Z',
#   'viewcount': '11785',
#   'comment_ct': '70',
#   'likecount': '359'},
#  {'video_title': 'The State of Data Science with Krish Naik & The Data Professor [Panel Discussion]',
#   'published': '2020-06-05T13:00:26Z',
#   'viewcount': '23911',
#   'comment_ct': '146',
#   'likecount': '687'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 6 (Only 3 months of coding experience)',
#   'published': '2020-06-01T13:00:32Z',
#   'viewcount': '5706',
#   'comment_ct': '53',
#   'likecount': '154'},
#  {'video_title': 'How to Build a Data Science Portfolio Website with Hugo & Github Pages [feat. Data Professor]',
#   'published': '2020-05-29T13:00:21Z',
#   'viewcount': '72797',
#   'comment_ct': '269',
#   'likecount': '2199'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 5 (Very Detailed Project)',
#   'published': '2020-05-25T13:00:13Z',
#   'viewcount': '20981',
#   'comment_ct': '81',
#   'likecount': '489'},
#  {'video_title': 'Different Data Science Roles Explained (by a Data Scientist)',
#   'published': '2020-05-22T13:01:09Z',
#   'viewcount': '55466',
#   'comment_ct': '178',
#   'likecount': '1973'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 4 (Resume & Github)',
#   'published': '2020-05-18T13:00:22Z',
#   'viewcount': '11251',
#   'comment_ct': '53',
#   'likecount': '178'},
#  {'video_title': 'How to Make A Data Science Portfolio Website with Github Pages',
#   'published': '2020-05-15T13:30:00Z',
#   'viewcount': '130396',
#   'comment_ct': '193',
#   'likecount': '4440'},
#  {'video_title': '10000 Subscriber and 100th Video Special (Data Science)',
#   'published': '2020-05-13T13:00:17Z',
#   'viewcount': '3100',
#   'comment_ct': '115',
#   'likecount': '147'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 3 (Student Portfolio)',
#   'published': '2020-05-11T13:00:33Z',
#   'viewcount': '4522',
#   'comment_ct': '74',
#   'likecount': '153'},
#  {'video_title': 'How I Would Learn Data Science (If I Had to Start Over)',
#   'published': '2020-05-08T13:00:03Z',
#   'viewcount': '1395164',
#   'comment_ct': '1994',
#   'likecount': '49025'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 2 (Resume and Portfolio)',
#   'published': '2020-05-04T13:00:12Z',
#   'viewcount': '5546',
#   'comment_ct': '42',
#   'likecount': '196'},
#  {'video_title': 'What You Need to Know for a Data Science Internship',
#   'published': '2020-05-01T13:00:10Z',
#   'viewcount': '22161',
#   'comment_ct': '60',
#   'likecount': '1208'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 1 (Exploratory Analysis)',
#   'published': '2020-04-27T13:00:10Z',
#   'viewcount': '8362',
#   'comment_ct': '54',
#   'likecount': '350'},
#  {'video_title': "What It's Like to be a Socially Distanced Data Scientist (A Day in the Life)",
#   'published': '2020-04-24T13:00:32Z',
#   'viewcount': '14983',
#   'comment_ct': '103',
#   'likecount': '458'},
#  {'video_title': 'Data Science in Sports - Talk for Northwestern (Kellogg) MBA Students',
#   'published': '2020-04-22T13:00:30Z',
#   'viewcount': '3132',
#   'comment_ct': '24',
#   'likecount': '85'},
#  {'video_title': '5 Tips for Crushing the Work From Home Life',
#   'published': '2020-04-20T13:00:04Z',
#   'viewcount': '5424',
#   'comment_ct': '38',
#   'likecount': '203'},
#  {'video_title': 'Data Science Project from Scratch - Part 7 (Documenting Your Work)',
#   'published': '2020-04-17T13:00:04Z',
#   'viewcount': '21565',
#   'comment_ct': '129',
#   'likecount': '740'},
#  {'video_title': 'Data Science Project from Scratch -  Part 6 (Putting the Model into Production)',
#   'published': '2020-04-15T13:00:32Z',
#   'viewcount': '29530',
#   'comment_ct': '98',
#   'likecount': '734'},
#  {'video_title': 'Data Science Project from Scratch  - Part 5 (Model Building)',
#   'published': '2020-04-13T13:00:03Z',
#   'viewcount': '44217',
#   'comment_ct': '154',
#   'likecount': '907'},
#  {'video_title': 'Data Science Project from Scratch - Part 4 (Exploratory Data Analysis)',
#   'published': '2020-04-10T13:00:15Z',
#   'viewcount': '72584',
#   'comment_ct': '213',
#   'likecount': '1890'},
#  {'video_title': 'Data Science Project from Scratch - Part 3 (Data Cleaning)',
#   'published': '2020-04-08T13:00:19Z',
#   'viewcount': '80915',
#   'comment_ct': '277',
#   'likecount': '1759'},
#  {'video_title': 'Data Science Project from Scratch - Part 2 (Data Collection)',
#   'published': '2020-04-06T13:00:07Z',
#   'viewcount': '128706',
#   'comment_ct': '620',
#   'likecount': '3498'},
#  {'video_title': 'Data Science Project from Scratch - Part 1 (Project Planning)',
#   'published': '2020-04-03T13:00:12Z',
#   'viewcount': '197765',
#   'comment_ct': '175',
#   'likecount': '5045'},
#  {'video_title': 'When Data Science Goes Wrong',
#   'published': '2020-03-30T13:00:06Z',
#   'viewcount': '1807',
#   'comment_ct': '32',
#   'likecount': '106'},
#  {'video_title': 'How to ULTRALEARN Data Science',
#   'published': '2020-03-27T13:00:02Z',
#   'viewcount': '61898',
#   'comment_ct': '169',
#   'likecount': '3822'},
#  {'video_title': 'Why Right NOW is a Great Time to Learn Data Science',
#   'published': '2020-03-23T13:00:30Z',
#   'viewcount': '4430',
#   'comment_ct': '50',
#   'likecount': '268'},
#  {'video_title': 'Data Science Project Example Start to Finish (Deep Learning Image Classifier)',
#   'published': '2020-03-20T13:00:22Z',
#   'viewcount': '13021',
#   'comment_ct': '45',
#   'likecount': '468'},
#  {'video_title': "The Secret Data Scientists Don't Want You to Know",
#   'published': '2020-03-16T13:00:23Z',
#   'viewcount': '10760',
#   'comment_ct': '103',
#   'likecount': '1139'},
#  {'video_title': 'The 5 Stages of Learning Data Science',
#   'published': '2020-03-13T13:00:26Z',
#   'viewcount': '17509',
#   'comment_ct': '78',
#   'likecount': '1296'},
#  {'video_title': 'Can You Learn Data Science Without a Computer?',
#   'published': '2020-03-11T13:00:03Z',
#   'viewcount': '1705',
#   'comment_ct': '14',
#   'likecount': '117'},
#  {'video_title': 'The Best Free Data Science Courses Nobody is Talking About',
#   'published': '2020-03-09T13:00:04Z',
#   'viewcount': '346846',
#   'comment_ct': '620',
#   'likecount': '21220'},
#  {'video_title': 'The Data Science Projects that Got Me a Job',
#   'published': '2020-03-06T14:00:11Z',
#   'viewcount': '40978',
#   'comment_ct': '41',
#   'likecount': '1399'},
#  {'video_title': 'How to Integrate Data Science into Your Business',
#   'published': '2020-03-02T14:00:01Z',
#   'viewcount': '3378',
#   'comment_ct': '18',
#   'likecount': '129'},
#  {'video_title': 'The Problem with Data Science',
#   'published': '2020-02-28T14:00:07Z',
#   'viewcount': '3792',
#   'comment_ct': '19',
#   'likecount': '154'},
#  {'video_title': 'How Much Did Cheating Help the Astros Win? (What the Numbers Say)',
#   'published': '2020-02-24T14:00:00Z',
#   'viewcount': '1170',
#   'comment_ct': '16',
#   'likecount': '46'},
#  {'video_title': 'How to Set Up Your Data Science Environment (Anaconda Beginner)',
#   'published': '2020-02-21T14:00:02Z',
#   'viewcount': '128703',
#   'comment_ct': '97',
#   'likecount': '2462'},
#  {'video_title': '3 Proven Data Science Projects for Beginners (Kaggle)',
#   'published': '2020-02-17T14:00:04Z',
#   'viewcount': '327153',
#   'comment_ct': '525',
#   'likecount': '17780'},
#  {'video_title': 'Data Science Advice for College Students',
#   'published': '2020-02-14T17:22:37Z',
#   'viewcount': '68934',
#   'comment_ct': '197',
#   'likecount': '1964'},
#  {'video_title': 'Avoid These Data Science Resume Mistakes!',
#   'published': '2020-02-10T15:52:59Z',
#   'viewcount': '28425',
#   'comment_ct': '62',
#   'likecount': '1243'},
#  {'video_title': 'Data Science Explained with ... Cooking?',
#   'published': '2020-02-07T15:56:55Z',
#   'viewcount': '5303',
#   'comment_ct': '48',
#   'likecount': '315'},
#  {'video_title': 'The 4 Types of Sports Analytics Projects',
#   'published': '2020-02-03T16:35:19Z',
#   'viewcount': '31379',
#   'comment_ct': '62',
#   'likecount': '1023'},
#  {'video_title': 'Data Science in Golf: PGA Merchandise Show 2020',
#   'published': '2020-01-31T18:50:23Z',
#   'viewcount': '587',
#   'comment_ct': '13',
#   'likecount': '18'},
#  {'video_title': 'How I Learned Data Science',
#   'published': '2020-01-27T14:41:18Z',
#   'viewcount': '94122',
#   'comment_ct': '210',
#   'likecount': '2695'},
#  {'video_title': 'What is Sports Analytics Really?',
#   'published': '2020-01-20T14:00:00Z',
#   'viewcount': '21338',
#   'comment_ct': '73',
#   'likecount': '614'},
#  {'video_title': 'Data Science Certificate vs Bootcamp vs Masters Degree',
#   'published': '2020-01-18T01:03:08Z',
#   'viewcount': '111246',
#   'comment_ct': '582',
#   'likecount': '3137'},
#  {'video_title': 'How To Learn Programming for Data Science [3 Steps]',
#   'published': '2020-01-13T16:48:44Z',
#   'viewcount': '30092',
#   'comment_ct': '96',
#   'likecount': '1979'},
#  {'video_title': 'Data Science Fundamentals: SQL Queries',
#   'published': '2020-01-10T19:15:01Z',
#   'viewcount': '6502',
#   'comment_ct': '35',
#   'likecount': '214'},
#  {'video_title': 'Questions You Should Ask Your Data Science Interviewers',
#   'published': '2020-01-06T14:00:04Z',
#   'viewcount': '3147',
#   'comment_ct': '14',
#   'likecount': '152'},
#  {'video_title': 'The 9 Books That Changed My Perspective in 2019',
#   'published': '2020-01-03T14:45:28Z',
#   'viewcount': '3392',
#   'comment_ct': '25',
#   'likecount': '180'},
#  {'video_title': 'The Data Science Interview: What to Expect',
#   'published': '2019-12-30T14:00:01Z',
#   'viewcount': '8563',
#   'comment_ct': '32',
#   'likecount': '380'},
#  {'video_title': '5 Data Science Resolutions for 2020',
#   'published': '2019-12-27T14:00:07Z',
#   'viewcount': '475',
#   'comment_ct': '12',
#   'likecount': '25'},
#  {'video_title': 'How to Scrape NBA Data Using the nba_api Python Module',
#   'published': '2019-12-23T12:59:47Z',
#   'viewcount': '16830',
#   'comment_ct': '93',
#   'likecount': '595'},
#  {'video_title': 'Collision Course: Sports Betting + Data Science',
#   'published': '2019-12-20T14:00:02Z',
#   'viewcount': '18109',
#   'comment_ct': '27',
#   'likecount': '505'},
#  {'video_title': '3 Reasons You Should NOT Become a Data Scientist',
#   'published': '2019-12-16T18:46:58Z',
#   'viewcount': '100960',
#   'comment_ct': '204',
#   'likecount': '2932'},
#  {'video_title': '5 Sports Analytics Books to Get You Started',
#   'published': '2019-12-13T14:00:01Z',
#   'viewcount': '10945',
#   'comment_ct': '59',
#   'likecount': '415'},
#  {'video_title': 'Math Needed for Mastering Data Science',
#   'published': '2019-12-09T14:00:15Z',
#   'viewcount': '57041',
#   'comment_ct': '222',
#   'likecount': '2882'},
#  {'video_title': 'The 5 Stages of Data Science Adoption',
#   'published': '2019-12-06T14:00:04Z',
#   'viewcount': '1329',
#   'comment_ct': '17',
#   'likecount': '69'},
#  {'video_title': 'How YOU Can Land a Sports Analytics Job',
#   'published': '2019-12-02T14:00:05Z',
#   'viewcount': '69813',
#   'comment_ct': '231',
#   'likecount': '3086'},
#  {'video_title': 'Data Science Fundamentals: Linear Regression',
#   'published': '2019-11-29T14:00:02Z',
#   'viewcount': '6390',
#   'comment_ct': '42',
#   'likecount': '172'},
#  {'video_title': 'Golf: Would You Rather Be the LONGEST or STRAIGHTEST Driver on the PGA Tour?',
#   'published': '2019-11-25T14:00:11Z',
#   'viewcount': '1105',
#   'comment_ct': '12',
#   'likecount': '53'},
#  {'video_title': 'Sports Analytics 101: The Pythagorean Theorem of Sports',
#   'published': '2019-11-22T14:00:06Z',
#   'viewcount': '6155',
#   'comment_ct': '26',
#   'likecount': '272'},
#  {'video_title': '9 Ways You Can Make Extra Income as a Data Scientist',
#   'published': '2019-11-18T15:34:12Z',
#   'viewcount': '46255',
#   'comment_ct': '80',
#   'likecount': '1760'},
#  {'video_title': 'Applying Data Science To My YouTube Data: My Surprising Findings',
#   'published': '2019-11-11T21:12:11Z',
#   'viewcount': '5940',
#   'comment_ct': '31',
#   'likecount': '137'},
#  {'video_title': 'Why Selling Is An Important Data Science Skill',
#   'published': '2019-11-04T14:57:00Z',
#   'viewcount': '1631',
#   'comment_ct': '13',
#   'likecount': '81'},
#  {'video_title': 'By The Numbers: Where Should The NBA Put a 4 Point Line?',
#   'published': '2019-10-21T16:38:58Z',
#   'viewcount': '2855',
#   'comment_ct': '18',
#   'likecount': '73'},
#  {'video_title': 'Why is Balance Important in Data Science?',
#   'published': '2019-10-16T17:40:34Z',
#   'viewcount': '704',
#   'comment_ct': '13',
#   'likecount': '32'},
#  {'video_title': 'How to Stay Productive & Motivated When Learning Data Science',
#   'published': '2019-09-29T00:29:59Z',
#   'viewcount': '11925',
#   'comment_ct': '54',
#   'likecount': '585'},
#  {'video_title': 'How Far Should the NBA 3-Point Line Actually Be?',
#   'published': '2019-09-21T23:04:57Z',
#   'viewcount': '3884',
#   'comment_ct': '34',
#   'likecount': '116'},
#  {'video_title': '6 Habits of Successful Data Scientists',
#   'published': '2019-09-13T04:40:51Z',
#   'viewcount': '2233',
#   'comment_ct': '17',
#   'likecount': '95'},
#  {'video_title': 'How To Build A Word Cloud From Scraped Data (Python)',
#   'published': '2019-09-04T01:32:06Z',
#   'viewcount': '4670',
#   'comment_ct': '9',
#   'likecount': '102'},
#  {'video_title': "Thank You For The Support | What's Next | Ken Jee | Data Science",
#   'published': '2019-08-26T12:42:32Z',
#   'viewcount': '521',
#   'comment_ct': '29',
#   'likecount': '24'},
#  {'video_title': 'Is Data Science Right For You?',
#   'published': '2019-08-18T16:54:05Z',
#   'viewcount': '51012',
#   'comment_ct': '109',
#   'likecount': '1182'},
#  {'video_title': 'Data Science Fundamentals: Data Cleaning in Python',
#   'published': '2019-08-11T20:50:23Z',
#   'viewcount': '14920',
#   'comment_ct': '55',
#   'likecount': '393'},
#  {'video_title': 'How To Get Data Science Experience (Without a Job)',
#   'published': '2019-08-08T01:58:40Z',
#   'viewcount': '29562',
#   'comment_ct': '77',
#   'likecount': '1388'},
#  {'video_title': 'Take Your Data Science Projects From Good to Great',
#   'published': '2019-08-05T02:34:28Z',
#   'viewcount': '1617',
#   'comment_ct': '11',
#   'likecount': '107'},
#  {'video_title': 'The Projects You Should Do To Get A Data Science Job',
#   'published': '2019-07-30T03:35:48Z',
#   'viewcount': '151145',
#   'comment_ct': '255',
#   'likecount': '5712'},
#  {'video_title': 'What Does a Data Scientist Actually Do?',
#   'published': '2019-07-19T03:18:04Z',
#   'viewcount': '46542',
#   'comment_ct': '81',
#   'likecount': '1272'},
#  {'video_title': 'Data Science Fundamentals: Data Manipulation in Python (Pandas)',
#   'published': '2019-07-13T21:09:41Z',
#   'viewcount': '13020',
#   'comment_ct': '43',
#   'likecount': '352'},
#  {'video_title': 'Data Science Fundamentals: Data Exploration in Python (Pandas)',
#   'published': '2019-07-05T14:29:49Z',
#   'viewcount': '17985',
#   'comment_ct': '61',
#   'likecount': '529'},
#  {'video_title': 'Data Science: Pros and Cons',
#   'published': '2019-06-30T15:26:49Z',
#   'viewcount': '5282',
#   'comment_ct': '18',
#   'likecount': '218'},
#  {'video_title': 'How I Got My First Data Science Internship (And How You Can Land One)',
#   'published': '2019-06-21T04:33:34Z',
#   'viewcount': '24937',
#   'comment_ct': '89',
#   'likecount': '1201'},
#  {'video_title': 'My Top 5 Data Science Internship Tips',
#   'published': '2019-06-15T15:28:26Z',
#   'viewcount': '11956',
#   'comment_ct': '23',
#   'likecount': '496'},
#  {'video_title': 'Golf STATS: Strokes Gained Explained',
#   'published': '2019-06-07T03:10:34Z',
#   'viewcount': '7568',
#   'comment_ct': '28',
#   'likecount': '158'},
#  {'video_title': 'Most Data Science Hopefuls Overlook This Important Skill',
#   'published': '2019-05-25T18:34:33Z',
#   'viewcount': '619',
#   'comment_ct': '5',
#   'likecount': '45'},
#  {'video_title': 'What I Learned From My Three Degrees',
#   'published': '2019-05-17T03:10:29Z',
#   'viewcount': '1272',
#   'comment_ct': '12',
#   'likecount': '61'},
#  {'video_title': 'I Wish I Had Known THIS Before Starting in Data Science',
#   'published': '2019-05-14T00:21:28Z',
#   'viewcount': '25674',
#   'comment_ct': '66',
#   'likecount': '1071'},
#  {'video_title': 'NASA Physicist Turned Data Scientist (Tim Bowling) - KNN EP. 02',
#   'published': '2019-05-05T20:26:36Z',
#   'viewcount': '1254',
#   'comment_ct': '2',
#   'likecount': '40'},
#  {'video_title': 'Should You Learn R for Data Science?',
#   'published': '2019-04-25T15:00:01Z',
#   'viewcount': '21252',
#   'comment_ct': '71',
#   'likecount': '566'},
#  {'video_title': 'Scrape Twitter Data in Python with Twitterscraper Module',
#   'published': '2019-04-18T15:00:14Z',
#   'viewcount': '46452',
#   'comment_ct': '331',
#   'likecount': '855'},
#  {'video_title': 'Work From Home Data Scientist: Day in the Life',
#   'published': '2019-04-12T15:00:00Z',
#   'viewcount': '28115',
#   'comment_ct': '101',
#   'likecount': '758'},
#  {'video_title': 'Where to Look for Data Science Jobs',
#   'published': '2019-03-29T16:00:01Z',
#   'viewcount': '3015',
#   'comment_ct': '9',
#   'likecount': '121'},
#  {'video_title': 'Data Science: Startup vs. Large Corporation',
#   'published': '2019-03-21T17:00:01Z',
#   'viewcount': '2174',
#   'comment_ct': '4',
#   'likecount': '75'},
#  {'video_title': "Data Science, Machine Learning, and AI: What's the Difference?",
#   'published': '2019-03-16T14:00:04Z',
#   'viewcount': '6191',
#   'comment_ct': '26',
#   'likecount': '176'},
#  {'video_title': 'Was Captain Marvel Bad? A Sentiment Analysis of Twitter Data',
#   'published': '2019-03-09T21:58:10Z',
#   'viewcount': '4212',
#   'comment_ct': '15',
#   'likecount': '180'},
#  {'video_title': "Why You DON'T Want to be a WFH Data Scientist",
#   'published': '2019-03-03T22:14:01Z',
#   'viewcount': '809',
#   'comment_ct': '12',
#   'likecount': '33'},
#  {'video_title': 'Welcome To My Channel | Ken Jee | Data Science',
#   'published': '2019-03-03T01:00:17Z',
#   'viewcount': '1441',
#   'comment_ct': '8',
#   'likecount': '36'},
#  {'video_title': 'Where YOU Should Start With Data Science Projects',
#   'published': '2019-02-19T03:23:50Z',
#   'viewcount': '17098',
#   'comment_ct': '17',
#   'likecount': '352'},
#  {'video_title': 'Watch This Before Applying to Data Science Jobs',
#   'published': '2019-02-04T23:40:34Z',
#   'viewcount': '1502',
#   'comment_ct': '13',
#   'likecount': '66'},
#  {'video_title': 'My Top 5 Data Science Resources for 2019',
#   'published': '2019-01-05T22:07:08Z',
#   'viewcount': '3714',
#   'comment_ct': '17',
#   'likecount': '122'},
#  {'video_title': "IT'S NOT TOO LATE TO LEARN CODE!",
#   'published': '2018-12-18T02:01:15Z',
#   'viewcount': '836',
#   'comment_ct': '6',
#   'likecount': '36'},
#  {'video_title': 'The Best Way to Predict NBA Minutes Played',
#   'published': '2018-12-11T02:39:35Z',
#   'viewcount': '4355',
#   'comment_ct': '14',
#   'likecount': '109'},
#  {'video_title': 'Demystifying Data Science Roles',
#   'published': '2018-11-30T01:22:49Z',
#   'viewcount': '1140',
#   'comment_ct': '5',
#   'likecount': '54'},
#  {'video_title': 'How to Simulate NBA Games in Python',
#   'published': '2018-11-19T23:31:49Z',
#   'viewcount': '17782',
#   'comment_ct': '54',
#   'likecount': '394'},
#  {'video_title': 'Should You Get A Masters in Data Science?',
#   'published': '2018-11-14T01:39:33Z',
#   'viewcount': '20607',
#   'comment_ct': '135',
#   'likecount': '305'},
#  {'video_title': 'How I Became A Data Scientist From a Business Background',
#   'published': '2018-11-12T00:26:08Z',
#   'viewcount': '6480',
#   'comment_ct': '23',
#   'likecount': '197'},
#  {'video_title': 'Predicting Season Long NBA Wins Using Multiple Linear Regression',
#   'published': '2018-07-10T16:39:52Z',
#   'viewcount': '8749',
#   'comment_ct': '17',
#   'likecount': '192'},
#  {'video_title': 'Predicting Crypto-Currency Price Using RNN lSTM & GRU',
#   'published': '2017-11-18T20:04:51Z',
#   'viewcount': '18996',
#   'comment_ct': '41',
#   'likecount': '293'}]

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.4.2)

# %%
channel_details
# Out:
# [{'ch_name': 'GUVI',
#   'ch_desc': 'GUVI is an IIT-M & IIM-A incubated edu-tech company that offers Wide range of online Tech courses in your Native language.\nWith 100% placement support, Globally recognized certifications, Mentors from top global product companies  and Platforms improve your Programming and IT skills GUVI does it all. With over 18 Lakh+ learners and 9+ years of experience we provide apex learning through our Edu-tech services, GUVI shares its most loved Tech-videos on YouTube!\n\nWhat’s on our YouTube Channel?\nCareer guidance videos that give an idea for beginners & early professionals to upgrade their careers.\nNew initiatives & offers that unlock your flexible path for learning the latest technologies.\nWalkthrough videos of our practice platforms that shape up your coding & web development skills.\n\nKnow more by visiting our official website - www.guvi.in\n\n',
#   'ch_join': '2012-06-20T09:27:56Z',
#   'subscriber': '179000',
#   'viewer': '3439436',
#   'vi_count': '1284',
#   'playlist_id': 'UUduIoIMfD8tT3KoU0-zBRgQ'},
#  {'ch_name': 'Academind',
#   'ch_desc': "There's always something to learn!\nWe like to learn and love to teach, that's why we create courses and tutorials on many tech-related topics since 2016!\n\nWe teach development and web development (Python, React.js, JavaScript, Next.js, Flutter and many more) but also new technologies like ChatGPT. Check our YouTube channel, official website and social media and start learning today!\n\n🎥 Udemy Courses\nhttps://www.udemy.com/user/academind\n\n👉Academind Pro Membership (50+ courses included)\nhttps://pro.academind.com/\n\n🤝 Social Media\n• Twitter: @maxedapps (https://twitter.com/maxedapps) and @academind_real (https://twitter.com/academind_real)\n• Instagram: @academind_real (https://www.instagram.com/academind_real/)\n• Facebook: academindchannel (https://www.facebook.com/academindchannel)\n\n💻 Academind Official Website\nhttps://academind.com/\n\nSee you in the videos!\n\nImprint: https://academind.com/impressum/en\n",
#   'ch_join': '2015-12-04T12:55:40Z',
#   'subscriber': '889000',
#   'viewer': '73408003',
#   'vi_count': '661',
#   'playlist_id': 'UUSJbGtTlrDami-tDGPUV9-w'},
#  {'ch_name': 'Ken Jee',
#   'ch_desc': 'Hi, I\'m Ken! Data Science, machine learning, AI and Sports Analytics are my passions.  When I was first starting out on my data science journey I was extremely lost. There were very few resources for me to learn about this field from. I decided to start making YouTube videos to share my experiences and to help others learn about data science, machine learning, and AI. \n\nOn this channel I produce fun and informative Data Science content. My goal is to make this field more acessible to everyone through commentary, tutorial, and other educational videos. \n\nI\'ve been working in the data science field doing sports analytics for the last 7 years. I\'ve held data science positions in companies ranging from startups to fortune 100 organizations.  Hopefully my experience will be valuable to you! \n\nCheck out my podcast "Ken\'s Nearest Neighbors" for some great interviews with the best in the field!\n\n',
#   'ch_join': '2014-02-28T14:58:24Z',
#   'subscriber': '253000',
#   'viewer': '8655901',
#   'vi_count': '284',
#   'playlist_id': 'UUiT9RITQ9PW6BhXK0y2jaeg'},
#  {'ch_name': 'ZenClass from GUVI',
#   'ch_desc': 'Welcome to ZenClass Channel! \n\nZen Class is one of the industry’s leading Project-Based Career Program from GUVI - IIT-M Incubated Company. We provide online live classes programs with 100% Job Placement Support.\n\nFull Stack Developer Program - https://bit.ly/3Cc4REq\n\nIIT Certified Programming Professional & Master Data Science - https://bit.ly/3DoUjTC\n\nAutomation Testing Program - https://bit.ly/3wJpAhV\n\nMaster Cyber Security & Ethical Hacking Program - https://bit.ly/30m5spF\n\nCall +91-9344419057 for more details\n',
#   'ch_join': '2019-12-28T03:57:05.532042Z',
#   'subscriber': '8840',
#   'viewer': '724352',
#   'vi_count': '301',
#   'playlist_id': 'UUiEmtpFVJjpvdhsQ2QAhxVA'},
#  {'ch_name': 'Programming with Mosh',
#   'ch_desc': 'I train professional software engineers that companies love to hire. \n\nMy courses: http://codewithmosh.com \n\nMy blog: http://programmingwithmosh.com\n\nConnect on social media: \n\nhttp://www.twitter.com/moshhamedani\n\nhttps://www.facebook.com/programmingwithmosh\n\n#python #javascript #chsarp',
#   'ch_join': '2014-10-07T00:40:53Z',
#   'subscriber': '3590000',
#   'viewer': '180782898',
#   'vi_count': '178',
#   'playlist_id': 'UUWv7vMbMWH4-V0ZXdmDpPBA'}]

# %%
video_det
# Out:
# [{'video_title': 'The Death of the Full-Time Job (Rise of the Contractor)',
#   'published': '2023-09-22T11:46:35Z',
#   'viewcount': '4858',
#   'comment_ct': '70',
#   'likecount': '334'},
#  {'video_title': 'How to Survive a Down Data Job Market',
#   'published': '2023-09-05T10:50:39Z',
#   'viewcount': '15550',
#   'comment_ct': '64',
#   'likecount': '507'},
#  {'video_title': 'The Harsh Reality of the Data Job Market',
#   'published': '2023-08-24T11:30:19Z',
#   'viewcount': '103807',
#   'comment_ct': '293',
#   'likecount': '2522'},
#  {'video_title': '7 Industries AI will Aggressively Disrupt',
#   'published': '2023-08-14T11:30:19Z',
#   'viewcount': '5562',
#   'comment_ct': '41',
#   'likecount': '229'},
#  {'video_title': "What's in My Data Science Travel Bag? (50+ Flights Last Year)",
#   'published': '2023-08-07T17:57:05Z',
#   'viewcount': '3846',
#   'comment_ct': '47',
#   'likecount': '122'},
#  {'video_title': '7 Enticing Jobs AI Will Create',
#   'published': '2023-07-24T12:00:01Z',
#   'viewcount': '4407',
#   'comment_ct': '36',
#   'likecount': '191'},
#  {'video_title': 'The ChatGPT Code Interpreter is OVERRATED',
#   'published': '2023-07-22T09:42:29Z',
#   'viewcount': '3943',
#   'comment_ct': '31',
#   'likecount': '142'},
#  {'video_title': 'Exciting Announcement!',
#   'published': '2023-06-23T17:28:36Z',
#   'viewcount': '6505',
#   'comment_ct': '50',
#   'likecount': '294'},
#  {'video_title': 'AI: A Customer Service Revolution?',
#   'published': '2023-05-26T12:00:21Z',
#   'viewcount': '3739',
#   'comment_ct': '35',
#   'likecount': '117'},
#  {'video_title': 'Beginner Kaggle Data Science Project Walk-Through (Housing Prices) | With ChatGPT',
#   'published': '2023-05-16T12:00:25Z',
#   'viewcount': '26716',
#   'comment_ct': '57',
#   'likecount': '917'},
#  {'video_title': 'How I Would Learn Data Science with AI (If I Could Start Over)',
#   'published': '2023-05-04T12:04:56Z',
#   'viewcount': '31670',
#   'comment_ct': '77',
#   'likecount': '1341'},
#  {'video_title': 'This AI question will determine our future',
#   'published': '2023-04-06T13:00:32Z',
#   'viewcount': '4225',
#   'comment_ct': '37',
#   'likecount': '262'},
#  {'video_title': "I'll Never Code the Same Again... (GPT-4 is OP)",
#   'published': '2023-04-03T13:00:27Z',
#   'viewcount': '70729',
#   'comment_ct': '79',
#   'likecount': '828'},
#  {'video_title': 'Your current portfolio is actually hurting you #shorts',
#   'published': '2023-03-30T13:00:37Z',
#   'viewcount': '6595',
#   'comment_ct': '7',
#   'likecount': '395'},
#  {'video_title': 'Traditional "networking" is stupid. Do THIS instead #shorts',
#   'published': '2023-03-27T13:00:41Z',
#   'viewcount': '6675',
#   'comment_ct': '3',
#   'likecount': '363'},
#  {'video_title': "you're job searching wrong. #shorts",
#   'published': '2023-03-23T13:00:35Z',
#   'viewcount': '4051',
#   'comment_ct': '3',
#   'likecount': '245'},
#  {'video_title': 'The Economics of Data Roles #shorts',
#   'published': '2023-03-21T13:00:15Z',
#   'viewcount': '7929',
#   'comment_ct': '10',
#   'likecount': '506'},
#  {'video_title': 'Why your phone knows everything you say #shorts',
#   'published': '2023-03-18T13:00:42Z',
#   'viewcount': '2683',
#   'comment_ct': '7',
#   'likecount': '120'},
#  {'video_title': 'Read these for a successful career. #shorts',
#   'published': '2023-03-16T01:19:35Z',
#   'viewcount': '2953',
#   'comment_ct': '2',
#   'likecount': '234'},
#  {'video_title': 'Is Your Phone Actually Listening to You? #shorts',
#   'published': '2023-03-09T13:00:01Z',
#   'viewcount': '2398',
#   'comment_ct': '5',
#   'likecount': '44'},
#  {'video_title': 'How I Realized I Was a Bad Manager #shorts',
#   'published': '2023-03-07T13:00:11Z',
#   'viewcount': '2603',
#   'comment_ct': '1',
#   'likecount': '120'},
#  {'video_title': 'How I Use ChatGPT as a Data Scientist (4-5 hrs Saved Per Week)',
#   'published': '2023-03-03T13:00:07Z',
#   'viewcount': '19986',
#   'comment_ct': '52',
#   'likecount': '751'},
#  {'video_title': 'Why I Quit Data Science... and then crawled back #shorts',
#   'published': '2023-03-01T13:00:17Z',
#   'viewcount': '7837',
#   'comment_ct': '13',
#   'likecount': '266'},
#  {'video_title': 'The Best Place to Look for Data Science Opportunities #shorts',
#   'published': '2023-02-27T13:00:32Z',
#   'viewcount': '2546',
#   'comment_ct': '2',
#   'likecount': '160'},
#  {'video_title': 'Learning On the companies dime #shorts',
#   'published': '2023-02-24T17:00:13Z',
#   'viewcount': '3045',
#   'comment_ct': '1',
#   'likecount': '173'},
#  {'video_title': 'The Best Way to Transition to Data Science? #shorts',
#   'published': '2023-02-21T17:13:47Z',
#   'viewcount': '3936',
#   'comment_ct': '6',
#   'likecount': '251'},
#  {'video_title': 'Avoid this Massive Data Science Learning Mistake #shorts',
#   'published': '2023-02-17T13:00:03Z',
#   'viewcount': '6703',
#   'comment_ct': '6',
#   'likecount': '387'},
#  {'video_title': "Don't Go into Data for the Money #shorts",
#   'published': '2023-02-15T10:00:37Z',
#   'viewcount': '3705',
#   'comment_ct': '12',
#   'likecount': '218'},
#  {'video_title': 'First Data Science Project? Watch This.',
#   'published': '2023-02-13T13:00:36Z',
#   'viewcount': '6508',
#   'comment_ct': '22',
#   'likecount': '340'},
#  {'video_title': 'How to Approach Applying for a Data Role #shorts',
#   'published': '2023-02-08T13:00:39Z',
#   'viewcount': '3652',
#   'comment_ct': '7',
#   'likecount': '243'},
#  {'video_title': 'The Hard Reality of Data Science Work #shorts',
#   'published': '2023-02-06T19:35:25Z',
#   'viewcount': '14008',
#   'comment_ct': '14',
#   'likecount': '786'},
#  {'video_title': 'How Much Money Does a Data Scientist Make? #shorts',
#   'published': '2023-02-03T12:00:03Z',
#   'viewcount': '4467',
#   'comment_ct': '6',
#   'likecount': '187'},
#  {'video_title': 'These 3 Things Make Data Science Special #shorts',
#   'published': '2023-02-01T12:00:12Z',
#   'viewcount': '4159',
#   'comment_ct': '7',
#   'likecount': '328'},
#  {'video_title': 'Will Data Science Be Automated? #shorts',
#   'published': '2023-01-27T11:00:44Z',
#   'viewcount': '8724',
#   'comment_ct': '8',
#   'likecount': '386'},
#  {'video_title': 'Is Data Science A Good Fit For You? #shorts',
#   'published': '2023-01-25T11:00:05Z',
#   'viewcount': '4997',
#   'comment_ct': '11',
#   'likecount': '287'},
#  {'video_title': '5 Books I Wish I Read Earlier In My Career',
#   'published': '2023-01-23T15:31:48Z',
#   'viewcount': '9166',
#   'comment_ct': '50',
#   'likecount': '512'},
#  {'video_title': 'How To Start Working on Data Science Projects (As a Beginner) #shorts',
#   'published': '2023-01-19T07:00:06Z',
#   'viewcount': '6140',
#   'comment_ct': '12',
#   'likecount': '554'},
#  {'video_title': 'What Data Science Tool Would I Learn First? #shorts',
#   'published': '2023-01-17T07:00:12Z',
#   'viewcount': '6242',
#   'comment_ct': '10',
#   'likecount': '472'},
#  {'video_title': 'How long does it take to become a Data Scientist? #shorts',
#   'published': '2023-01-12T11:45:02Z',
#   'viewcount': '6244',
#   'comment_ct': '6',
#   'likecount': '471'},
#  {'video_title': 'Where & how to start your Data Science Journey #shorts',
#   'published': '2023-01-09T00:35:13Z',
#   'viewcount': '6651',
#   'comment_ct': '2',
#   'likecount': '410'},
#  {'video_title': 'How I Would NOT Learn Data Science in 2023.',
#   'published': '2023-01-03T13:00:34Z',
#   'viewcount': '124332',
#   'comment_ct': '254',
#   'likecount': '4111'},
#  {'video_title': 'The Greatest Data Science Event You Never Heard Of  [Behind The Scenes]',
#   'published': '2022-12-14T13:00:23Z',
#   'viewcount': '4838',
#   'comment_ct': '28',
#   'likecount': '202'},
#  {'video_title': 'The Essential Programming Concepts For Learning Data Science',
#   'published': '2022-11-14T13:00:02Z',
#   'viewcount': '20375',
#   'comment_ct': '46',
#   'likecount': '847'},
#  {'video_title': 'The Data Content House: What You Missed',
#   'published': '2022-10-07T13:00:04Z',
#   'viewcount': '10436',
#   'comment_ct': '49',
#   'likecount': '348'},
#  {'video_title': 'Is Data Science A Good Career?',
#   'published': '2022-09-29T20:40:31Z',
#   'viewcount': '61060',
#   'comment_ct': '139',
#   'likecount': '1933'},
#  {'video_title': 'IRON ANALYST (Teaser) #shorts',
#   'published': '2022-09-27T17:21:13Z',
#   'viewcount': '5641',
#   'comment_ct': '24',
#   'likecount': '365'},
#  {'video_title': 'When a New Data Scientist Joins The Team',
#   'published': '2022-08-29T13:00:01Z',
#   'viewcount': '16412',
#   'comment_ct': '133',
#   'likecount': '745'},
#  {'video_title': 'State of Data Science - Web Data',
#   'published': '2022-08-05T20:20:04Z',
#   'viewcount': '10433',
#   'comment_ct': '34',
#   'likecount': '359'},
#  {'video_title': 'Data Science Town Hall - State of Data Science',
#   'published': '2022-08-04T18:34:49Z',
#   'viewcount': '9961',
#   'comment_ct': '38',
#   'likecount': '376'},
#  {'video_title': 'The Programming Roadmap For Data Science',
#   'published': '2022-07-29T14:31:33Z',
#   'viewcount': '27329',
#   'comment_ct': '64',
#   'likecount': '1301'},
#  {'video_title': '5 Impactful Data Science Projects For Your Portfolio',
#   'published': '2022-06-27T13:00:10Z',
#   'viewcount': '77723',
#   'comment_ct': '90',
#   'likecount': '2928'},
#  {'video_title': 'Can AI Fix my Baseball Swing?',
#   'published': '2022-06-10T13:00:00Z',
#   'viewcount': '7615',
#   'comment_ct': '68',
#   'likecount': '341'},
#  {'video_title': 'Every Data Scientist... (funny!)',
#   'published': '2022-05-24T13:00:07Z',
#   'viewcount': '16732',
#   'comment_ct': '146',
#   'likecount': '853'},
#  {'video_title': 'State of Data Science (Town Hall) ft - Data Squad',
#   'published': '2022-05-07T22:43:20Z',
#   'viewcount': '15980',
#   'comment_ct': '65',
#   'likecount': '429'},
#  {'video_title': 'Data Science Portfolio Project From Scratch | Building a YouTube Data Dashboard with Streamlit',
#   'published': '2022-04-04T13:00:16Z',
#   'viewcount': '59546',
#   'comment_ct': '87',
#   'likecount': '1524'},
#  {'video_title': 'Why You Are NOT Landing Data Jobs ... Yet',
#   'published': '2022-03-25T13:00:38Z',
#   'viewcount': '21320',
#   'comment_ct': '113',
#   'likecount': '890'},
#  {'video_title': 'Data Scientists VS NFT Scam',
#   'published': '2022-03-03T13:00:36Z',
#   'viewcount': '4645',
#   'comment_ct': '49',
#   'likecount': '189'},
#  {'video_title': 'When a PM Joins the Data Team... (funny!) - Ft @LukeBarousse',
#   'published': '2022-02-21T13:00:03Z',
#   'viewcount': '11173',
#   'comment_ct': '144',
#   'likecount': '510'},
#  {'video_title': 'What Professional Data Scientists ACTUALLY Do',
#   'published': '2022-02-14T13:00:31Z',
#   'viewcount': '95954',
#   'comment_ct': '187',
#   'likecount': '3321'},
#  {'video_title': 'Can You Analyze My Data Better Than I Can?',
#   'published': '2022-01-31T13:00:11Z',
#   'viewcount': '7335',
#   'comment_ct': '62',
#   'likecount': '323'},
#  {'video_title': 'Giving Back to My Most Engaged Subscribers!',
#   'published': '2022-01-28T13:00:01Z',
#   'viewcount': '2331',
#   'comment_ct': '89',
#   'likecount': '119'},
#  {'video_title': 'How to Make $1 Billion Betting on Horse Racing with Machine Learning',
#   'published': '2022-01-24T13:00:09Z',
#   'viewcount': '33163',
#   'comment_ct': '131',
#   'likecount': '949'},
#  {'video_title': 'Should You Be Excited About Web 3? (As a Data Scientist)',
#   'published': '2022-01-17T13:00:00Z',
#   'viewcount': '8854',
#   'comment_ct': '83',
#   'likecount': '424'},
#  {'video_title': 'Should  @LukeBarousse Take This Data Analyst Job? (Funny) #Shorts',
#   'published': '2022-01-14T10:00:02Z',
#   'viewcount': '8526',
#   'comment_ct': '33',
#   'likecount': '253'},
#  {'video_title': 'The Only Data Science Explanation You Need',
#   'published': '2022-01-10T13:00:33Z',
#   'viewcount': '59845',
#   'comment_ct': '172',
#   'likecount': '2234'},
#  {'video_title': 'We Need to Talk About The LinkedIn Machine Learning Assessment.',
#   'published': '2022-01-03T13:00:35Z',
#   'viewcount': '14484',
#   'comment_ct': '144',
#   'likecount': '647'},
#  {'video_title': 'How I Would Learn Data Science in 2022 (If I Had to Start Over)',
#   'published': '2021-12-27T13:00:34Z',
#   'viewcount': '341805',
#   'comment_ct': '536',
#   'likecount': '15006'},
#  {'video_title': 'What the Heck is WSL 2? (My New Favorite Tool)',
#   'published': '2021-12-17T14:00:01Z',
#   'viewcount': '12599',
#   'comment_ct': '67',
#   'likecount': '430'},
#  {'video_title': 'How Statistics Saved the US SERIOUS $$$$ During WW2 #Shorts',
#   'published': '2021-12-10T13:00:22Z',
#   'viewcount': '8023',
#   'comment_ct': '25',
#   'likecount': '571'},
#  {'video_title': 'How Zillow Lost $500 MILLION With Machine Learning',
#   'published': '2021-12-03T13:00:14Z',
#   'viewcount': '24682',
#   'comment_ct': '146',
#   'likecount': '1185'},
#  {'video_title': 'Why Is Data Engineering So HOT Right Now?',
#   'published': '2021-11-26T13:00:22Z',
#   'viewcount': '29515',
#   'comment_ct': '141',
#   'likecount': '1102'},
#  {'video_title': 'Is Data Science Dying?',
#   'published': '2021-11-19T13:00:01Z',
#   'viewcount': '123676',
#   'comment_ct': '363',
#   'likecount': '3882'},
#  {'video_title': '7 Incredible Books That Transformed My Health and My Life',
#   'published': '2021-11-12T13:00:04Z',
#   'viewcount': '8139',
#   'comment_ct': '112',
#   'likecount': '386'},
#  {'video_title': 'Why EVERYONE Should Start a Podcast (Including YOU)',
#   'published': '2021-11-05T13:00:23Z',
#   'viewcount': '3629',
#   'comment_ct': '46',
#   'likecount': '202'},
#  {'video_title': 'Building a Burrito Dashboard - Data Science Project from Scratch with atoti',
#   'published': '2021-10-29T12:00:01Z',
#   'viewcount': '13484',
#   'comment_ct': '39',
#   'likecount': '300'},
#  {'video_title': 'ML Ops: What is it REALLY?',
#   'published': '2021-10-22T13:00:00Z',
#   'viewcount': '6986',
#   'comment_ct': '66',
#   'likecount': '285'},
#  {'video_title': 'Business Skills for Data Science: What are they REALLY?',
#   'published': '2021-10-18T13:00:27Z',
#   'viewcount': '6836',
#   'comment_ct': '50',
#   'likecount': '301'},
#  {'video_title': '#66DaysOfData Round 3 Live Event! (feat. @statquest)',
#   'published': '2021-10-12T16:05:54Z',
#   'viewcount': '2205',
#   'comment_ct': '5',
#   'likecount': '123'},
#  {'video_title': 'Roasting My First Data Science Project (Common Project Mistakes)',
#   'published': '2021-10-08T13:00:15Z',
#   'viewcount': '5941',
#   'comment_ct': '64',
#   'likecount': '283'},
#  {'video_title': "Is Data Visualization Important for Data Science? (A Data Scientist's Perspective)",
#   'published': '2021-08-20T13:00:20Z',
#   'viewcount': '12861',
#   'comment_ct': '112',
#   'likecount': '530'},
#  {'video_title': 'Project Presentation - Expectations vs. Reality (funny) #shorts',
#   'published': '2021-08-07T14:00:11Z',
#   'viewcount': '10225',
#   'comment_ct': '32',
#   'likecount': '434'},
#  {'video_title': 'Data Science Project - Expectations vs Reality (funny) #shorts',
#   'published': '2021-08-06T23:04:24Z',
#   'viewcount': '41365',
#   'comment_ct': '32',
#   'likecount': '1605'},
#  {'video_title': 'How I Learned to Learn.',
#   'published': '2021-07-31T13:00:26Z',
#   'viewcount': '50849',
#   'comment_ct': '209',
#   'likecount': '2367'},
#  {'video_title': 'Is Spotify Shuffle Really Random? #Shorts',
#   'published': '2021-07-21T13:00:21Z',
#   'viewcount': '10732',
#   'comment_ct': '50',
#   'likecount': '588'},
#  {'video_title': 'I Eat a Papaya Live on Stream (Plus Q&A for 150K Subs!)',
#   'published': '2021-07-16T21:30:26Z',
#   'viewcount': '2409',
#   'comment_ct': '30',
#   'likecount': '93'},
#  {'video_title': 'Why are APIs Important for Data Science?',
#   'published': '2021-07-09T13:00:32Z',
#   'viewcount': '9982',
#   'comment_ct': '95',
#   'likecount': '455'},
#  {'video_title': 'Is Your Phone REALLY Listening to You?',
#   'published': '2021-07-03T13:00:31Z',
#   'viewcount': '5187',
#   'comment_ct': '116',
#   'likecount': '279'},
#  {'video_title': 'Kaggle vs Github - Which is Best for Your Data Science Portfolio?',
#   'published': '2021-06-25T13:00:12Z',
#   'viewcount': '15508',
#   'comment_ct': '123',
#   'likecount': '611'},
#  {'video_title': '#66DaysOfData - 3 Reasons to Start!',
#   'published': '2021-06-18T13:00:32Z',
#   'viewcount': '4098',
#   'comment_ct': '41',
#   'likecount': '224'},
#  {'video_title': '#66DaysOfData - What is it? #shorts',
#   'published': '2021-06-11T12:48:29Z',
#   'viewcount': '9221',
#   'comment_ct': '54',
#   'likecount': '395'},
#  {'video_title': 'A Quick Data Science Project Tip! #SHORTS',
#   'published': '2021-06-03T13:00:06Z',
#   'viewcount': '16683',
#   'comment_ct': '89',
#   'likecount': '1020'},
#  {'video_title': 'Discouraged with Data Science? - Watch THIS video.',
#   'published': '2021-05-28T13:00:02Z',
#   'viewcount': '7467',
#   'comment_ct': '195',
#   'likecount': '393'},
#  {'video_title': 'How Data Science Projects Pay Off',
#   'published': '2021-05-22T13:30:03Z',
#   'viewcount': '10736',
#   'comment_ct': '146',
#   'likecount': '601'},
#  {'video_title': 'How I Use Data to Optimize My Life | What I Collect & How I Analyze It',
#   'published': '2021-05-14T13:00:03Z',
#   'viewcount': '10622',
#   'comment_ct': '134',
#   'likecount': '491'},
#  {'video_title': 'What is a lambda function (python)? #shorts',
#   'published': '2021-05-13T00:38:55Z',
#   'viewcount': '15449',
#   'comment_ct': '49',
#   'likecount': '949'},
#  {'video_title': 'Why Kaggle Should Be Your Favorite Data Science Resource #shorts',
#   'published': '2021-05-07T13:00:30Z',
#   'viewcount': '30531',
#   'comment_ct': '64',
#   'likecount': '1619'},
#  {'video_title': 'What is Pandas? (Data & Data Science) #shorts',
#   'published': '2021-04-30T13:00:07Z',
#   'viewcount': '23840',
#   'comment_ct': '87',
#   'likecount': '1226'},
#  {'video_title': 'The 7 Biggest Data Science  Beginner Mistakes',
#   'published': '2021-04-23T13:00:14Z',
#   'viewcount': '77224',
#   'comment_ct': '284',
#   'likecount': '3433'},
#  {'video_title': 'Data Scientist Reacts: REAL Data Science Job Application Data',
#   'published': '2021-04-16T13:00:00Z',
#   'viewcount': '23502',
#   'comment_ct': '85',
#   'likecount': '694'},
#  {'video_title': "Why You Probably Won't Become a Data Scientist",
#   'published': '2021-04-09T13:00:31Z',
#   'viewcount': '138369',
#   'comment_ct': '481',
#   'likecount': '4042'},
#  {'video_title': 'How to Go From Data Analyst to Data Scientist',
#   'published': '2021-04-02T13:00:14Z',
#   'viewcount': '53849',
#   'comment_ct': '177',
#   'likecount': '1543'},
#  {'video_title': 'Why I Have 2 Offices for Data Science & Content Creation',
#   'published': '2021-03-26T13:00:03Z',
#   'viewcount': '3983',
#   'comment_ct': '92',
#   'likecount': '138'},
#  {'video_title': 'MARCH MADNESS - Will My Machine Learning Model Beat Your Bracket?',
#   'published': '2021-03-19T13:00:32Z',
#   'viewcount': '18197',
#   'comment_ct': '108',
#   'likecount': '350'},
#  {'video_title': 'My Regrets as a Data Science Student',
#   'published': '2021-03-12T13:00:27Z',
#   'viewcount': '23944',
#   'comment_ct': '112',
#   'likecount': '882'},
#  {'video_title': 'My Daily Battle With Time - Will I Win? [Vlog]',
#   'published': '2021-03-08T13:00:06Z',
#   'viewcount': '3833',
#   'comment_ct': '83',
#   'likecount': '196'},
#  {'video_title': 'What is the Future of my Comment Leaderboard Project?',
#   'published': '2021-02-26T14:00:15Z',
#   'viewcount': '5573',
#   'comment_ct': '81',
#   'likecount': '201'},
#  {'video_title': 'How to Build a Website  - Building my ULTIMATE Portfolio Website',
#   'published': '2021-02-19T13:00:14Z',
#   'viewcount': '6765',
#   'comment_ct': '51',
#   'likecount': '174'},
#  {'video_title': 'Why I Quit Data Science',
#   'published': '2021-02-12T13:00:19Z',
#   'viewcount': '104805',
#   'comment_ct': '347',
#   'likecount': '2350'},
#  {'video_title': '🌶 Hot Topics in Tech: Data Science Explained #SHORTS',
#   'published': '2021-01-29T13:00:06Z',
#   'viewcount': '10711',
#   'comment_ct': '116',
#   'likecount': '556'},
#  {'video_title': 'How I Balance Data Science and Content Creation (7 Secrets)',
#   'published': '2021-01-23T14:00:30Z',
#   'viewcount': '6998',
#   'comment_ct': '126',
#   'likecount': '294'},
#  {'video_title': 'Kaggle Project From Scratch - Part 3 (Advanced Graphs & Gender Imbalance Analysis)',
#   'published': '2021-01-16T14:00:10Z',
#   'viewcount': '9761',
#   'comment_ct': '52',
#   'likecount': '301'},
#  {'video_title': 'Kaggle Project From Scratch - Part 2 (Exploratory Data Analysis)',
#   'published': '2021-01-08T13:00:16Z',
#   'viewcount': '22764',
#   'comment_ct': '134',
#   'likecount': '697'},
#  {'video_title': 'Kaggle Project From Scratch - Part 1 (Data Science Profession Survey)',
#   'published': '2021-01-02T14:00:26Z',
#   'viewcount': '37925',
#   'comment_ct': '147',
#   'likecount': '1139'},
#  {'video_title': 'What is the #66DaysOfData?',
#   'published': '2020-12-26T14:00:31Z',
#   'viewcount': '70016',
#   'comment_ct': '202',
#   'likecount': '2325'},
#  {'video_title': 'How I Would Learn Data Science in 2021 (What Has Changed?)',
#   'published': '2020-12-19T14:00:01Z',
#   'viewcount': '131497',
#   'comment_ct': '488',
#   'likecount': '5970'},
#  {'video_title': 'Unboxing the Ultimate Z by HP Data Science Package (FIRST EVER HP Workstation w/ Data Science Stack)',
#   'published': '2020-12-10T13:00:09Z',
#   'viewcount': '10933',
#   'comment_ct': '133',
#   'likecount': '398'},
#  {'video_title': 'I Built the FIRST EVER YouTube Subscriber LEADERBOARD',
#   'published': '2020-12-07T14:00:11Z',
#   'viewcount': '23525',
#   'comment_ct': '326',
#   'likecount': '727'},
#  {'video_title': '7 Things to Look For in a Masters For Data Science (feat. @TinaHuang1)',
#   'published': '2020-11-20T13:00:26Z',
#   'viewcount': '28078',
#   'comment_ct': '160',
#   'likecount': '857'},
#  {'video_title': '6 Lessons from #66DaysOfData',
#   'published': '2020-11-13T13:00:02Z',
#   'viewcount': '6733',
#   'comment_ct': '93',
#   'likecount': '340'},
#  {'video_title': '100K Channel Update + AMA Stream!',
#   'published': '2020-11-12T17:34:26Z',
#   'viewcount': '2319',
#   'comment_ct': '22',
#   'likecount': '127'},
#  {'video_title': 'Find a Data Science Project With These 3 Techniques',
#   'published': '2020-11-06T13:00:13Z',
#   'viewcount': '16816',
#   'comment_ct': '106',
#   'likecount': '727'},
#  {'video_title': 'How I Chose My Masters Degree for Breaking into Data Science',
#   'published': '2020-10-30T14:00:07Z',
#   'viewcount': '27303',
#   'comment_ct': '155',
#   'likecount': '678'},
#  {'video_title': 'git for Data Science Made Simple... (Hopefully)',
#   'published': '2020-10-23T15:00:10Z',
#   'viewcount': '19916',
#   'comment_ct': '92',
#   'likecount': '871'},
#  {'video_title': 'The PODCAST you might have asked for?',
#   'published': '2020-10-19T15:00:11Z',
#   'viewcount': '2118',
#   'comment_ct': '44',
#   'likecount': '94'},
#  {'video_title': 'Dealing with Doubt in Data Science (My Impostor Syndrome Story)',
#   'published': '2020-10-16T15:00:18Z',
#   'viewcount': '6747',
#   'comment_ct': '113',
#   'likecount': '448'},
#  {'video_title': 'Advice from a Data Analytics CEO (@How to Get an Analytics Job) - KNN EP. 17',
#   'published': '2020-10-14T15:00:11Z',
#   'viewcount': '14290',
#   'comment_ct': '47',
#   'likecount': '417'},
#  {'video_title': 'Data Science Resume Round-Up With @Tina Huang  | Episode 3',
#   'published': '2020-10-12T15:00:00Z',
#   'viewcount': '6834',
#   'comment_ct': '62',
#   'likecount': '143'},
#  {'video_title': '5 Unusual Data Science Projects that Will Land You a Job',
#   'published': '2020-10-09T15:00:09Z',
#   'viewcount': '11747',
#   'comment_ct': '83',
#   'likecount': '567'},
#  {'video_title': 'Sh*t Data Scientists Say (Parody)',
#   'published': '2020-10-05T15:00:08Z',
#   'viewcount': '9531',
#   'comment_ct': '144',
#   'likecount': '579'},
#  {'video_title': '5 Proven Strategies to Break into a Data Science Job',
#   'published': '2020-10-02T15:00:08Z',
#   'viewcount': '8620',
#   'comment_ct': '93',
#   'likecount': '366'},
#  {'video_title': 'Why Data-Viz is so Darn Important (@Story by Data | Kate Strachnyi) - KNN EP. 16',
#   'published': '2020-09-30T15:00:09Z',
#   'viewcount': '7072',
#   'comment_ct': '61',
#   'likecount': '287'},
#  {'video_title': 'Data Science Resume Round-Up With @TinaHuang1  - Episode 1',
#   'published': '2020-09-28T15:00:04Z',
#   'viewcount': '11716',
#   'comment_ct': '69',
#   'likecount': '292'},
#  {'video_title': '5 Essential Data Science Projects for Your Portfolio',
#   'published': '2020-09-26T15:00:06Z',
#   'viewcount': '73054',
#   'comment_ct': '206',
#   'likecount': '3106'},
#  {'video_title': 'His Startup Will Land You a Data Science Job (Jeremie Harris) - KNN EP. 15',
#   'published': '2020-09-23T15:00:02Z',
#   'viewcount': '5185',
#   'comment_ct': '64',
#   'likecount': '198'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 21(The Cleanest Portfolio)',
#   'published': '2020-09-21T15:00:03Z',
#   'viewcount': '12223',
#   'comment_ct': '58',
#   'likecount': '469'},
#  {'video_title': 'Hedge Funds, Startups, and Data Science Oh my! (@DataLeap) - KNN EP. 14',
#   'published': '2020-09-18T16:00:10Z',
#   'viewcount': '7451',
#   'comment_ct': '34',
#   'likecount': '253'},
#  {'video_title': 'Land a Data Science Job in a Different Country (Vijay Pravin Maharajan) - KNN EP. 13',
#   'published': '2020-09-16T15:00:24Z',
#   'viewcount': '5109',
#   'comment_ct': '56',
#   'likecount': '194'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 20 (Bootcamp Capstone)',
#   'published': '2020-09-14T15:00:00Z',
#   'viewcount': '4281',
#   'comment_ct': '35',
#   'likecount': '157'},
#  {'video_title': 'The 5 Pillars of Success I Live By',
#   'published': '2020-09-11T15:00:11Z',
#   'viewcount': '10139',
#   'comment_ct': '152',
#   'likecount': '873'},
#  {'video_title': 'Fast Cars to Faster Data (Alex Castrounis) - KNN EP. 12',
#   'published': '2020-09-09T15:00:12Z',
#   'viewcount': '1891',
#   'comment_ct': '25',
#   'likecount': '78'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 19 (One Big Improvement)',
#   'published': '2020-09-07T15:00:30Z',
#   'viewcount': '4039',
#   'comment_ct': '43',
#   'likecount': '163'},
#  {'video_title': "How I Learn Data Science Through Studying Other People's Code | #66DaysOfData",
#   'published': '2020-09-04T15:00:00Z',
#   'viewcount': '11822',
#   'comment_ct': '144',
#   'likecount': '737'},
#  {'video_title': 'How She Dominated the FAANG Data Science Interview  (@TinaHuang1 ) - KNN EP. 11',
#   'published': '2020-09-02T15:00:13Z',
#   'viewcount': '17965',
#   'comment_ct': '89',
#   'likecount': '572'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 18 (Job-Worthy GitHub)',
#   'published': '2020-08-31T15:00:15Z',
#   'viewcount': '17993',
#   'comment_ct': '93',
#   'likecount': '794'},
#  {'video_title': "Why I'm Starting Data Science Over Again.",
#   'published': '2020-08-29T15:30:10Z',
#   'viewcount': '50754',
#   'comment_ct': '450',
#   'likecount': '2603'},
#  {'video_title': 'Inside the Mind of the Ultimate Kaggle Grandmaster (@Abhishek Thakur ) - KNN EP. 10',
#   'published': '2020-08-26T15:00:03Z',
#   'viewcount': '15174',
#   'comment_ct': '77',
#   'likecount': '632'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 17 (Best Portfolio Website Yet?)',
#   'published': '2020-08-24T15:00:31Z',
#   'viewcount': '12941',
#   'comment_ct': '55',
#   'likecount': '462'},
#  {'video_title': "Don't Buy My Course..",
#   'published': '2020-08-21T16:00:32Z',
#   'viewcount': '7339',
#   'comment_ct': '146',
#   'likecount': '359'},
#  {'video_title': 'How a Subscriber Landed a Data Analyst Job in Less Than a Year (Ray Ojel) - KNN EP. 09',
#   'published': '2020-08-19T15:00:11Z',
#   'viewcount': '29112',
#   'comment_ct': '166',
#   'likecount': '1115'},
#  {'video_title': 'Reviewing Your Projects - Episode 16 (Project Review for Beginners)',
#   'published': '2020-08-17T15:00:07Z',
#   'viewcount': '3241',
#   'comment_ct': '40',
#   'likecount': '128'},
#  {'video_title': 'Data Scientist Dismantles the YouTube Algorithm.',
#   'published': '2020-08-14T15:00:31Z',
#   'viewcount': '6322',
#   'comment_ct': '108',
#   'likecount': '539'},
#  {'video_title': 'Sports Analytics & Streaming Data Science on Twitch (Nick Wan) - KNN EP. 08',
#   'published': '2020-08-12T15:30:26Z',
#   'viewcount': '5000',
#   'comment_ct': '39',
#   'likecount': '183'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 15 (Quant Finance)',
#   'published': '2020-08-10T15:00:08Z',
#   'viewcount': '12409',
#   'comment_ct': '53',
#   'likecount': '391'},
#  {'video_title': 'The Plagiarism Problem in Data Science',
#   'published': '2020-08-07T15:00:16Z',
#   'viewcount': '13075',
#   'comment_ct': '145',
#   'likecount': '629'},
#  {'video_title': 'Interview with the Director of AI Research @ NVIDIA (Anima Anandkumar) - KNN EP. 07',
#   'published': '2020-08-05T15:00:09Z',
#   'viewcount': '14426',
#   'comment_ct': '89',
#   'likecount': '602'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 14 [Deep Learning Focus]',
#   'published': '2020-08-03T15:00:08Z',
#   'viewcount': '4916',
#   'comment_ct': '56',
#   'likecount': '187'},
#  {'video_title': 'My First Data Science Contracting Side-Gig (How I Did It)',
#   'published': '2020-07-31T14:30:01Z',
#   'viewcount': '11428',
#   'comment_ct': '90',
#   'likecount': '582'},
#  {'video_title': 'Do You Have a Data Science Mentor? (@Danny Ma) - KNN EP. 06',
#   'published': '2020-07-30T01:00:10Z',
#   'viewcount': '2321',
#   'comment_ct': '34',
#   'likecount': '116'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 13 (BONUS LinkedIn Review)',
#   'published': '2020-07-27T15:00:30Z',
#   'viewcount': '5620',
#   'comment_ct': '112',
#   'likecount': '251'},
#  {'video_title': 'Building a Deep Learning BEAST (NVIDIA TITAN RTX + RYZEN 3900X)',
#   'published': '2020-07-24T15:00:11Z',
#   'viewcount': '8218',
#   'comment_ct': '199',
#   'likecount': '246'},
#  {'video_title': 'Is it Important to Share Your Data Science Work? (Ft. Eric Weber)',
#   'published': '2020-07-22T15:00:05Z',
#   'viewcount': '1858',
#   'comment_ct': '27',
#   'likecount': '98'},
#  {'video_title': 'Reviewing Your Data Science Resumes - Episode 12 (3 Different Resumes!)',
#   'published': '2020-07-20T15:00:08Z',
#   'viewcount': '29145',
#   'comment_ct': '90',
#   'likecount': '565'},
#  {'video_title': 'Beginner Kaggle Data Science Project Walk-Through (Titanic)',
#   'published': '2020-07-17T16:00:05Z',
#   'viewcount': '332261',
#   'comment_ct': '425',
#   'likecount': '7352'},
#  {'video_title': 'Uber Driver to Machine Learning Engineer in 9 Months! (@Daniel Bourke) - KNN EP. 05',
#   'published': '2020-07-16T02:00:09Z',
#   'viewcount': '30310',
#   'comment_ct': '121',
#   'likecount': '1125'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 11(GITHUB CLEANING)',
#   'published': '2020-07-13T16:00:01Z',
#   'viewcount': '3637',
#   'comment_ct': '50',
#   'likecount': '135'},
#  {'video_title': 'The Best Computer for Data Science Beginners',
#   'published': '2020-07-10T16:00:09Z',
#   'viewcount': '38288',
#   'comment_ct': '158',
#   'likecount': '854'},
#  {'video_title': 'Should You Major in Data Science? (Jaemin Lee) - KNN EP. 04',
#   'published': '2020-07-08T21:00:09Z',
#   'viewcount': '6167',
#   'comment_ct': '82',
#   'likecount': '231'},
#  {'video_title': 'Critiquing MY OWN Data Science Resume',
#   'published': '2020-07-06T16:00:30Z',
#   'viewcount': '12663',
#   'comment_ct': '88',
#   'likecount': '397'},
#  {'video_title': 'Where to Start Learning Data Science',
#   'published': '2020-07-03T16:00:04Z',
#   'viewcount': '18802',
#   'comment_ct': '127',
#   'likecount': '784'},
#  {'video_title': 'Data Science Productivity, Motivation, and Organization (ft. Data Professor & Codebasics)',
#   'published': '2020-07-01T15:00:12Z',
#   'viewcount': '4155',
#   'comment_ct': '37',
#   'likecount': '197'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 10 (Leveraging Your Data)',
#   'published': '2020-06-29T15:00:08Z',
#   'viewcount': '4596',
#   'comment_ct': '52',
#   'likecount': '176'},
#  {'video_title': 'How to Get a Data Science Job at FAANG (@Data Science Jay) - KNN EP. 03',
#   'published': '2020-06-26T15:00:10Z',
#   'viewcount': '16436',
#   'comment_ct': '79',
#   'likecount': '550'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 9 (Professional Violinist)',
#   'published': '2020-06-22T13:00:03Z',
#   'viewcount': '2415',
#   'comment_ct': '40',
#   'likecount': '82'},
#  {'video_title': 'Ken Jee Q & A Live Stream (50,000 Sub Special!)',
#   'published': '2020-06-20T02:09:18Z',
#   'viewcount': '2386',
#   'comment_ct': '49',
#   'likecount': '139'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 8 (College Student Help)',
#   'published': '2020-06-15T13:00:12Z',
#   'viewcount': '4369',
#   'comment_ct': '46',
#   'likecount': '169'},
#  {'video_title': "Why You're Struggling to Learn Data Science",
#   'published': '2020-06-12T13:00:17Z',
#   'viewcount': '15255',
#   'comment_ct': '159',
#   'likecount': '1010'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 7 (Incredible Portfolio Website)',
#   'published': '2020-06-08T13:00:21Z',
#   'viewcount': '11785',
#   'comment_ct': '70',
#   'likecount': '359'},
#  {'video_title': 'The State of Data Science with Krish Naik & The Data Professor [Panel Discussion]',
#   'published': '2020-06-05T13:00:26Z',
#   'viewcount': '23911',
#   'comment_ct': '146',
#   'likecount': '687'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 6 (Only 3 months of coding experience)',
#   'published': '2020-06-01T13:00:32Z',
#   'viewcount': '5706',
#   'comment_ct': '53',
#   'likecount': '154'},
#  {'video_title': 'How to Build a Data Science Portfolio Website with Hugo & Github Pages [feat. Data Professor]',
#   'published': '2020-05-29T13:00:21Z',
#   'viewcount': '72797',
#   'comment_ct': '269',
#   'likecount': '2199'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 5 (Very Detailed Project)',
#   'published': '2020-05-25T13:00:13Z',
#   'viewcount': '20981',
#   'comment_ct': '81',
#   'likecount': '489'},
#  {'video_title': 'Different Data Science Roles Explained (by a Data Scientist)',
#   'published': '2020-05-22T13:01:09Z',
#   'viewcount': '55466',
#   'comment_ct': '178',
#   'likecount': '1973'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 4 (Resume & Github)',
#   'published': '2020-05-18T13:00:22Z',
#   'viewcount': '11251',
#   'comment_ct': '53',
#   'likecount': '178'},
#  {'video_title': 'How to Make A Data Science Portfolio Website with Github Pages',
#   'published': '2020-05-15T13:30:00Z',
#   'viewcount': '130396',
#   'comment_ct': '193',
#   'likecount': '4440'},
#  {'video_title': '10000 Subscriber and 100th Video Special (Data Science)',
#   'published': '2020-05-13T13:00:17Z',
#   'viewcount': '3100',
#   'comment_ct': '115',
#   'likecount': '147'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 3 (Student Portfolio)',
#   'published': '2020-05-11T13:00:33Z',
#   'viewcount': '4522',
#   'comment_ct': '74',
#   'likecount': '153'},
#  {'video_title': 'How I Would Learn Data Science (If I Had to Start Over)',
#   'published': '2020-05-08T13:00:03Z',
#   'viewcount': '1395164',
#   'comment_ct': '1994',
#   'likecount': '49025'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 2 (Resume and Portfolio)',
#   'published': '2020-05-04T13:00:12Z',
#   'viewcount': '5546',
#   'comment_ct': '42',
#   'likecount': '196'},
#  {'video_title': 'What You Need to Know for a Data Science Internship',
#   'published': '2020-05-01T13:00:10Z',
#   'viewcount': '22160',
#   'comment_ct': '60',
#   'likecount': '1208'},
#  {'video_title': 'Reviewing Your Data Science Projects - Episode 1 (Exploratory Analysis)',
#   'published': '2020-04-27T13:00:10Z',
#   'viewcount': '8362',
#   'comment_ct': '54',
#   'likecount': '350'},
#  {'video_title': "What It's Like to be a Socially Distanced Data Scientist (A Day in the Life)",
#   'published': '2020-04-24T13:00:32Z',
#   'viewcount': '14983',
#   'comment_ct': '103',
#   'likecount': '458'},
#  {'video_title': 'Data Science in Sports - Talk for Northwestern (Kellogg) MBA Students',
#   'published': '2020-04-22T13:00:30Z',
#   'viewcount': '3132',
#   'comment_ct': '24',
#   'likecount': '85'},
#  {'video_title': '5 Tips for Crushing the Work From Home Life',
#   'published': '2020-04-20T13:00:04Z',
#   'viewcount': '5424',
#   'comment_ct': '38',
#   'likecount': '203'},
#  {'video_title': 'Data Science Project from Scratch - Part 7 (Documenting Your Work)',
#   'published': '2020-04-17T13:00:04Z',
#   'viewcount': '21565',
#   'comment_ct': '129',
#   'likecount': '740'},
#  {'video_title': 'Data Science Project from Scratch -  Part 6 (Putting the Model into Production)',
#   'published': '2020-04-15T13:00:32Z',
#   'viewcount': '29530',
#   'comment_ct': '98',
#   'likecount': '734'},
#  {'video_title': 'Data Science Project from Scratch  - Part 5 (Model Building)',
#   'published': '2020-04-13T13:00:03Z',
#   'viewcount': '44217',
#   'comment_ct': '154',
#   'likecount': '907'},
#  {'video_title': 'Data Science Project from Scratch - Part 4 (Exploratory Data Analysis)',
#   'published': '2020-04-10T13:00:15Z',
#   'viewcount': '72584',
#   'comment_ct': '213',
#   'likecount': '1890'},
#  {'video_title': 'Data Science Project from Scratch - Part 3 (Data Cleaning)',
#   'published': '2020-04-08T13:00:19Z',
#   'viewcount': '80915',
#   'comment_ct': '277',
#   'likecount': '1759'},
#  {'video_title': 'Data Science Project from Scratch - Part 2 (Data Collection)',
#   'published': '2020-04-06T13:00:07Z',
#   'viewcount': '128706',
#   'comment_ct': '620',
#   'likecount': '3498'},
#  {'video_title': 'Data Science Project from Scratch - Part 1 (Project Planning)',
#   'published': '2020-04-03T13:00:12Z',
#   'viewcount': '197765',
#   'comment_ct': '175',
#   'likecount': '5045'},
#  {'video_title': 'When Data Science Goes Wrong',
#   'published': '2020-03-30T13:00:06Z',
#   'viewcount': '1807',
#   'comment_ct': '32',
#   'likecount': '106'},
#  {'video_title': 'How to ULTRALEARN Data Science',
#   'published': '2020-03-27T13:00:02Z',
#   'viewcount': '61898',
#   'comment_ct': '169',
#   'likecount': '3822'},
#  {'video_title': 'Why Right NOW is a Great Time to Learn Data Science',
#   'published': '2020-03-23T13:00:30Z',
#   'viewcount': '4430',
#   'comment_ct': '50',
#   'likecount': '268'},
#  {'video_title': 'Data Science Project Example Start to Finish (Deep Learning Image Classifier)',
#   'published': '2020-03-20T13:00:22Z',
#   'viewcount': '13021',
#   'comment_ct': '45',
#   'likecount': '468'},
#  {'video_title': "The Secret Data Scientists Don't Want You to Know",
#   'published': '2020-03-16T13:00:23Z',
#   'viewcount': '10760',
#   'comment_ct': '103',
#   'likecount': '1139'},
#  {'video_title': 'The 5 Stages of Learning Data Science',
#   'published': '2020-03-13T13:00:26Z',
#   'viewcount': '17509',
#   'comment_ct': '78',
#   'likecount': '1296'},
#  {'video_title': 'Can You Learn Data Science Without a Computer?',
#   'published': '2020-03-11T13:00:03Z',
#   'viewcount': '1705',
#   'comment_ct': '14',
#   'likecount': '117'},
#  {'video_title': 'The Best Free Data Science Courses Nobody is Talking About',
#   'published': '2020-03-09T13:00:04Z',
#   'viewcount': '346846',
#   'comment_ct': '620',
#   'likecount': '21220'},
#  {'video_title': 'The Data Science Projects that Got Me a Job',
#   'published': '2020-03-06T14:00:11Z',
#   'viewcount': '40978',
#   'comment_ct': '41',
#   'likecount': '1399'},
#  {'video_title': 'How to Integrate Data Science into Your Business',
#   'published': '2020-03-02T14:00:01Z',
#   'viewcount': '3378',
#   'comment_ct': '18',
#   'likecount': '129'},
#  {'video_title': 'The Problem with Data Science',
#   'published': '2020-02-28T14:00:07Z',
#   'viewcount': '3792',
#   'comment_ct': '19',
#   'likecount': '154'},
#  {'video_title': 'How Much Did Cheating Help the Astros Win? (What the Numbers Say)',
#   'published': '2020-02-24T14:00:00Z',
#   'viewcount': '1170',
#   'comment_ct': '16',
#   'likecount': '46'},
#  {'video_title': 'How to Set Up Your Data Science Environment (Anaconda Beginner)',
#   'published': '2020-02-21T14:00:02Z',
#   'viewcount': '128703',
#   'comment_ct': '97',
#   'likecount': '2462'},
#  {'video_title': '3 Proven Data Science Projects for Beginners (Kaggle)',
#   'published': '2020-02-17T14:00:04Z',
#   'viewcount': '327153',
#   'comment_ct': '525',
#   'likecount': '17780'},
#  {'video_title': 'Data Science Advice for College Students',
#   'published': '2020-02-14T17:22:37Z',
#   'viewcount': '68934',
#   'comment_ct': '197',
#   'likecount': '1964'},
#  {'video_title': 'Avoid These Data Science Resume Mistakes!',
#   'published': '2020-02-10T15:52:59Z',
#   'viewcount': '28425',
#   'comment_ct': '62',
#   'likecount': '1243'},
#  {'video_title': 'Data Science Explained with ... Cooking?',
#   'published': '2020-02-07T15:56:55Z',
#   'viewcount': '5303',
#   'comment_ct': '48',
#   'likecount': '315'},
#  {'video_title': 'The 4 Types of Sports Analytics Projects',
#   'published': '2020-02-03T16:35:19Z',
#   'viewcount': '31378',
#   'comment_ct': '62',
#   'likecount': '1023'},
#  {'video_title': 'Data Science in Golf: PGA Merchandise Show 2020',
#   'published': '2020-01-31T18:50:23Z',
#   'viewcount': '587',
#   'comment_ct': '13',
#   'likecount': '18'},
#  {'video_title': 'How I Learned Data Science',
#   'published': '2020-01-27T14:41:18Z',
#   'viewcount': '94122',
#   'comment_ct': '210',
#   'likecount': '2695'},
#  {'video_title': 'What is Sports Analytics Really?',
#   'published': '2020-01-20T14:00:00Z',
#   'viewcount': '21336',
#   'comment_ct': '73',
#   'likecount': '614'},
#  {'video_title': 'Data Science Certificate vs Bootcamp vs Masters Degree',
#   'published': '2020-01-18T01:03:08Z',
#   'viewcount': '111246',
#   'comment_ct': '582',
#   'likecount': '3137'},
#  {'video_title': 'How To Learn Programming for Data Science [3 Steps]',
#   'published': '2020-01-13T16:48:44Z',
#   'viewcount': '30092',
#   'comment_ct': '96',
#   'likecount': '1979'},
#  {'video_title': 'Data Science Fundamentals: SQL Queries',
#   'published': '2020-01-10T19:15:01Z',
#   'viewcount': '6502',
#   'comment_ct': '35',
#   'likecount': '214'},
#  {'video_title': 'Questions You Should Ask Your Data Science Interviewers',
#   'published': '2020-01-06T14:00:04Z',
#   'viewcount': '3147',
#   'comment_ct': '14',
#   'likecount': '152'},
#  {'video_title': 'The 9 Books That Changed My Perspective in 2019',
#   'published': '2020-01-03T14:45:28Z',
#   'viewcount': '3392',
#   'comment_ct': '25',
#   'likecount': '180'},
#  {'video_title': 'The Data Science Interview: What to Expect',
#   'published': '2019-12-30T14:00:01Z',
#   'viewcount': '8563',
#   'comment_ct': '32',
#   'likecount': '380'},
#  {'video_title': '5 Data Science Resolutions for 2020',
#   'published': '2019-12-27T14:00:07Z',
#   'viewcount': '475',
#   'comment_ct': '12',
#   'likecount': '25'},
#  {'video_title': 'How to Scrape NBA Data Using the nba_api Python Module',
#   'published': '2019-12-23T12:59:47Z',
#   'viewcount': '16830',
#   'comment_ct': '93',
#   'likecount': '595'},
#  {'video_title': 'Collision Course: Sports Betting + Data Science',
#   'published': '2019-12-20T14:00:02Z',
#   'viewcount': '18107',
#   'comment_ct': '27',
#   'likecount': '505'},
#  {'video_title': '3 Reasons You Should NOT Become a Data Scientist',
#   'published': '2019-12-16T18:46:58Z',
#   'viewcount': '100960',
#   'comment_ct': '204',
#   'likecount': '2932'},
#  {'video_title': '5 Sports Analytics Books to Get You Started',
#   'published': '2019-12-13T14:00:01Z',
#   'viewcount': '10945',
#   'comment_ct': '59',
#   'likecount': '415'},
#  {'video_title': 'Math Needed for Mastering Data Science',
#   'published': '2019-12-09T14:00:15Z',
#   'viewcount': '57041',
#   'comment_ct': '222',
#   'likecount': '2882'},
#  {'video_title': 'The 5 Stages of Data Science Adoption',
#   'published': '2019-12-06T14:00:04Z',
#   'viewcount': '1329',
#   'comment_ct': '17',
#   'likecount': '69'},
#  {'video_title': 'How YOU Can Land a Sports Analytics Job',
#   'published': '2019-12-02T14:00:05Z',
#   'viewcount': '69813',
#   'comment_ct': '231',
#   'likecount': '3086'},
#  {'video_title': 'Data Science Fundamentals: Linear Regression',
#   'published': '2019-11-29T14:00:02Z',
#   'viewcount': '6390',
#   'comment_ct': '42',
#   'likecount': '172'},
#  {'video_title': 'Golf: Would You Rather Be the LONGEST or STRAIGHTEST Driver on the PGA Tour?',
#   'published': '2019-11-25T14:00:11Z',
#   'viewcount': '1105',
#   'comment_ct': '12',
#   'likecount': '53'},
#  {'video_title': 'Sports Analytics 101: The Pythagorean Theorem of Sports',
#   'published': '2019-11-22T14:00:06Z',
#   'viewcount': '6155',
#   'comment_ct': '26',
#   'likecount': '272'},
#  {'video_title': '9 Ways You Can Make Extra Income as a Data Scientist',
#   'published': '2019-11-18T15:34:12Z',
#   'viewcount': '46255',
#   'comment_ct': '80',
#   'likecount': '1760'},
#  {'video_title': 'Applying Data Science To My YouTube Data: My Surprising Findings',
#   'published': '2019-11-11T21:12:11Z',
#   'viewcount': '5940',
#   'comment_ct': '31',
#   'likecount': '137'},
#  {'video_title': 'Why Selling Is An Important Data Science Skill',
#   'published': '2019-11-04T14:57:00Z',
#   'viewcount': '1631',
#   'comment_ct': '13',
#   'likecount': '81'},
#  {'video_title': 'By The Numbers: Where Should The NBA Put a 4 Point Line?',
#   'published': '2019-10-21T16:38:58Z',
#   'viewcount': '2855',
#   'comment_ct': '18',
#   'likecount': '73'},
#  {'video_title': 'Why is Balance Important in Data Science?',
#   'published': '2019-10-16T17:40:34Z',
#   'viewcount': '704',
#   'comment_ct': '13',
#   'likecount': '32'},
#  {'video_title': 'How to Stay Productive & Motivated When Learning Data Science',
#   'published': '2019-09-29T00:29:59Z',
#   'viewcount': '11925',
#   'comment_ct': '54',
#   'likecount': '585'},
#  {'video_title': 'How Far Should the NBA 3-Point Line Actually Be?',
#   'published': '2019-09-21T23:04:57Z',
#   'viewcount': '3884',
#   'comment_ct': '34',
#   'likecount': '116'},
#  {'video_title': '6 Habits of Successful Data Scientists',
#   'published': '2019-09-13T04:40:51Z',
#   'viewcount': '2233',
#   'comment_ct': '17',
#   'likecount': '95'},
#  {'video_title': 'How To Build A Word Cloud From Scraped Data (Python)',
#   'published': '2019-09-04T01:32:06Z',
#   'viewcount': '4670',
#   'comment_ct': '9',
#   'likecount': '102'},
#  {'video_title': "Thank You For The Support | What's Next | Ken Jee | Data Science",
#   'published': '2019-08-26T12:42:32Z',
#   'viewcount': '521',
#   'comment_ct': '29',
#   'likecount': '24'},
#  {'video_title': 'Is Data Science Right For You?',
#   'published': '2019-08-18T16:54:05Z',
#   'viewcount': '51012',
#   'comment_ct': '109',
#   'likecount': '1182'},
#  {'video_title': 'Data Science Fundamentals: Data Cleaning in Python',
#   'published': '2019-08-11T20:50:23Z',
#   'viewcount': '14920',
#   'comment_ct': '55',
#   'likecount': '393'},
#  {'video_title': 'How To Get Data Science Experience (Without a Job)',
#   'published': '2019-08-08T01:58:40Z',
#   'viewcount': '29562',
#   'comment_ct': '77',
#   'likecount': '1388'},
#  {'video_title': 'Take Your Data Science Projects From Good to Great',
#   'published': '2019-08-05T02:34:28Z',
#   'viewcount': '1617',
#   'comment_ct': '11',
#   'likecount': '107'},
#  {'video_title': 'The Projects You Should Do To Get A Data Science Job',
#   'published': '2019-07-30T03:35:48Z',
#   'viewcount': '151145',
#   'comment_ct': '255',
#   'likecount': '5712'},
#  {'video_title': 'What Does a Data Scientist Actually Do?',
#   'published': '2019-07-19T03:18:04Z',
#   'viewcount': '46542',
#   'comment_ct': '81',
#   'likecount': '1272'},
#  {'video_title': 'Data Science Fundamentals: Data Manipulation in Python (Pandas)',
#   'published': '2019-07-13T21:09:41Z',
#   'viewcount': '13020',
#   'comment_ct': '43',
#   'likecount': '352'},
#  {'video_title': 'Data Science Fundamentals: Data Exploration in Python (Pandas)',
#   'published': '2019-07-05T14:29:49Z',
#   'viewcount': '17985',
#   'comment_ct': '61',
#   'likecount': '529'},
#  {'video_title': 'Data Science: Pros and Cons',
#   'published': '2019-06-30T15:26:49Z',
#   'viewcount': '5282',
#   'comment_ct': '18',
#   'likecount': '218'},
#  {'video_title': 'How I Got My First Data Science Internship (And How You Can Land One)',
#   'published': '2019-06-21T04:33:34Z',
#   'viewcount': '24937',
#   'comment_ct': '89',
#   'likecount': '1201'},
#  {'video_title': 'My Top 5 Data Science Internship Tips',
#   'published': '2019-06-15T15:28:26Z',
#   'viewcount': '11956',
#   'comment_ct': '23',
#   'likecount': '496'},
#  {'video_title': 'Golf STATS: Strokes Gained Explained',
#   'published': '2019-06-07T03:10:34Z',
#   'viewcount': '7568',
#   'comment_ct': '28',
#   'likecount': '158'},
#  {'video_title': 'Most Data Science Hopefuls Overlook This Important Skill',
#   'published': '2019-05-25T18:34:33Z',
#   'viewcount': '619',
#   'comment_ct': '5',
#   'likecount': '45'},
#  {'video_title': 'What I Learned From My Three Degrees',
#   'published': '2019-05-17T03:10:29Z',
#   'viewcount': '1272',
#   'comment_ct': '12',
#   'likecount': '61'},
#  {'video_title': 'I Wish I Had Known THIS Before Starting in Data Science',
#   'published': '2019-05-14T00:21:28Z',
#   'viewcount': '25674',
#   'comment_ct': '66',
#   'likecount': '1071'},
#  {'video_title': 'NASA Physicist Turned Data Scientist (Tim Bowling) - KNN EP. 02',
#   'published': '2019-05-05T20:26:36Z',
#   'viewcount': '1254',
#   'comment_ct': '2',
#   'likecount': '40'},
#  {'video_title': 'Should You Learn R for Data Science?',
#   'published': '2019-04-25T15:00:01Z',
#   'viewcount': '21252',
#   'comment_ct': '71',
#   'likecount': '566'},
#  {'video_title': 'Scrape Twitter Data in Python with Twitterscraper Module',
#   'published': '2019-04-18T15:00:14Z',
#   'viewcount': '46452',
#   'comment_ct': '331',
#   'likecount': '855'},
#  {'video_title': 'Work From Home Data Scientist: Day in the Life',
#   'published': '2019-04-12T15:00:00Z',
#   'viewcount': '28115',
#   'comment_ct': '101',
#   'likecount': '758'},
#  {'video_title': 'Where to Look for Data Science Jobs',
#   'published': '2019-03-29T16:00:01Z',
#   'viewcount': '3015',
#   'comment_ct': '9',
#   'likecount': '121'},
#  {'video_title': 'Data Science: Startup vs. Large Corporation',
#   'published': '2019-03-21T17:00:01Z',
#   'viewcount': '2174',
#   'comment_ct': '4',
#   'likecount': '75'},
#  {'video_title': "Data Science, Machine Learning, and AI: What's the Difference?",
#   'published': '2019-03-16T14:00:04Z',
#   'viewcount': '6191',
#   'comment_ct': '26',
#   'likecount': '176'},
#  {'video_title': 'Was Captain Marvel Bad? A Sentiment Analysis of Twitter Data',
#   'published': '2019-03-09T21:58:10Z',
#   'viewcount': '4212',
#   'comment_ct': '15',
#   'likecount': '180'},
#  {'video_title': "Why You DON'T Want to be a WFH Data Scientist",
#   'published': '2019-03-03T22:14:01Z',
#   'viewcount': '809',
#   'comment_ct': '12',
#   'likecount': '33'},
#  {'video_title': 'Welcome To My Channel | Ken Jee | Data Science',
#   'published': '2019-03-03T01:00:17Z',
#   'viewcount': '1441',
#   'comment_ct': '8',
#   'likecount': '36'},
#  {'video_title': 'Where YOU Should Start With Data Science Projects',
#   'published': '2019-02-19T03:23:50Z',
#   'viewcount': '17098',
#   'comment_ct': '17',
#   'likecount': '352'},
#  {'video_title': 'Watch This Before Applying to Data Science Jobs',
#   'published': '2019-02-04T23:40:34Z',
#   'viewcount': '1502',
#   'comment_ct': '13',
#   'likecount': '66'},
#  {'video_title': 'My Top 5 Data Science Resources for 2019',
#   'published': '2019-01-05T22:07:08Z',
#   'viewcount': '3714',
#   'comment_ct': '17',
#   'likecount': '122'},
#  {'video_title': "IT'S NOT TOO LATE TO LEARN CODE!",
#   'published': '2018-12-18T02:01:15Z',
#   'viewcount': '836',
#   'comment_ct': '6',
#   'likecount': '36'},
#  {'video_title': 'The Best Way to Predict NBA Minutes Played',
#   'published': '2018-12-11T02:39:35Z',
#   'viewcount': '4355',
#   'comment_ct': '14',
#   'likecount': '109'},
#  {'video_title': 'Demystifying Data Science Roles',
#   'published': '2018-11-30T01:22:49Z',
#   'viewcount': '1140',
#   'comment_ct': '5',
#   'likecount': '54'},
#  {'video_title': 'How to Simulate NBA Games in Python',
#   'published': '2018-11-19T23:31:49Z',
#   'viewcount': '17782',
#   'comment_ct': '54',
#   'likecount': '394'},
#  {'video_title': 'Should You Get A Masters in Data Science?',
#   'published': '2018-11-14T01:39:33Z',
#   'viewcount': '20607',
#   'comment_ct': '135',
#   'likecount': '305'},
#  {'video_title': 'How I Became A Data Scientist From a Business Background',
#   'published': '2018-11-12T00:26:08Z',
#   'viewcount': '6480',
#   'comment_ct': '23',
#   'likecount': '197'},
#  {'video_title': 'Predicting Season Long NBA Wins Using Multiple Linear Regression',
#   'published': '2018-07-10T16:39:52Z',
#   'viewcount': '8749',
#   'comment_ct': '17',
#   'likecount': '192'},
#  {'video_title': 'Predicting Crypto-Currency Price Using RNN lSTM & GRU',
#   'published': '2017-11-18T20:04:51Z',
#   'viewcount': '18996',
#   'comment_ct': '41',
#   'likecount': '293'}]

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (671 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.3/671.3 kB 8.8 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 29.4 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.5.0

# %%
import pymongo
from pymongo import MongoClient

# Connect to MongoDB
client = pymongo.MongoClient('mongodb://localhost:27017/')
db = client['youtube_project']
collection = db['channel_list']
collection = db['videoslist']

# Insert channel data into MongoDB
collection.insert_many(channel_details)

# Insert video data into MongoDB
collection.insert_many(video_det)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-4-0095c1f80386> in <cell line: 9>()
#       7 collection = db['orders']
#       8 data = {"name": "John", "age": 30, "city": "New York"}
# ----> 9 collection.insert_one(data)
#      10 # Insert channel data into MongoDB
#      11 #collection.insert_many(channel_details)
#
# /usr/local/lib/python3.10/dist-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session, comment)
#     669         write_concern = self._write_concern_for(session)
#     670         return InsertOneResult(
# --> 671             self._insert_one(
#     672                 document,
#     673                 ordered=True,
#
# /usr/local/lib/python3.10/dist-packages/pymongo/collection.py in _insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     609             _check_write_command_response(result)
#     610
# --> 611         self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     612
#     613         if not isinstance(doc, RawBSONDocument):
#
# /usr/local/lib/python3.10/dist-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1565     ) -> T:
#    1566         """Internal retryable write helper."""
# -> 1567         with self._tmp_session(session) as s:
#    1568             return self._retry_with_session(retryable, func, s, None)
#    1569
#
# /usr/lib/python3.10/contextlib.py in __enter__(self)
#     133         del self.args, self.kwds, self.func
#     134         try:
# --> 135             return next(self.gen)
#     136         except StopIteration:
#     137             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.10/dist-packages/pymongo/mongo_client.py in _tmp_session(self, session, close)
#    1883             return
#    1884
# -> 1885         s = self._ensure_session(session)
#    1886         if s:
#    1887             try:
#
# /usr/local/lib/python3.10/dist-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1866             # Don't make implicit sessions causally consistent. Applications
#    1867             # should always opt-in.
# -> 1868             return self.__start_session(True, causal_consistency=False)
#    1869         except (ConfigurationError, InvalidOperation):
#    1870             # Sessions not supported.
#
# /usr/local/lib/python3.10/dist-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1809         # Raises ConfigurationError if sessions are not supported.
#    1810         if implicit:
# -> 1811             self._topology._check_implicit_session_support()
#    1812             server_session: Union[_EmptyServerSession, _ServerSession] = _EmptyServerSession()
#    1813         else:
#
# /usr/local/lib/python3.10/dist-packages/pymongo/topology.py in _check_implicit_session_support(self)
#     581     def _check_implicit_session_support(self) -> None:
#     582         with self._lock:
# --> 583             self._check_session_support()
#     584
#     585     def _check_session_support(self) -> float:
#
# /usr/local/lib/python3.10/dist-packages/pymongo/topology.py in _check_session_support(self)
#     597                     )
#     598             elif not self._description.readable_servers:
# --> 599                 self._select_servers_loop(
#     600                     readable_server_selector, self.get_server_selection_timeout(), None
#     601                 )
#
# /usr/local/lib/python3.10/dist-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     267             # No suitable servers.
#     268             if timeout == 0 or now > end_time:
# --> 269                 raise ServerSelectionTimeoutError(
#     270                     f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     271                 )
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused, Timeout: 30s, Topology Description: <TopologyDescription id: 653f88ef24a4c665d55a3637, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused')>]>

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.10/dist-packages (1.28.0)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.8.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.23.5)
# Requirement already satisfied: packaging<24,>=16.8 in /usr/local/lib/python3.10/dist-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.5.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=6.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.6.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.5.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.2)
# Requirement already satisfied: watchdog>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.0.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.19.1)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<7,>=1.4->streamlit) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)

# %%
def main():

  print(channel_details)
  print(video_det)
  print(video_ids)

# %%
if __name__=="__main__":
    main()
# Out:
# [{'ch_name': 'Academind', 'ch_desc': "There's always something to learn!\nWe like to learn and love to teach, that's why we create courses and tutorials on many tech-related topics since 2016!\n\nWe teach development and web development (Python, React.js, JavaScript, Next.js, Flutter and many more) but also new technologies like ChatGPT. Check our YouTube channel, official website and social media and start learning today!\n\n🎥 Udemy Courses\nhttps://www.udemy.com/user/academind\n\n👉Academind Pro Membership (50+ courses included)\nhttps://pro.academind.com/\n\n🤝 Social Media\n• Twitter: @maxedapps (https://twitter.com/maxedapps) and @academind_real (https://twitter.com/academind_real)\n• Instagram: @academind_real (https://www.instagram.com/academind_real/)\n• Facebook: academindchannel (https://www.facebook.com/academindchannel)\n\n💻 Academind Official Website\nhttps://academind.com/\n\nSee you in the videos!\n\nImprint: https://academind.com/impressum/en\n", 'ch_join': '2015-12-04T12:55:40Z', 'subscriber': '889000', 'viewer': '73408003', 'vi_count': '661', 'playlist_id': 'UUSJbGtTlrDami-tDGPUV9-w'}, {'ch_name': 'Programming with Mosh', 'ch_desc': 'I train professional software engineers that companies love to hire. \n\nMy courses: http://codewithmosh.com \n\nMy blog: http://programmingwithmosh.com\n\nConnect on social media: \n\nhttp://www.twitter.com/moshhamedani\n\nhttps://www.facebook.com/programmingwithmosh\n\n#python #javascript #chsarp', 'ch_join': '2014-10-07T00:40:53Z', 'subscriber': '3590000', 'viewer': '180782898', 'vi_count': '178', 'playlist_id': 'UUWv7vMbMWH4-V0ZXdmDpPBA'}, {'ch_name': 'Ken Jee', 'ch_desc': 'Hi, I\'m Ken! Data Science, machine learning, AI and Sports Analytics are my passions.  When I was first starting out on my data science journey I was extremely lost. There were very few resources for me to learn about this field from. I decided to start making YouTube videos to share my experiences and to help others learn about data science, machine learning, and AI. \n\nOn this channel I produce fun and informative Data Science content. My goal is to make this field more acessible to everyone through commentary, tutorial, and other educational videos. \n\nI\'ve been working in the data science field doing sports analytics for the last 7 years. I\'ve held data science positions in companies ranging from startups to fortune 100 organizations.  Hopefully my experience will be valuable to you! \n\nCheck out my podcast "Ken\'s Nearest Neighbors" for some great interviews with the best in the field!\n\n', 'ch_join': '2014-02-28T14:58:24Z', 'subscriber': '253000', 'viewer': '8655901', 'vi_count': '284', 'playlist_id': 'UUiT9RITQ9PW6BhXK0y2jaeg'}, {'ch_name': 'ZenClass from GUVI', 'ch_desc': 'Welcome to ZenClass Channel! \n\nZen Class is one of the industry’s leading Project-Based Career Program from GUVI - IIT-M Incubated Company. We provide online live classes programs with 100% Job Placement Support.\n\nFull Stack Developer Program - https://bit.ly/3Cc4REq\n\nIIT Certified Programming Professional & Master Data Science - https://bit.ly/3DoUjTC\n\nAutomation Testing Program - https://bit.ly/3wJpAhV\n\nMaster Cyber Security & Ethical Hacking Program - https://bit.ly/30m5spF\n\nCall +91-9344419057 for more details\n', 'ch_join': '2019-12-28T03:57:05.532042Z', 'subscriber': '8830', 'viewer': '724352', 'vi_count': '301', 'playlist_id': 'UUiEmtpFVJjpvdhsQ2QAhxVA'}, {'ch_name': 'GUVI', 'ch_desc': 'GUVI is an IIT-M & IIM-A incubated edu-tech company that offers Wide range of online Tech courses in your Native language.\nWith 100% placement support, Globally recognized certifications, Mentors from top global product companies  and Platforms improve your Programming and IT skills GUVI does it all. With over 18 Lakh+ learners and 9+ years of experience we provide apex learning through our Edu-tech services, GUVI shares its most loved Tech-videos on YouTube!\n\nWhat’s on our YouTube Channel?\nCareer guidance videos that g ...
# [{'video_title': 'Next.js Projects:  Build a Full-stack App with Next.js, Tailwind, Radix UI, and Prisma', 'published': '2023-10-10T13:00:08Z', 'viewcount': '56132', 'comment_ct': '103', 'likecount': '1763'}, {'video_title': 'Next js Tutorial for Beginners | Nextjs 13 (App Router) with TypeScript', 'published': '2023-09-11T13:00:10Z', 'viewcount': '195374', 'comment_ct': '330', 'likecount': '5915'}, {'video_title': 'New Next js Course Coming Soon!', 'published': '2023-09-07T13:00:11Z', 'viewcount': '30196', 'comment_ct': '195', 'likecount': '1473'}, {'video_title': 'React Tutorial for Beginners', 'published': '2023-03-12T08:00:07Z', 'viewcount': '1385990', 'comment_ct': '903', 'likecount': '27023'}, {'video_title': 'ChatGPT Tutorial for Developers - 38 Ways to 10x Your Productivity', 'published': '2023-01-13T17:00:09Z', 'viewcount': '3434412', 'comment_ct': '1590', 'likecount': '52967'}, {'video_title': "Mosh's Xmas gift to you!", 'published': '2022-12-20T08:12:53Z', 'viewcount': '46802', 'comment_ct': '128', 'likecount': '1312'}, {'video_title': "Don't write code like John Smith!", 'published': '2022-11-15T14:00:07Z', 'viewcount': '78821', 'comment_ct': '241', 'likecount': '3233'}, {'video_title': 'C++ Tutorial for Beginners - Learn C++ in 1 Hour', 'published': '2022-08-10T16:00:12Z', 'viewcount': '2502144', 'comment_ct': '1737', 'likecount': '69640'}, {'video_title': 'TypeScript Tutorial for Beginners', 'published': '2022-05-23T13:00:18Z', 'viewcount': '845218', 'comment_ct': '650', 'likecount': '16691'}, {'video_title': 'Docker Compose Tutorial', 'published': '2022-03-22T14:00:12Z', 'viewcount': '339152', 'comment_ct': '391', 'likecount': '6065'}, {'video_title': 'Java Collections Tutorial', 'published': '2022-03-01T14:00:18Z', 'viewcount': '134079', 'comment_ct': '95', 'likecount': '2462'}, {'video_title': 'Java Generics Tutorial', 'published': '2022-02-22T14:00:07Z', 'viewcount': '51193', 'comment_ct': '44', 'likecount': '1096'}, {'video_title': 'Java Interfaces Tutorial', 'published': '2022-02-15T14:00:06Z', 'viewcount': '60446', 'comment_ct': '60', 'likecount': '1170'}, {'video_title': 'Java Exception Handling Tutorial', 'published': '2022-02-08T17:27:53Z', 'viewcount': '113758', 'comment_ct': '105', 'likecount': '1616'}, {'video_title': "Mosh's New Year's Gift to You!", 'published': '2022-01-10T16:00:10Z', 'viewcount': '55585', 'comment_ct': '162', 'likecount': '1481'}, {'video_title': "Mosh's Xmas Gift (2021)", 'published': '2021-12-20T23:02:36Z', 'viewcount': '81384', 'comment_ct': '327', 'likecount': '2926'}, {'video_title': '50% Off Black Friday Sale', 'published': '2021-11-22T19:09:19Z', 'viewcount': '103038', 'comment_ct': '288', 'likecount': '2888'}, {'video_title': 'Python Django Tutorial for Beginners', 'published': '2021-06-28T14:00:31Z', 'viewcount': '1951788', 'comment_ct': '1869', 'likecount': '34972'}, {'video_title': 'Docker Tutorial for Beginners', 'published': '2021-03-30T15:14:41Z', 'viewcount': '2107523', 'comment_ct': '1275', 'likecount': '37667'}, {'video_title': 'Docker course is coming!', 'published': '2021-03-25T17:30:03Z', 'viewcount': '45543', 'comment_ct': '223', 'likecount': '2036'}, {'video_title': 'HTML Tutorial for Beginners: HTML Crash Course', 'published': '2021-01-11T14:30:10Z', 'viewcount': '7421752', 'comment_ct': '4812', 'likecount': '174922'}, {'video_title': '5 Front-end Development Skills to Land Your First Job', 'published': '2021-01-07T14:30:14Z', 'viewcount': '1450873', 'comment_ct': '1101', 'likecount': '65491'}, {'video_title': 'Learn Web Development and Make $78,000/y', 'published': '2021-01-05T14:30:11Z', 'viewcount': '214980', 'comment_ct': '514', 'likecount': '11471'}, {'video_title': "Mosh's Christmas Gift to You!", 'published': '2020-12-22T00:41:01Z', 'viewcount': '83904', 'comment_ct': '270', 'likecount': '2678'}, {'video_title': 'What is Git? Explained in 2 Minutes!', 'published': '2020-09-21T13:00:03Z', 'viewcount': '447559', 'comment_ct': '343', 'likecount': '18290 ...
# ['J9sfR6HN6BY', 'ZVnjOPwW4ZA', 'QHBVA_7bSRg', 'SqcY0GlETPk', 'sTeoEFzVNSc', 'uN6JO-5GW8w', 'FhyHvFXXkbo', 'ZzaPdXTrSb8', 'd56mG7DezGs', 'HG6yIjZapSA', 'rH0winlka8A', '7i3Rliqzquw', 'JFuMei9Wwk4', '_nmm0nZqIIY', 'Sf8vefrS5PQ', 'LxQe4TqDdAU', 'KaVlRUvwvNk', 'rHux0gMZ3Eg', 'pTFZFxd4hOI', 'Eo90IEphG_M', 'qz0aGYrrlhU', '-_X6PhkjpzU', 'Nb0btdq1164', '1GlJnq-24uU', '2ReR1YJrNOM', '7eh4d6sabA0', 'kqtD5dpn9C8', '8JJ101D3knE', 'uxZZzmeCoLE', '6oFuwhIibo4', 'nKzEJWbkPbQ', 'uJLwnsLn0_Q', '0-S5a0eXPoc', 'poQXNp9ItL4', 'bjFvcFjJpE0', 'NU_1StN5Tkk', '8TnBZ8rom9c', 'QAs25_hMhZY', 'q4MEKTVxg0c', 'BBpAmxU_NQo', 'cifiry8yoao', 'XBoZPCgdnm8', 'eIrMbAQSU34', 'i8xsbYgMiBs', 'pEbIhUySqbk', '7S_tz1z_5bA', '_uQrJ0TkZlc', 'r16Rn4_jDfk', 'stZU1tJzHrA', 'z3-XFI_nXNM', '3Tcq_dBhIrQ', '2qKQGqpRsks', 'HLy_wLI6juc', 't9j8lCUGZXo', 'OxUsVif94aI', 'NKmasqr_Xkw', 'cQT33yu9pY8', 'Ctqi5Y4X-jA', '9OeznAkyQz4', 'Zp5MuPOtsSY', 'u-OmVr_fT4s', '94UHCEmprCY', 'ODjFDZC_TyA', '9ueMumuFv6g', 'tsBy6je8KjM', 'Y8Tko2YC5hA', 'f79MRyMsjrQ', 'yE9v9rt6ziw', 'Ke90Tje7VS0', 'NCwa_xi0Uuc', 'N3AkSS5hXMA', 'rNmxANyH0BU', 'mesu75PTDC8', 'XgSjoHgy3Rk', 'g1C40tDP0Bk', 'G3BS3sh3D8Q', '4_iT6EGkQfk', 'NgF9-pdTDGs', '09BwruU4kiY', 'gvicrj31JOM', 'H1NmJIv1A2Y', 'iJKkZA215tQ', 'fD0t_DKREbE', 'N8ap4k_1QEQ', 'bl98dm7vJt0', 'oigfaZ5ApsM', 's9wW2PpJsmQ', '23AOrSN-wmI', 'jpegXpQpb3o', 'IsG4Xd6LlsM', 'upDLs1sn7g4', 'W6NZfCO5SIk', 'PFmuCDHHpwk', 'pTB0EiLXUC8', 'pKd0Rpw7O48', 'TlB_eWDSMt4', 'VLXAzzRjQws', '9ErAONqE6HE', 'V2gVOIyUqVs', 'l20MBBFZAmA', 'IbgZASv0hc8', 'j95Lwxvi9JY', 'WlWdbtJoCLQ', '44b6CDDnDPg', 'Cxo4UKpHv5s', '9Amxzvq5LY8', 'jn8PZNBmKm0', 'KvG0a9dY3UI', 'qZQmCfkmbNA', 'jOupHNvDIq8', 'XUSHH0E-7zk', 'uVwtVBpw7RQ', 'SLwpqD8n3d0', 'H5ySG5364uE', 'fo6rvTP9kkc', '_TxOmmJTd98', 'aQ8YkJrAbzE', '56bbjE4assU', 'vpT4-7YdV7M', 'q7aWkjH3UUI', '4_J_CLKwoto', 'ZqDtPFrUonQ', 'HYrXogLj7vg', 'ocz2Ml5Wg9g', 'gK21_9QuthM', 'tUCa3JcFILI', 'LtT01ZCHRjk', 'hAaoPOx_oIw', 'vwyvMZStS54', 'mqWXRX5fxGQ', 'ra5qNKNc95U', 'wPT3K3w6JtU', '9AaRJ8COXdM', 'k5E2AVpwsko', 'azCCiJJjKr4', 'tiWqCBXnWj0', 'P17bFRuefjA', 'W9Ah_ZDFc1c', 'QygRnETpBIg', 'NjN00cM18Z4', '8Wyc2XuBkQg', 'AsB54HC7MV4', 'c0UdqoRT_Xg', 'WjcL09xgo3o', 'ZX7_12fwQLU', 'yt8lqei9xyg', 'Q1uORsKjrMo', 'yG4FH60fhUE', 'UEcdQR-NoNA', 'e-_mDyqm2oU', '93ZU6j59wL4', 'yBxPgF85vt4', 'E7Voso411Vs', 'bevlMOzaFTc', 'gfkTfcpWqAY', 'SRn_E6juCVE', 'CaspUXvVVG4', '_-CD_5YhJTA', 'rtXpYpZdOzM', 'u-HdLtqEOog', 'gyal6TbgmSU', 'jQgwEsJISy0', '5koPpYVa020', 'BFAGGPgi0ec', 'kh6ehZ1BCUk', 'tTRy_GluLac', 'dC0LVPZedZA', 'QkHeKnjNuWA', 'QASCp8PyRXM', 'jbiqBchPfKw', 'NjCF_7bpKjw', 'ZnGP9ScI9pc', 'AvhdNKmmAXU', '4t0n5k0X7ow', 'FfQT31gZWp8', 'niYCJOMZPJw', 'FXlSC1gcs7E', 'IPc1HP1QAog', 'JhxC-K-Eehg']

# %%
print(ch_name,video_det)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-b8a85e2a0995> in <cell line: 1>()
# ----> 1 print(ch_name,video_det)
#
# NameError: name 'ch_name' is not defined

# %%
from pymongo import MongoClient
db = MongoClient(port=123456)['hema']
cursor = db.mycollection.find()
print(f"No error, here's the cursor {cursor}")
# Out:
# No error, here's the cursor <pymongo.cursor.Cursor object at 0x7b8d2423e110>

# %%
import pymongo

# %%
client = pymongo.MongoClient('mongodb://localhost:27017')

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client['youtube_proj']
