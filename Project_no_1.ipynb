# %%
import pandas as pd
df = pd.read_excel("/content/Project SQL.xlsx")

# %% [markdown]
# 1.**Country code extracted from order id column**

# %%
df["Order ID"]
# Out:
# 0       CA-2017-167976
# 1       CA-2017-165099
# 2       US-2015-147662
# 3       CA-2017-109757
# 4       CA-2014-111360
#              ...
# 9689    CA-2015-112014
# 9690    CA-2016-106621
# 9691    CA-2016-134222
# 9692    CA-2016-108224
# 9693    CA-2017-159282
# Name: Order ID, Length: 9694, dtype: object

# %% [markdown]
# **2.Get the top 5 profit from sales for each city wise**

# %%
df.loc[df.City=="Akron"][df.Profit==df.Profit.max()]
# Out:
# <ipython-input-13-056640a0c11a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.loc[df.City=="Akron"][df.Profit==df.Profit.max()]
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, rk, Sales Category]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(df[['City','Sales','Profit']][df.City=="Aberdeen"][df.Profit== df.Profit.max()].head(5))
# Out:
# Empty DataFrame
# Columns: [City, Sales, Profit]
# Index: []
# <ipython-input-11-839b116aca4b>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[['City','Sales','Profit']][df.City=="Aberdeen"][df.Profit== df.Profit.max()].head(5))

# %% [markdown]
# 3.**Extract the maximum values using row number function**

# %%
print(df['Row ID'].nlargest())
# Out:
# 9594    9994
# 1587    9993
# 1596    9992
# 1590    9991
# 4871    9990
# Name: Row ID, dtype: int64

# %%
print(df['Row ID'].max())
# Out:
# 9994

# %%
df[['City','State']]
# Out:
#           City         State
# 0     Aberdeen  South Dakota
# 1      Abilene         Texas
# 2        Akron          Ohio
# 3        Akron          Ohio
# 4        Akron          Ohio
# ...        ...           ...
# 9689   Yucaipa    California
# 9690      Yuma       Arizona
# 9691      Yuma       Arizona
# 9692      Yuma       Arizona
# 9693      Yuma       Arizona
#
# [9694 rows x 2 columns]

# %% [markdown]
# **4.Remove duplicates from city , state**

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9689    False
# 9690    False
# 9691    False
# 9692    False
# 9693    False
# Length: 9694, dtype: bool

# %% [markdown]
# **5.Segment wise sales which is greater than 500**

# %%
df[['Row ID','Sales']][df.Sales > 500]
# Out:
#       Row ID     Sales
# 22       455   665.408
# 36      2417   595.000
# 50      3281  4164.050
# 61      9190   663.072
# 72      1439  2453.430
# ...      ...       ...
# 9664    2845   845.488
# 9681    5298   543.920
# 9682    1083   836.592
# 9683    1086  4899.930
# 9693    7282   599.985
#
# [1151 rows x 2 columns]

# %% [markdown]
# **6.Category Sales 0 - 100 as low , 101 - 500 medium , 500 - 2000 as high , > 2000  as best**

# %%
import numpy as np
df.loc[(df.Sales >=0) & (df.Sales <100),'Sales Category']="LOW"
df.loc[(df.Sales >100) & (df.Sales <= 500),'Sales Category']="MEDIUM"
df.loc[(df.Sales >500) & (df.Sales <= 2000),'Sales Category']="HIGH"
df.loc[(df.Sales >2000) ,'Sales Category']="BEST"
df[['Sales','Sales Category']]
# Out:
#         Sales Sales Category
# 0      25.500            LOW
# 1       1.392            LOW
# 2       2.286            LOW
# 3       4.368            LOW
# 4       5.742            LOW
# ...       ...            ...
# 9689   50.800            LOW
# 9690   10.496            LOW
# 9691   44.856            LOW
# 9692  185.528         MEDIUM
# 9693  599.985           HIGH
#
# [9694 rows x 2 columns]

# %% [markdown]
# 7**.city , region wise sum of sales , profits , count of sales & profits**

# %%
Region_list=df.groupby('Region').groups.keys()
print(len(Region_list))
print( df.groupby('Region').get_group('Central'))
# Out:
# 4
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0       9261  CA-2017-167976 2017-11-11      43053    Second Class
# 1       6990  CA-2017-165099 2017-12-11      43082     First Class
# 51      1568  CA-2015-129112 2015-11-29      42338     First Class
# 52      2976  CA-2015-137512 2015-05-07      42136  Standard Class
# 53      1567  CA-2015-129112 2015-11-29      42338     First Class
# ...      ...             ...        ...        ...             ...
# 9655    5350  CA-2015-149811 2015-01-04      42014  Standard Class
# 9656    8737  CA-2016-168774 2016-09-04      42622  Standard Class
# 9660    2572  CA-2017-109778 2017-07-16      42937  Standard Class
# 9661    2883  CA-2014-165540 2014-02-21      41695  Standard Class
# 9664    2845  US-2016-162852 2016-12-27      42735  Standard Class
#
#      Customer ID      Customer Name      Segment        Country       City  \
# 0       JL-15505    Jeremy Lonsdale     Consumer  United States   Aberdeen
# ...

# %%
print(df.groupby('City').ngroups)
# Out:
# 529

# %%
df['Sales']
# Out:
# 0        25.500
# 1         1.392
# 2         2.286
# 3         4.368
# 4         5.742
#          ...
# 9689     50.800
# 9690     10.496
# 9691     44.856
# 9692    185.528
# 9693    599.985
# Name: Sales, Length: 9694, dtype: float64

# %%
sum_sales={}
for Region in df['Region'].unique():
  tempdf = df[df['Region']==Region]
  sum_sale= tempdf['Sales'].sum()
  sum_sales['Region_list']=sum_sale
  aggregate_df=pd.DataFrame.from_dict(sum_sales,orient='index',columns=['Sales for Region'])
  print(aggregate_df)
# Out:
#              Sales for Region
# Region_list       497800.8728
#              Sales for Region
# Region_list        672194.054
#              Sales for Region
# Region_list       713471.3445
#              Sales for Region
# Region_list        388983.585

# %%
sum_tot=df.groupby('Region')['Sales'].sum()
print(sum_tot)
# Out:
# Region
# Central    497800.8728
# East       672194.0540
# South      388983.5850
# West       713471.3445
# Name: Sales, dtype: float64

# %%
profit_tot=df.groupby('Region')['Profit'].sum()
print(profit_tot)
# Out:
# Region
# Central     40128.9030
# East        90672.0127
# South       46035.6890
# West       106021.1495
# Name: Profit, dtype: float64

# %%
print(df.groupby('Sales').ngroups)
# Out:
# 5696

# %%
print(df.groupby('Profit').ngroups)
# Out:
# 7076

# %% [markdown]
# **8.Select all the records belongs to region east & west with sales > 500**

# %%
 df[(df['Region']=='East') & (df['Sales']> 500)] ,df[['Region','Sales']]
# Out:
# (      Row ID        Order ID Order Date  Ship Date       Ship Mode  \
#  22       455  CA-2017-147277 2017-10-20      43032  Standard Class
#  61      9190  US-2015-130512 2015-08-21      42241  Standard Class
#  267      989  CA-2017-167899 2017-05-21      42881  Standard Class
#  435     5695  US-2015-138093 2015-12-10      42354  Standard Class
#  436     7184  CA-2017-128853 2017-04-21      42848     First Class
#  ...      ...             ...        ...        ...             ...
#  9647    5395  US-2014-123183 2014-11-19      41968  Standard Class
#  9648    4941  CA-2015-156482 2015-02-06      42048  Standard Class
#  9681    5298  CA-2017-108791 2017-07-27      42947  Standard Class
#  9682    1083  US-2016-143819 2016-03-01      42434  Standard Class
#  9683    1086  US-2016-143819 2016-03-01      42434  Standard Class
#
#       Customer ID      Customer Name      Segment        Country        City  \
# ...

# %%
df[(df['Region']=='West') & (df['Sales']> 500)] ,df[['Region','Sales']]
# Out:
# (      Row ID        Order ID Order Date  Ship Date       Ship Mode  \
#  36      2417  CA-2017-168655 2017-10-12      43026  Standard Class
#  94      9908  US-2015-129007 2015-09-13      42262     First Class
#  95      7058  CA-2016-165330 2016-12-11      42715        Same Day
#  96      9943  CA-2014-143371 2014-12-28      42007  Standard Class
#  97      5871  CA-2016-128223 2016-06-14      42535        Same Day
#  ...      ...             ...        ...        ...             ...
#  9440    8784  CA-2016-116911 2016-09-15      42633  Standard Class
#  9463     639  CA-2016-115917 2016-05-20      42515  Standard Class
#  9597    9180  CA-2017-156776 2017-08-07      42958  Standard Class
#  9598    9187  CA-2017-156776 2017-08-07      42958  Standard Class
#  9693    7282  CA-2017-159282 2017-10-16      43029  Standard Class
#
#       Customer ID      Customer Name      Segment        Country         City  \
# ...

# %% [markdown]
# **9.create 'Rank' by city**

# %%
df["Rank"] = df['City'].rank()
df.sort_values('City',inplace=True)
df[['City','Rank']]
# Out:
#           City    Rank
# 0     Aberdeen     1.0
# 1      Abilene     2.0
# 2        Akron    13.0
# 3        Akron    13.0
# 4        Akron    13.0
# ...        ...     ...
# 9689   Yucaipa  9690.0
# 9692      Yuma  9692.5
# 9690      Yuma  9692.5
# 9691      Yuma  9692.5
# 9693      Yuma  9692.5
#
# [9694 rows x 2 columns]

# %% [markdown]
# **Dense Rank by Sales**

# %%
df["Dense Rank"] = df['Sales'].rank(method = 'dense').astype(int)
df[['Dense Rank','Sales']]
# Out:
#       Dense Rank    Sales
# 0           1444   25.500
# 1             21    1.392
# 22          5013  665.408
# 20          4182  284.364
# 19          4168  279.960
# ...          ...      ...
# 9689        2227   50.800
# 9690         670   10.496
# 9691        2081   44.856
# 9692        3699  185.528
# 9693        4924  599.985
#
# [9694 rows x 2 columns]

# %% [markdown]
#  ***LEFT OUTER JOIN:***
#
#  In left outer join of 2 data frames,the first (left) data frame will print as it is.
#  And the second data frame the values which is common in first data frame only printed.
#
# # **We use MERGE method and how ='left'**
#
#  ***RIGHT OUTER JOIN:***
#
#
#  In Right outer join of 2 data frames,the Second (right) data frame will print as it is.
#  And the first data frame the values which is common in second data frame only printed.
#
# # **We use MERGE method and how ='right'**
#
# **INNER JOIN:**
#
# In inner join function, with the 2 data frames the common values in both data frames only printed
#
# # **We use MERGE method and how ='inner'**
#
#
# **OUTER JOIN:**
#
# In 2 data frames , the outer join print all the values in both data frames and fill NAN values in which there is no common values.
#
# # **We use MERGE method and how ='outer'**
